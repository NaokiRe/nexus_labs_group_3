# %% [markdown]
# # depression, ed, healthanxiety, lonely, mentalhealth, parenting

# %%
# !pip install scipy
# !pip install pandas
# !pip install numpy
# !pip install prettytable
# Out:
# Requirement already satisfied: scipy in /Users/yuma/anaconda3/lib/python3.9/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/yuma/anaconda3/lib/python3.9/site-packages (from scipy) (1.26.2)
# Requirement already satisfied: pandas in /Users/yuma/anaconda3/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/yuma/anaconda3/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yuma/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yuma/anaconda3/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/yuma/anaconda3/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/yuma/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/yuma/anaconda3/lib/python3.9/site-packages (1.26.2)
# Requirement already satisfied: prettytable in /Users/yuma/anaconda3/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: wcwidth in /Users/yuma/anaconda3/lib/python3.9/site-packages (from prettytable) (0.2.5)

# %%
from scipy.stats import f_oneway, ttest_ind
import itertools
import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import numpy as np
from numpy import mean, std
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf
import ipywidgets as widgets

# %%
adhd_data = pd.read_csv('datasets/adhd_2018_features_tfidf_256.csv')
anxiety_data = pd.read_csv('datasets/anxiety_2018_features_tfidf_256.csv')
autism_data = pd.read_csv('datasets/autism_2018_features_tfidf_256.csv')
bpd_data = pd.read_csv('datasets/bpd_2018_features_tfidf_256.csv')
depression_data = pd.read_csv('datasets/depression_2018_features_tfidf_256.csv')
ed_data = pd.read_csv('datasets/EDAnonymous_2019_features_tfidf_256.csv')
healthanxiety_data = pd.read_csv('datasets/healthanxiety_2018_features_tfidf_256.csv')
ptsd_data = pd.read_csv('datasets/ptsd_2018_features_tfidf_256.csv')
schizophrenia_data = pd.read_csv('datasets/schizophrenia_2018_features_tfidf_256.csv')
socialanxiety_data = pd.read_csv('datasets/socialanxiety_2018_features_tfidf_256.csv')

datasets = {
    "adhd": adhd_data,
    "anxiety": anxiety_data,
    "autism": autism_data,
    "bpd": bpd_data,
    "depression": depression_data,
    "ed": ed_data,
    "healthanxiety": healthanxiety_data,
    "ptsd": ptsd_data,
    "schizophrenia": schizophrenia_data,
    "socialanxiety": socialanxiety_data
}

readability_parameters = [
    "automated_readability_index",
    "coleman_liau_index",
    "flesch_kincaid_grade_level",
    "flesch_reading_ease",
    "gulpease_index",
    "gunning_fog_index",
    "lix",
    "smog_index",
    "wiener_sachtextformel"
]

tfidf_parameters = [
    "tfidf_abus",
    "tfidf_actual",
    "tfidf_addict",
    "tfidf_adhd",
    "tfidf_advic",
    "tfidf_ago",
    "tfidf_alcohol",
    "tfidf_almost",
    "tfidf_alon",
    "tfidf_alreadi",
    "tfidf_also",
    "tfidf_alway",
    "tfidf_amp",
    "tfidf_amp x200b",
    "tfidf_ani",
    "tfidf_anoth",
    "tfidf_anxieti",
    "tfidf_anxious",
    "tfidf_anymor",
    "tfidf_anyon",
    "tfidf_anyon els",
    "tfidf_anyth",
    "tfidf_around",
    "tfidf_ask",
    "tfidf_attack",
    "tfidf_away",
    "tfidf_back",
    "tfidf_bad",
    "tfidf_becaus",
    "tfidf_becom",
    "tfidf_befor",
    "tfidf_believ",
    "tfidf_best",
    "tfidf_better",
    "tfidf_bit",
    "tfidf_bodi",
    "tfidf_bpd",
    "tfidf_brain",
    "tfidf_call",
    "tfidf_came",
    "tfidf_care",
    "tfidf_caus",
    "tfidf_chang",
    "tfidf_come",
    "tfidf_complet",
    "tfidf_constant",
    "tfidf_control",
    "tfidf_could",
    "tfidf_coupl",
    "tfidf_cri",
    "tfidf_day",
    "tfidf_deal",
    "tfidf_depress",
    "tfidf_diagnos",
    "tfidf_die",
    "tfidf_differ",
    "tfidf_disord",
    "tfidf_doctor",
    "tfidf_doe",
    "tfidf_done",
    "tfidf_dont",
    "tfidf_drink",
    "tfidf_drug",
    "tfidf_eat",
    "tfidf_els",
    "tfidf_emot",
    "tfidf_end",
    "tfidf_enough",
    "tfidf_etc",
    "tfidf_even",
    "tfidf_ever",
    "tfidf_everi",
    "tfidf_everyon",
    "tfidf_everyth",
    "tfidf_experi",
    "tfidf_famili",
    "tfidf_fear",
    "tfidf_feel",
    "tfidf_feel like",
    "tfidf_felt",
    "tfidf_final",
    "tfidf_find",
    "tfidf_first",
    "tfidf_food",
    "tfidf_found",
    "tfidf_friend",
    "tfidf_fuck",
    "tfidf_get",
    "tfidf_give",
    "tfidf_go",
    "tfidf_good",
    "tfidf_got",
    "tfidf_great",
    "tfidf_guess",
    "tfidf_guy",
    "tfidf_happen",
    "tfidf_happi",
    "tfidf_hard",
    "tfidf_hate",
    "tfidf_head",
    "tfidf_health",
    "tfidf_hear",
    "tfidf_heart",
    "tfidf_help",
    "tfidf_high",
    "tfidf_home",
    "tfidf_hope",
    "tfidf_hour",
    "tfidf_hous",
    "tfidf_hurt",
    "tfidf_idea",
    "tfidf_im",
    "tfidf_issu",
    "tfidf_job",
    "tfidf_keep",
    "tfidf_kill",
    "tfidf_kind",
    "tfidf_know",
    "tfidf_last",
    "tfidf_late",
    "tfidf_leav",
    "tfidf_left",
    "tfidf_let",
    "tfidf_life",
    "tfidf_like",
    "tfidf_littl",
    "tfidf_live",
    "tfidf_long",
    "tfidf_look",
    "tfidf_lose",
    "tfidf_lost",
    "tfidf_lot",
    "tfidf_love",
    "tfidf_made",
    "tfidf_make",
    "tfidf_mani",
    "tfidf_mayb",
    "tfidf_mean",
    "tfidf_med",
    "tfidf_medic",
    "tfidf_mental",
    "tfidf_might",
    "tfidf_mind",
    "tfidf_mom",
    "tfidf_month",
    "tfidf_move",
    "tfidf_much",
    "tfidf_need",
    "tfidf_never",
    "tfidf_new",
    "tfidf_next",
    "tfidf_night",
    "tfidf_normal",
    "tfidf_noth",
    "tfidf_notic",
    "tfidf_old",
    "tfidf_onc",
    "tfidf_one",
    "tfidf_onli",
    "tfidf_pain",
    "tfidf_panic",
    "tfidf_parent",
    "tfidf_part",
    "tfidf_past",
    "tfidf_peopl",
    "tfidf_person",
    "tfidf_place",
    "tfidf_pleas",
    "tfidf_point",
    "tfidf_possibl",
    "tfidf_post",
    "tfidf_pretti",
    "tfidf_probabl",
    "tfidf_problem",
    "tfidf_ptsd",
    "tfidf_put",
    "tfidf_question",
    "tfidf_quit",
    "tfidf_read",
    "tfidf_real",
    "tfidf_realli",
    "tfidf_reason",
    "tfidf_recent",
    "tfidf_relationship",
    "tfidf_rememb",
    "tfidf_right",
    "tfidf_said",
    "tfidf_say",
    "tfidf_scare",
    "tfidf_school",
    "tfidf_see",
    "tfidf_seem",
    "tfidf_self",
    "tfidf_sever",
    "tfidf_shit",
    "tfidf_sinc",
    "tfidf_situat",
    "tfidf_sleep",
    "tfidf_social",
    "tfidf_someon",
    "tfidf_someth",
    "tfidf_sometim",
    "tfidf_sorri",
    "tfidf_start",
    "tfidf_stay",
    "tfidf_still",
    "tfidf_stop",
    "tfidf_stress",
    "tfidf_struggl",
    "tfidf_stuff",
    "tfidf_suicid",
    "tfidf_support",
    "tfidf_sure",
    "tfidf_symptom",
    "tfidf_take",
    "tfidf_talk",
    "tfidf_tell",
    "tfidf_thank",
    "tfidf_therapi",
    "tfidf_therapist",
    "tfidf_thing",
    "tfidf_think",
    "tfidf_though",
    "tfidf_thought",
    "tfidf_time",
    "tfidf_tire",
    "tfidf_today",
    "tfidf_told",
    "tfidf_took",
    "tfidf_tri",
    "tfidf_turn",
    "tfidf_two",
    "tfidf_understand",
    "tfidf_us",
    "tfidf_use",
    "tfidf_usual",
    "tfidf_veri",
    "tfidf_want",
    "tfidf_way",
    "tfidf_week",
    "tfidf_weight",
    "tfidf_well",
    "tfidf_went",
    "tfidf_whi",
    "tfidf_whole",
    "tfidf_wish",
    "tfidf_without",
    "tfidf_wonder",
    "tfidf_work",
    "tfidf_worri",
    "tfidf_wors",
    "tfidf_would",
    "tfidf_wrong",
    "tfidf_x200b",
    "tfidf_year"
]

diseases = list(datasets.keys())

# %% [markdown]
# **ANOVA Testing**
#
# The F-statistic and p-value are both outcomes of an ANOVA test, which is used to determine if there are statistically significant differences between groups.
#
# * F-statistic: This statistic represents the ratio of the variability between groups to the variability within groups. A higher F-statistic suggests that the means of the groups are more different from each other relative to the variation within each group.
#
# * p-value: This value indicates the probability of obtaining results as extreme as the ones observed in the data, assuming that the null hypothesis is true (i.e., assuming there are no differences between the groups). A lower p-value suggests stronger evidence against the null hypothesis. Typically, a p-value below a certain significance level (commonly 0.05) is considered statistically significant.

# %%
anova_significant_pairs = {}
anova_insignificant_pairs = {}

for parameter in readability_parameters:
    for pair in itertools.combinations(diseases, 2):
        disease_1 = pair[0]
        disease_2 = pair[1]

        group_1 = datasets[disease_1][parameter]
        group_2 = datasets[disease_2][parameter]

        f_stat, p_value = f_oneway(group_1, group_2)
        if p_value < 0.05: 
            if (disease_1, disease_2) not in anova_significant_pairs:
                anova_significant_pairs[(disease_1, disease_2)] = []
            anova_significant_pairs[(disease_1, disease_2)].append(parameter)
        else:
            if (disease_1, disease_2) not in anova_insignificant_pairs:
                anova_insignificant_pairs[(disease_1, disease_2)] = []
            anova_insignificant_pairs[(disease_1, disease_2)].append(parameter)
        print(f"ANOVA results for {parameter} between {disease_1} and {disease_2}: F-statistic = {f_stat}, p-value = {p_value}")

for pair, parameters in anova_significant_pairs.items():
    if pair in anova_insignificant_pairs:
        print(f"{pair[0]} and {pair[1]}: {', '.join(parameters)} : {', '.join(anova_insignificant_pairs[pair])}")
    else:
        print(f"{pair[0]} and {pair[1]}: {', '.join(parameters)} : No insignificant parameters")
for pair, parameters in anova_insignificant_pairs.items():
    if pair not in anova_significant_pairs:
        print(f"{pair[0]} and {pair[1]}: No significant parameters : {', '.join(parameters)}")
# Out:
# ANOVA results for automated_readability_index between adhd and anxiety: F-statistic = 135.16592711157259, p-value = 4.2508434680442095e-31
# ANOVA results for automated_readability_index between adhd and autism: F-statistic = 48.27619672556893, p-value = 4.108654483849592e-12
# ANOVA results for automated_readability_index between adhd and bpd: F-statistic = 115.24789117721284, p-value = 1.088934972823013e-26
# ANOVA results for automated_readability_index between adhd and depression: F-statistic = 852.5794182903754, p-value = 8.305541612583729e-185
# ANOVA results for automated_readability_index between adhd and ed: F-statistic = 470.58666550801547, p-value = 2.4739430633821322e-101
# ANOVA results for automated_readability_index between adhd and healthanxiety: F-statistic = 26.202096608352424, p-value = 3.172247129220692e-07
# ANOVA results for automated_readability_index between adhd and ptsd: F-statistic = 0.22803028973280645, p-value = 0.6330061576476655
# ANOVA results for automated_readability_index between adhd and schizophrenia: F-statistic = 2.486988033315433, p-value = 0.11484285261620589
# ANOVA results for automated_readability_index between adhd and socialanxiety: F-statistic = 73.07961214522746, p-value = 1.4787013819449842e-17
# ANOVA results for automated_readability_index between anxiety and autism: F-statistic = 176.47875026589054, p-value = 6.587303060567951e-40
# ANOVA results for automated_readability_index between anxiety and bpd: F-statistic = 12.584080941775243, p-value = 0.00039067929207334013
# ANOVA results for automated_readability_index between anxiety and depression: F-statistic = 460.5052771256981, p-value = 1.8355332592636972e-101
# ANOVA results for automated_readability_index between anxiety and ed: F-statistic = 285.4752900634974, p-value = 2.928980711426257e-63
# ANOVA results for automated_readability_index between anxiety and healthanxiety: F-statistic = 0.03042434731746814, p-value = 0.8615346323029953
# ANOVA results for automated_readability_index between anxiety and ptsd: F-statistic = 22.664043780799744, p-value = 1.9586122671971223e-06
# ANOVA results for automated_readability_index between anxiety and schizophrenia: F-statistic = 66.25415288559809, p-value = 4.456498274276188e-16
# ANOVA results for automated_readability_index between anxiety and socialanxiety: F-statistic = 0.0781468006783793, p-value = 0.7798297636360685
# ANOVA results for automated_readability_index between autism and bpd: F-statistic = 154.2184498522687, p-value = 1.4397354788844229e-34
# ANOVA results for automated_readability_index between autism and depression: F-statistic = 353.95433295292213, p-value = 2.011442796355148e-78
# ANOVA results for automated_readability_index between autism and ed: F-statistic = 280.64844806196714, p-value = 1.6881918563921634e-60
# ANOVA results for automated_readability_index between autism and healthanxiety: F-statistic = 67.24371716788072, p-value = 5.158768868734957e-16
# ANOVA results for automated_readability_index between autism and ptsd: F-statistic = 21.76251298253099, p-value = 3.3839664365535952e-06
# ANOVA results for automated_readability_index between autism and schizophrenia: F-statistic = 16.57602316316123, p-value = 4.8885817711489046e-05
# ANOVA results for automated_readability_index between autism and socialanxiety: F-statistic = 129.936673956826, p-value = 1.3949402939386738e-29
# ANOVA results for automated_readability_index between bpd and depression: F-statistic = 74.98147492022743, p-value = 5.013241813498239e-18
# ANOVA results for automated_readability_index between bpd and ed: F-statistic = 88.29237750240165, p-value = 8.430768081851678e-21
# ANOVA results for automated_readability_index between bpd and healthanxiety: F-statistic = 2.899396305170162, p-value = 0.0887123693321198
# ANOVA results for automated_readability_index between bpd and ptsd: F-statistic = 30.437269859386507, p-value = 3.739015300826384e-08
# ANOVA results for automated_readability_index between bpd and schizophrenia: F-statistic = 70.71946786698787, p-value = 6.017768602053346e-17
# ANOVA results for automated_readability_index between bpd and socialanxiety: F-statistic = 6.789806045941214, p-value = 0.009194379705137857
# ANOVA results for automated_readability_index between depression and ed: F-statistic = 20.11823945443222, p-value = 7.309770403874082e-06
# ANOVA results for automated_readability_index between depression and healthanxiety: F-statistic = 49.81843363117934, p-value = 1.7299742143091976e-12
# ANOVA results for automated_readability_index between depression and ptsd: F-statistic = 123.74212899149776, p-value = 1.1186561907068813e-28
# ANOVA results for automated_readability_index between depression and schizophrenia: F-statistic = 244.15949994911693, p-value = 8.740896566615097e-55
# ANOVA results for automated_readability_index between depression and socialanxiety: F-statistic = 167.27292896060425, p-value = 3.7733398930387375e-38
# ANOVA results for automated_readability_index between ed and healthanxiety: F-statistic = 60.21388497152701, p-value = 1.118794747408974e-14
# ANOVA results for automated_readability_index between ed and ptsd: F-statistic = 113.80031826305999, p-value = 3.8356166161501976e-26
# ANOVA results for automated_readability_index between ed and schizophrenia: F-statistic = 205.2974348695081, p-value = 2.5081606967392974e-45
# ANOVA results for automated_readability_index between ed and socialanxiety: F-statistic = 155.9399112444154, p-value = 2.665056782849468e-35
# ANOVA results for automated_readability_index between healthanxiety and ptsd: F-statistic = 8.870839723910937, p-value = 0.0029442351931928488
# ANOVA results for automated_readability_index between healthanxiety and schizophrenia: F-statistic = 23.656830279569082, p-value = 1.2509772494929568e-06
# ANOVA results for automated_readability_index between healthanxiety and socialanxiety: F-statistic = 9.110130475064689e-05, p-value = 0.9923850728128811
# ANOVA results for automated_readability_index between ptsd and schizophrenia: F-statistic = 1.6940954241311534, p-value = 0.19323628147522304
# ANOVA results for automated_readability_index between ptsd and socialanxiety: F-statistic = 17.26236522391652, p-value = 3.332955614814077e-05
# ANOVA results for automated_readability_index between schizophrenia and socialanxiety: F-statistic = 48.094939973123374, p-value = 4.74380081171978e-12
# ANOVA results for coleman_liau_index between adhd and anxiety: F-statistic = 198.32362235135253, p-value = 9.945957210482585e-45
# ANOVA results for coleman_liau_index between adhd and autism: F-statistic = 85.85957884210178, p-value = 2.6668383944349344e-20
# ANOVA results for coleman_liau_index between adhd and bpd: F-statistic = 129.41586223602116, p-value = 9.68051865585154e-30
# ANOVA results for coleman_liau_index between adhd and depression: F-statistic = 1261.0253254337917, p-value = 1.5718244840139293e-270
# ANOVA results for coleman_liau_index between adhd and ed: F-statistic = 389.55322854710664, p-value = 1.25061351283841e-84
# ANOVA results for coleman_liau_index between adhd and healthanxiety: F-statistic = 15.34533533789001, p-value = 9.05526121842622e-05
# ANOVA results for coleman_liau_index between adhd and ptsd: F-statistic = 0.15186566413943084, p-value = 0.6967730796121322
# ANOVA results for coleman_liau_index between adhd and schizophrenia: F-statistic = 16.089618029375814, p-value = 6.113332349397374e-05
# ANOVA results for coleman_liau_index between adhd and socialanxiety: F-statistic = 146.64852139141206, p-value = 1.8462425582553172e-33
# ANOVA results for coleman_liau_index between anxiety and autism: F-statistic = 320.24533280581437, p-value = 1.947237605875654e-70
# ANOVA results for coleman_liau_index between anxiety and bpd: F-statistic = 8.127914610101167, p-value = 0.004367063721386415
# ANOVA results for coleman_liau_index between anxiety and depression: F-statistic = 708.6372183235541, p-value = 1.6796907183460946e-154
# ANOVA results for coleman_liau_index between anxiety and ed: F-statistic = 205.67503959457127, p-value = 3.1015513438834466e-46
# ANOVA results for coleman_liau_index between anxiety and healthanxiety: F-statistic = 4.721094920810531, p-value = 0.02981971694881784
# ANOVA results for coleman_liau_index between anxiety and ptsd: F-statistic = 47.07586981400428, p-value = 7.265607053874787e-12
# ANOVA results for coleman_liau_index between anxiety and schizophrenia: F-statistic = 161.47714186668688, p-value = 1.0619515461673457e-36
# ANOVA results for coleman_liau_index between anxiety and socialanxiety: F-statistic = 7.1343832408217285, p-value = 0.007572693799833287
# ANOVA results for coleman_liau_index between autism and bpd: F-statistic = 226.8681356681816, p-value = 1.7540404675222838e-49
# ANOVA results for coleman_liau_index between autism and depression: F-statistic = 591.6619417595298, p-value = 3.3617133254380007e-129
# ANOVA results for coleman_liau_index between autism and ed: F-statistic = 273.0273170363415, p-value = 5.7357972220236385e-59
# ANOVA results for coleman_liau_index between autism and healthanxiety: F-statistic = 71.41557075719545, p-value = 6.841470334695217e-17
# ANOVA results for coleman_liau_index between autism and ptsd: F-statistic = 24.86325553554412, p-value = 6.93236630402226e-07
# ANOVA results for coleman_liau_index between autism and schizophrenia: F-statistic = 16.845049265165414, p-value = 4.248160131825783e-05
# ANOVA results for coleman_liau_index between autism and socialanxiety: F-statistic = 263.25304536927234, p-value = 3.8508880661371046e-57
# ANOVA results for coleman_liau_index between bpd and depression: F-statistic = 148.71419319451644, p-value = 4.07644150051446e-34
# ANOVA results for coleman_liau_index between bpd and ed: F-statistic = 59.64080610552592, p-value = 1.3706505227911111e-14
# ANOVA results for coleman_liau_index between bpd and healthanxiety: F-statistic = 9.48109805942889, p-value = 0.0020940661800526845
# ANOVA results for coleman_liau_index between bpd and ptsd: F-statistic = 40.42429941785726, p-value = 2.3516517191944383e-10
# ANOVA results for coleman_liau_index between bpd and schizophrenia: F-statistic = 123.53124925339856, p-value = 3.310229358397644e-28
# ANOVA results for coleman_liau_index between bpd and socialanxiety: F-statistic = 0.11044748094187459, p-value = 0.7396487873305431
# ANOVA results for coleman_liau_index between depression and ed: F-statistic = 0.12354489386108303, p-value = 0.7252238519940797
# ANOVA results for coleman_liau_index between depression and healthanxiety: F-statistic = 116.49293316114968, p-value = 4.24627201027644e-27
# ANOVA results for coleman_liau_index between depression and ptsd: F-statistic = 211.48408665638752, p-value = 1.0168140098574271e-47
# ANOVA results for coleman_liau_index between depression and schizophrenia: F-statistic = 463.5690754997892, p-value = 6.476874063664049e-102
# ANOVA results for coleman_liau_index between depression and socialanxiety: F-statistic = 191.83396547983554, p-value = 1.773808185415636e-43
# ANOVA results for coleman_liau_index between ed and healthanxiety: F-statistic = 53.53586114693754, p-value = 3.1560980335563197e-13
# ANOVA results for coleman_liau_index between ed and ptsd: F-statistic = 92.06867909097402, p-value = 1.5974187122852024e-21
# ANOVA results for coleman_liau_index between ed and schizophrenia: F-statistic = 206.41602194813183, p-value = 1.473929444531472e-45
# ANOVA results for coleman_liau_index between ed and socialanxiety: F-statistic = 76.45433292260948, p-value = 2.9655720858640864e-18
# ANOVA results for coleman_liau_index between healthanxiety and ptsd: F-statistic = 6.138918409701681, p-value = 0.01333345454222489
# ANOVA results for coleman_liau_index between healthanxiety and schizophrenia: F-statistic = 28.27471653528801, p-value = 1.183110000283016e-07
# ANOVA results for coleman_liau_index between healthanxiety and socialanxiety: F-statistic = 9.833981253393876, p-value = 0.0017269156663398137
# ANOVA results for coleman_liau_index between ptsd and schizophrenia: F-statistic = 3.7925104791969586, p-value = 0.051644908239662723
# ANOVA results for coleman_liau_index between ptsd and socialanxiety: F-statistic = 45.53040311643143, p-value = 1.7496605452122398e-11
# ANOVA results for coleman_liau_index between schizophrenia and socialanxiety: F-statistic = 141.41550037076922, p-value = 4.734807234345209e-32
# ANOVA results for flesch_kincaid_grade_level between adhd and anxiety: F-statistic = 128.5428833108024, p-value = 1.1576605499236645e-29
# ANOVA results for flesch_kincaid_grade_level between adhd and autism: F-statistic = 4.138973933500317, p-value = 0.041952033527369315
# ANOVA results for flesch_kincaid_grade_level between adhd and bpd: F-statistic = 139.86846624523363, p-value = 5.497908384414835e-32
# ANOVA results for flesch_kincaid_grade_level between adhd and depression: F-statistic = 1066.3523690833185, p-value = 8.079916099365029e-230
# ANOVA results for flesch_kincaid_grade_level between adhd and ed: F-statistic = 833.1181275825323, p-value = 4.922999984449709e-174
# ANOVA results for flesch_kincaid_grade_level between adhd and healthanxiety: F-statistic = 81.04961718803142, p-value = 2.91968034067752e-19
# ANOVA results for flesch_kincaid_grade_level between adhd and ptsd: F-statistic = 7.992167828180611, p-value = 0.004714068929051205
# ANOVA results for flesch_kincaid_grade_level between adhd and schizophrenia: F-statistic = 9.365877730244913, p-value = 0.0022201891646141097
# ANOVA results for flesch_kincaid_grade_level between adhd and socialanxiety: F-statistic = 71.12834124170807, p-value = 3.939564492659083e-17
# ANOVA results for flesch_kincaid_grade_level between anxiety and autism: F-statistic = 54.01095849340846, p-value = 2.162556093387185e-13
# ANOVA results for flesch_kincaid_grade_level between anxiety and bpd: F-statistic = 22.686389733033756, p-value = 1.9317057470318525e-06
# ANOVA results for flesch_kincaid_grade_level between anxiety and depression: F-statistic = 649.3966077727218, p-value = 7.067185222792444e-142
# ANOVA results for flesch_kincaid_grade_level between anxiety and ed: F-statistic = 575.8541438117805, p-value = 4.00735886053991e-124
# ANOVA results for flesch_kincaid_grade_level between anxiety and healthanxiety: F-statistic = 19.46424826190447, p-value = 1.0364469189613144e-05
# ANOVA results for flesch_kincaid_grade_level between anxiety and ptsd: F-statistic = 4.399779134959915, p-value = 0.035970543031811304
# ANOVA results for flesch_kincaid_grade_level between anxiety and schizophrenia: F-statistic = 7.006233868103273, p-value = 0.00813589452503653
# ANOVA results for flesch_kincaid_grade_level between anxiety and socialanxiety: F-statistic = 0.0885914822743656, p-value = 0.7659809086775705
# ANOVA results for flesch_kincaid_grade_level between autism and bpd: F-statistic = 71.16643797485895, p-value = 5.0278983155086624e-17
# ANOVA results for flesch_kincaid_grade_level between autism and depression: F-statistic = 225.4038649472548, p-value = 9.933926837164329e-51
# ANOVA results for flesch_kincaid_grade_level between autism and ed: F-statistic = 305.2312950919033, p-value = 2.049778354447101e-65
# ANOVA results for flesch_kincaid_grade_level between autism and healthanxiety: F-statistic = 58.42350401273598, p-value = 3.784552542675139e-14
# ANOVA results for flesch_kincaid_grade_level between autism and ptsd: F-statistic = 11.27264946839041, p-value = 0.0008079098071515224
# ANOVA results for flesch_kincaid_grade_level between autism and schizophrenia: F-statistic = 11.417495916315085, p-value = 0.0007440088420473123
# ANOVA results for flesch_kincaid_grade_level between autism and socialanxiety: F-statistic = 41.5490994442323, p-value = 1.3063925932296581e-10
# ANOVA results for flesch_kincaid_grade_level between bpd and depression: F-statistic = 93.34354572220985, p-value = 4.774849475717882e-22
# ANOVA results for flesch_kincaid_grade_level between bpd and ed: F-statistic = 199.1983157310115, p-value = 2.277468684726836e-44
# ANOVA results for flesch_kincaid_grade_level between bpd and healthanxiety: F-statistic = 1.3563568222891709, p-value = 0.24425894425691824
# ANOVA results for flesch_kincaid_grade_level between bpd and ptsd: F-statistic = 17.64740956966701, p-value = 2.735533837237837e-05
# ANOVA results for flesch_kincaid_grade_level between bpd and schizophrenia: F-statistic = 23.101750371530763, p-value = 1.6042255768351966e-06
# ANOVA results for flesch_kincaid_grade_level between bpd and socialanxiety: F-statistic = 12.622710807737038, p-value = 0.00038450226440747584
# ANOVA results for flesch_kincaid_grade_level between depression and ed: F-statistic = 83.71155492808174, p-value = 6.115532968492872e-20
# ANOVA results for flesch_kincaid_grade_level between depression and healthanxiety: F-statistic = 20.372231779980382, p-value = 6.403496844859466e-06
# ANOVA results for flesch_kincaid_grade_level between depression and ptsd: F-statistic = 103.0553643453213, p-value = 3.627002102900681e-24
# ANOVA results for flesch_kincaid_grade_level between depression and schizophrenia: F-statistic = 150.73871931093655, p-value = 1.4960430378185526e-34
# ANOVA results for flesch_kincaid_grade_level between depression and socialanxiety: F-statistic = 239.24437977275338, p-value = 9.709397749309396e-54
# ANOVA results for flesch_kincaid_grade_level between ed and healthanxiety: F-statistic = 77.03262384790688, p-value = 2.6199378584157048e-18
# ANOVA results for flesch_kincaid_grade_level between ed and ptsd: F-statistic = 184.4795049166005, p-value = 6.33964061486395e-41
# ANOVA results for flesch_kincaid_grade_level between ed and schizophrenia: F-statistic = 233.51922737395404, p-value = 3.950051657418648e-51
# ANOVA results for flesch_kincaid_grade_level between ed and socialanxiety: F-statistic = 342.40230607650375, p-value = 3.570196428053831e-74
# ANOVA results for flesch_kincaid_grade_level between healthanxiety and ptsd: F-statistic = 19.269104282159933, p-value = 1.2148770109127516e-05
# ANOVA results for flesch_kincaid_grade_level between healthanxiety and schizophrenia: F-statistic = 21.463866953110042, p-value = 3.86273631670428e-06
# ANOVA results for flesch_kincaid_grade_level between healthanxiety and socialanxiety: F-statistic = 13.576299816897285, p-value = 0.00023241283149585433
# ANOVA results for flesch_kincaid_grade_level between ptsd and schizophrenia: F-statistic = 0.014871388569706774, p-value = 0.9029542064056862
# ANOVA results for flesch_kincaid_grade_level between ptsd and socialanxiety: F-statistic = 3.8824526020692436, p-value = 0.04887133032088726
# ANOVA results for flesch_kincaid_grade_level between schizophrenia and socialanxiety: F-statistic = 5.630043242335927, p-value = 0.017704158035563616
# ANOVA results for flesch_reading_ease between adhd and anxiety: F-statistic = 231.25069426501005, p-value = 8.423635020719274e-52
# ANOVA results for flesch_reading_ease between adhd and autism: F-statistic = 8.228874267894325, p-value = 0.004137818904615938
# ANOVA results for flesch_reading_ease between adhd and bpd: F-statistic = 193.0612520910394, p-value = 2.3704388876320418e-43
# ANOVA results for flesch_reading_ease between adhd and depression: F-statistic = 1822.5248317763019, p-value = 0.0
# ANOVA results for flesch_reading_ease between adhd and ed: F-statistic = 957.0695178436633, p-value = 3.5768401556633366e-198
# ANOVA results for flesch_reading_ease between adhd and healthanxiety: F-statistic = 107.95389258327955, p-value = 4.520532771358716e-25
# ANOVA results for flesch_reading_ease between adhd and ptsd: F-statistic = 9.271780813696951, p-value = 0.0023375357140784157
# ANOVA results for flesch_reading_ease between adhd and schizophrenia: F-statistic = 4.342168091202495, p-value = 0.03722089604942389
# ANOVA results for flesch_reading_ease between adhd and socialanxiety: F-statistic = 164.7762781647624, p-value = 2.4052845648281304e-37
# ANOVA results for flesch_reading_ease between anxiety and autism: F-statistic = 100.43507976346528, p-value = 1.6115419090397463e-23
# ANOVA results for flesch_reading_ease between anxiety and bpd: F-statistic = 17.7277825390266, p-value = 2.569214098007516e-05
# ANOVA results for flesch_reading_ease between anxiety and depression: F-statistic = 1039.8360673120565, p-value = 1.186877046133454e-224
# ANOVA results for flesch_reading_ease between anxiety and ed: F-statistic = 552.8119063837202, p-value = 2.3672038639080958e-119
# ANOVA results for flesch_reading_ease between anxiety and healthanxiety: F-statistic = 17.78544257475068, p-value = 2.495907181882901e-05
# ANOVA results for flesch_reading_ease between anxiety and ptsd: F-statistic = 12.712809200691312, p-value = 0.00036498488525231194
# ANOVA results for flesch_reading_ease between anxiety and schizophrenia: F-statistic = 33.089316810525794, p-value = 9.071445135016933e-09
# ANOVA results for flesch_reading_ease between anxiety and socialanxiety: F-statistic = 4.454619425370682, p-value = 0.03482867445492917
# ANOVA results for flesch_reading_ease between autism and bpd: F-statistic = 105.29843054546019, p-value = 2.630951850573405e-24
# ANOVA results for flesch_reading_ease between autism and depression: F-statistic = 401.15318320398103, p-value = 1.5099408095593673e-88
# ANOVA results for flesch_reading_ease between autism and ed: F-statistic = 365.2000261818721, p-value = 2.920233776275736e-77
# ANOVA results for flesch_reading_ease between autism and healthanxiety: F-statistic = 76.56658969792595, p-value = 5.7015828168377356e-18
# ANOVA results for flesch_reading_ease between autism and ptsd: F-statistic = 15.147039514618605, p-value = 0.00010418132943696814
# ANOVA results for flesch_reading_ease between autism and schizophrenia: F-statistic = 10.696895049826365, p-value = 0.0010946402311913437
# ANOVA results for flesch_reading_ease between autism and socialanxiety: F-statistic = 92.47477191731554, p-value = 1.2577502766336117e-21
# ANOVA results for flesch_reading_ease between bpd and depression: F-statistic = 195.94060402094917, p-value = 2.300108055092579e-44
# ANOVA results for flesch_reading_ease between bpd and ed: F-statistic = 198.87528446019923, p-value = 2.6619590502621445e-44
# ANOVA results for flesch_reading_ease between bpd and healthanxiety: F-statistic = 1.6726110072641422, p-value = 0.19600495262284878
# ANOVA results for flesch_reading_ease between bpd and ptsd: F-statistic = 25.567926525690087, p-value = 4.524978691703244e-07
# ANOVA results for flesch_reading_ease between bpd and schizophrenia: F-statistic = 47.386197609982965, p-value = 6.932713247307152e-12
# ANOVA results for flesch_reading_ease between bpd and socialanxiety: F-statistic = 3.2512410959834193, p-value = 0.07142783825193334
# ANOVA results for flesch_reading_ease between depression and ed: F-statistic = 27.9587645578306, p-value = 1.2488737640000134e-07
# ANOVA results for flesch_reading_ease between depression and healthanxiety: F-statistic = 47.46292611887528, p-value = 5.736605720159834e-12
# ANOVA results for flesch_reading_ease between depression and ptsd: F-statistic = 191.8828486060323, p-value = 1.7807374704530546e-43
# ANOVA results for flesch_reading_ease between depression and schizophrenia: F-statistic = 326.60898079263836, p-value = 1.4913565338113792e-72
# ANOVA results for flesch_reading_ease between depression and socialanxiety: F-statistic = 319.20833735864386, p-value = 5.459072884733616e-71
# ANOVA results for flesch_reading_ease between ed and healthanxiety: F-statistic = 70.7296166263858, p-value = 5.961736149319389e-17
# ANOVA results for flesch_reading_ease between ed and ptsd: F-statistic = 201.51173030804821, p-value = 1.9524212315403082e-44
# ANOVA results for flesch_reading_ease between ed and schizophrenia: F-statistic = 294.3371268269451, p-value = 1.756232458045643e-63
# ANOVA results for flesch_reading_ease between ed and socialanxiety: F-statistic = 283.88688637760765, p-value = 4.0027510701468e-62
# ANOVA results for flesch_reading_ease between healthanxiety and ptsd: F-statistic = 23.734253847425588, p-value = 1.2232978231205131e-06
# ANOVA results for flesch_reading_ease between healthanxiety and schizophrenia: F-statistic = 36.716006464079555, p-value = 1.6583315473216786e-09
# ANOVA results for flesch_reading_ease between healthanxiety and socialanxiety: F-statistic = 6.73003956825946, p-value = 0.009518492953723052
# ANOVA results for flesch_reading_ease between ptsd and schizophrenia: F-statistic = 0.7839400027834611, p-value = 0.3760626104109921
# ANOVA results for flesch_reading_ease between ptsd and socialanxiety: F-statistic = 16.935128317318117, p-value = 3.956369174824152e-05
# ANOVA results for flesch_reading_ease between schizophrenia and socialanxiety: F-statistic = 35.305142229122325, p-value = 3.069429443705333e-09
# ANOVA results for gulpease_index between adhd and anxiety: F-statistic = 27.13380914907458, p-value = 1.926019226898771e-07
# ANOVA results for gulpease_index between adhd and autism: F-statistic = 17.485209383412887, p-value = 2.9382477039998115e-05
# ANOVA results for gulpease_index between adhd and bpd: F-statistic = 60.1632258234764, p-value = 9.894041012613363e-15
# ANOVA results for gulpease_index between adhd and depression: F-statistic = 448.76442164940005, p-value = 7.253392623231685e-99
# ANOVA results for gulpease_index between adhd and ed: F-statistic = 451.9797879237893, p-value = 1.6351965860834502e-97
# ANOVA results for gulpease_index between adhd and healthanxiety: F-statistic = 10.135644967043378, p-value = 0.0014618473298107987
# ANOVA results for gulpease_index between adhd and ptsd: F-statistic = 0.42340793352562195, p-value = 0.5152671537118588
# ANOVA results for gulpease_index between adhd and schizophrenia: F-statistic = 1.7038776906748432, p-value = 0.19183066238335733
# ANOVA results for gulpease_index between adhd and socialanxiety: F-statistic = 17.298798502027562, p-value = 3.227550116886308e-05
# ANOVA results for gulpease_index between anxiety and autism: F-statistic = 52.17390429220517, p-value = 5.480473928142129e-13
# ANOVA results for gulpease_index between anxiety and bpd: F-statistic = 26.125862801247514, p-value = 3.252880518848062e-07
# ANOVA results for gulpease_index between anxiety and depression: F-statistic = 402.07704088787267, p-value = 6.563654778481131e-89
# ANOVA results for gulpease_index between anxiety and ed: F-statistic = 463.17784393708763, p-value = 1.067040464673285e-100
# ANOVA results for gulpease_index between anxiety and healthanxiety: F-statistic = 1.1139269825498463, p-value = 0.29125708590077715
# ANOVA results for gulpease_index between anxiety and ptsd: F-statistic = 2.8040446658071834, p-value = 0.09406050537677965
# ANOVA results for gulpease_index between anxiety and schizophrenia: F-statistic = 1.7437739448089522, p-value = 0.18669282602712878
# ANOVA results for gulpease_index between anxiety and socialanxiety: F-statistic = 0.2292359822130882, p-value = 0.6321000910970138
# ANOVA results for gulpease_index between autism and bpd: F-statistic = 70.10245210764661, p-value = 8.51598309678468e-17
# ANOVA results for gulpease_index between autism and depression: F-statistic = 157.61387676458529, p-value = 4.81815202403336e-36
# ANOVA results for gulpease_index between autism and ed: F-statistic = 202.89637174224526, p-value = 1.0329051839806243e-44
# ANOVA results for gulpease_index between autism and healthanxiety: F-statistic = 33.49659112213792, p-value = 8.704669418367762e-09
# ANOVA results for gulpease_index between autism and ptsd: F-statistic = 12.127824441740925, p-value = 0.0005122106493071248
# ANOVA results for gulpease_index between autism and schizophrenia: F-statistic = 16.579171543838253, p-value = 4.880551444108896e-05
# ANOVA results for gulpease_index between autism and socialanxiety: F-statistic = 44.263644267301615, p-value = 3.3169905480470596e-11
# ANOVA results for gulpease_index between bpd and depression: F-statistic = 41.02355868360221, p-value = 1.5289284227676409e-10
# ANOVA results for gulpease_index between bpd and ed: F-statistic = 127.1056360203955, p-value = 4.0036453114653155e-29
# ANOVA results for gulpease_index between bpd and healthanxiety: F-statistic = 3.4223935259425073, p-value = 0.06441222250307811
# ANOVA results for gulpease_index between bpd and ptsd: F-statistic = 14.724273063175035, p-value = 0.00012697496045764142
# ANOVA results for gulpease_index between bpd and schizophrenia: F-statistic = 14.680827726435732, p-value = 0.00012967618374192292
# ANOVA results for gulpease_index between bpd and socialanxiety: F-statistic = 13.88461329708807, p-value = 0.00019646646305016637
# ANOVA results for gulpease_index between depression and ed: F-statistic = 95.66815638442918, p-value = 1.4803633256731588e-22
# ANOVA results for gulpease_index between depression and healthanxiety: F-statistic = 33.82999046685691, p-value = 6.086729842830077e-09
# ANOVA results for gulpease_index between depression and ptsd: F-statistic = 60.69665397071748, p-value = 6.913640179121107e-15
# ANOVA results for gulpease_index between depression and schizophrenia: F-statistic = 76.12938161812095, p-value = 2.815601435540899e-18
# ANOVA results for gulpease_index between depression and socialanxiety: F-statistic = 140.95464534923303, p-value = 1.9776598631636484e-32
# ANOVA results for gulpease_index between ed and healthanxiety: F-statistic = 86.0796382959263, p-value = 2.999446146782773e-20
# ANOVA results for gulpease_index between ed and ptsd: F-statistic = 108.43686092432233, p-value = 5.252967501772097e-25
# ANOVA results for gulpease_index between ed and schizophrenia: F-statistic = 133.4838208894037, p-value = 2.4106853927734898e-30
# ANOVA results for gulpease_index between ed and socialanxiety: F-statistic = 248.41796269635532, p-value = 9.34743744064911e-55
# ANOVA results for gulpease_index between healthanxiety and ptsd: F-statistic = 3.335334732245137, p-value = 0.06800568965230609
# ANOVA results for gulpease_index between healthanxiety and schizophrenia: F-statistic = 2.3626733833813947, p-value = 0.12444374981777326
# ANOVA results for gulpease_index between healthanxiety and socialanxiety: F-statistic = 0.4802216042670367, p-value = 0.4883664354232604
# ANOVA results for gulpease_index between ptsd and schizophrenia: F-statistic = 0.1281326633537877, p-value = 0.7204199907557107
# ANOVA results for gulpease_index between ptsd and socialanxiety: F-statistic = 2.91430011006897, p-value = 0.08788551198520267
# ANOVA results for gulpease_index between schizophrenia and socialanxiety: F-statistic = 1.917833025219168, p-value = 0.1661761739190228
# ANOVA results for gunning_fog_index between adhd and anxiety: F-statistic = 48.265547999135116, p-value = 3.890462370098781e-12
# ANOVA results for gunning_fog_index between adhd and autism: F-statistic = 1.9858938545492812, p-value = 0.15882457043941195
# ANOVA results for gunning_fog_index between adhd and bpd: F-statistic = 72.9335226164777, p-value = 1.6094998286503012e-17
# ANOVA results for gunning_fog_index between adhd and depression: F-statistic = 870.2150388630783, p-value = 1.561965252436392e-188
# ANOVA results for gunning_fog_index between adhd and ed: F-statistic = 841.4543164487524, p-value = 1.1421404611669568e-175
# ANOVA results for gunning_fog_index between adhd and healthanxiety: F-statistic = 73.88943605892811, p-value = 1.0455488577893831e-17
# ANOVA results for gunning_fog_index between adhd and ptsd: F-statistic = 3.555157179747875, p-value = 0.059410518299783485
# ANOVA results for gunning_fog_index between adhd and schizophrenia: F-statistic = 8.190418764854797, p-value = 0.004225493624798399
# ANOVA results for gunning_fog_index between adhd and socialanxiety: F-statistic = 58.52025444520422, p-value = 2.2483929450872837e-14
# ANOVA results for gunning_fog_index between anxiety and autism: F-statistic = 21.38325637504543, p-value = 3.811324878136312e-06
# ANOVA results for gunning_fog_index between anxiety and bpd: F-statistic = 18.089307944679607, p-value = 2.1253904225120027e-05
# ANOVA results for gunning_fog_index between anxiety and depression: F-statistic = 732.1640758416717, p-value = 1.653009463974192e-159
# ANOVA results for gunning_fog_index between anxiety and ed: F-statistic = 721.3695934621799, p-value = 4.919732327967116e-154
# ANOVA results for gunning_fog_index between anxiety and healthanxiety: F-statistic = 34.65592928577965, p-value = 4.069467107475958e-09
# ANOVA results for gunning_fog_index between anxiety and ptsd: F-statistic = 1.299994755625605, p-value = 0.2542435819189103
# ANOVA results for gunning_fog_index between anxiety and schizophrenia: F-statistic = 0.3162673663450975, p-value = 0.5738726315912719
# ANOVA results for gunning_fog_index between anxiety and socialanxiety: F-statistic = 8.400110816262195, p-value = 0.003759127257118631
# ANOVA results for gunning_fog_index between autism and bpd: F-statistic = 36.06116464329601, p-value = 2.141283799108106e-09
# ANOVA results for gunning_fog_index between autism and depression: F-statistic = 172.73468363055952, p-value = 2.5192874143042622e-39
# ANOVA results for gunning_fog_index between autism and ed: F-statistic = 298.92103103340287, p-value = 3.716868249914311e-64
# ANOVA results for gunning_fog_index between autism and healthanxiety: F-statistic = 49.30244991667836, p-value = 3.335827775226926e-12
# ANOVA results for gunning_fog_index between autism and ptsd: F-statistic = 5.302043860232149, p-value = 0.02144807739750622
# ANOVA results for gunning_fog_index between autism and schizophrenia: F-statistic = 7.923890443205081, p-value = 0.004934893567499498
# ANOVA results for gunning_fog_index between autism and socialanxiety: F-statistic = 29.409616666103442, p-value = 6.254910203344658e-08
# ANOVA results for gunning_fog_index between bpd and depression: F-statistic = 121.16541167916854, p-value = 4.037796679122363e-28
# ANOVA results for gunning_fog_index between bpd and ed: F-statistic = 284.6997651571235, p-value = 3.88082544722019e-62
# ANOVA results for gunning_fog_index between bpd and healthanxiety: F-statistic = 7.335622546958293, p-value = 0.006797036318991615
# ANOVA results for gunning_fog_index between bpd and ptsd: F-statistic = 9.961395615001218, p-value = 0.0016142671598734697
# ANOVA results for gunning_fog_index between bpd and schizophrenia: F-statistic = 8.225682499764698, p-value = 0.00415604609095359
# ANOVA results for gunning_fog_index between bpd and socialanxiety: F-statistic = 1.5717495374453112, p-value = 0.21001003884462766
# ANOVA results for gunning_fog_index between depression and ed: F-statistic = 135.36369305417864, p-value = 3.2611694763939817e-31
# ANOVA results for gunning_fog_index between depression and healthanxiety: F-statistic = 12.55972916239564, p-value = 0.00039485838287327106
# ANOVA results for gunning_fog_index between depression and ptsd: F-statistic = 97.32259167369013, p-value = 6.480728359608436e-23
# ANOVA results for gunning_fog_index between depression and schizophrenia: F-statistic = 120.2416241465886, p-value = 6.463919396393659e-28
# ANOVA results for gunning_fog_index between depression and socialanxiety: F-statistic = 190.82419437728228, p-value = 2.9361568044781836e-43
# ANOVA results for gunning_fog_index between ed and healthanxiety: F-statistic = 86.82284742923599, p-value = 2.079215816621644e-20
# ANOVA results for gunning_fog_index between ed and ptsd: F-statistic = 216.23666616154253, p-value = 1.8608620734551506e-47
# ANOVA results for gunning_fog_index between ed and schizophrenia: F-statistic = 244.1986479892313, p-value = 2.586478983833819e-53
# ANOVA results for gunning_fog_index between ed and socialanxiety: F-statistic = 366.71785097455967, p-value = 3.832088762436089e-79
# ANOVA results for gunning_fog_index between healthanxiety and ptsd: F-statistic = 23.365339817274826, p-value = 1.4774334825265683e-06
# ANOVA results for gunning_fog_index between healthanxiety and schizophrenia: F-statistic = 19.79421222968509, p-value = 9.14880478991928e-06
# ANOVA results for gunning_fog_index between healthanxiety and socialanxiety: F-statistic = 13.609719603074863, p-value = 0.0002283271560999625
# ANOVA results for gunning_fog_index between ptsd and schizophrenia: F-statistic = 0.20750728625201786, p-value = 0.6487857215872107
# ANOVA results for gunning_fog_index between ptsd and socialanxiety: F-statistic = 5.919398788987882, p-value = 0.015024448145054591
# ANOVA results for gunning_fog_index between schizophrenia and socialanxiety: F-statistic = 4.26991125178061, p-value = 0.038859840477894446
# ANOVA results for lix between adhd and anxiety: F-statistic = 85.7065207176667, p-value = 2.392858888376908e-20
# ANOVA results for lix between adhd and autism: F-statistic = 21.866287747371988, p-value = 2.989593509120313e-06
# ANOVA results for lix between adhd and bpd: F-statistic = 132.1294579443685, p-value = 2.526233114092333e-30
# ANOVA results for lix between adhd and depression: F-statistic = 1191.185909771486, p-value = 5.906684617048512e-256
# ANOVA results for lix between adhd and ed: F-statistic = 783.5863185518506, p-value = 2.739172692278669e-164
# ANOVA results for lix between adhd and healthanxiety: F-statistic = 52.3291670434471, p-value = 5.290164262821031e-13
# ANOVA results for lix between adhd and ptsd: F-statistic = 4.477337082600859, p-value = 0.0343896058582103
# ANOVA results for lix between adhd and schizophrenia: F-statistic = 0.10818042044515992, p-value = 0.742236530220111
# ANOVA results for lix between adhd and socialanxiety: F-statistic = 126.94331303200869, p-value = 3.184548562609859e-29
# ANOVA results for lix between anxiety and autism: F-statistic = 82.86521287210135, p-value = 1.0607345957411153e-19
# ANOVA results for lix between anxiety and bpd: F-statistic = 32.566449654653766, p-value = 1.18187850034912e-08
# ANOVA results for lix between anxiety and depression: F-statistic = 907.7102934985115, p-value = 9.42576395091679e-197
# ANOVA results for lix between anxiety and ed: F-statistic = 565.4120291218395, p-value = 5.806489064677839e-122
# ANOVA results for lix between anxiety and healthanxiety: F-statistic = 10.517538728151989, p-value = 0.00118660518557664
# ANOVA results for lix between anxiety and ptsd: F-statistic = 3.819078279344197, p-value = 0.05070207102589011
# ANOVA results for lix between anxiety and schizophrenia: F-statistic = 27.072332108675667, p-value = 2.0002891867157335e-07
# ANOVA results for lix between anxiety and socialanxiety: F-statistic = 24.7118943538674, p-value = 6.753948869438207e-07
# ANOVA results for lix between autism and bpd: F-statistic = 109.43268603566038, p-value = 3.510704161599309e-25
# ANOVA results for lix between autism and depression: F-statistic = 341.51688730314515, p-value = 9.443761416896917e-76
# ANOVA results for lix between autism and ed: F-statistic = 370.0407769616651, p-value = 3.295843045023165e-78
# ANOVA results for lix between autism and healthanxiety: F-statistic = 68.47755371186327, p-value = 2.836170110588949e-16
# ANOVA results for lix between autism and ptsd: F-statistic = 21.84920305080229, p-value = 3.2367469657016743e-06
# ANOVA results for lix between autism and schizophrenia: F-statistic = 9.288276420032618, p-value = 0.00234180396486811
# ANOVA results for lix between autism and socialanxiety: F-statistic = 106.86914910281905, p-value = 1.0723831813022325e-24
# ANOVA results for lix between bpd and depression: F-statistic = 127.07243514566466, p-value = 2.085558028592786e-29
# ANOVA results for lix between bpd and ed: F-statistic = 178.28303774942432, p-value = 5.676062973199068e-40
# ANOVA results for lix between bpd and healthanxiety: F-statistic = 0.1147112563423344, p-value = 0.7348656945773033
# ANOVA results for lix between bpd and ptsd: F-statistic = 21.292749176769725, p-value = 4.105963057205148e-06
# ANOVA results for lix between bpd and schizophrenia: F-statistic = 53.92250090523586, p-value = 2.606918452048852e-13
# ANOVA results for lix between bpd and socialanxiety: F-statistic = 0.7954991676755954, p-value = 0.37248413807656633
# ANOVA results for lix between depression and ed: F-statistic = 44.45695627651615, p-value = 2.6500149884377e-11
# ANOVA results for lix between depression and healthanxiety: F-statistic = 51.56237604814341, p-value = 7.127160761509502e-13
# ANOVA results for lix between depression and ptsd: F-statistic = 135.4180092699105, p-value = 3.2142151405692337e-31
# ANOVA results for lix between depression and schizophrenia: F-statistic = 280.4102025889979, p-value = 1.319072591223909e-62
# ANOVA results for lix between depression and socialanxiety: F-statistic = 184.59862399831994, p-value = 6.569177087091707e-42
# ANOVA results for lix between ed and healthanxiety: F-statistic = 96.6362941573079, p-value = 1.6636639101994653e-22
# ANOVA results for lix between ed and ptsd: F-statistic = 186.36110551412057, p-value = 2.58950130190225e-41
# ANOVA results for lix between ed and schizophrenia: F-statistic = 297.4074108204763, p-value = 4.230500493469801e-64
# ANOVA results for lix between ed and socialanxiety: F-statistic = 227.78872747782282, p-value = 1.9025974053689372e-50
# ANOVA results for lix between healthanxiety and ptsd: F-statistic = 13.027778438085695, p-value = 0.00031701456408413884
# ANOVA results for lix between healthanxiety and schizophrenia: F-statistic = 28.604746510189447, p-value = 1.0003204969770822e-07
# ANOVA results for lix between healthanxiety and socialanxiety: F-statistic = 0.07675967182405706, p-value = 0.7817534265416626
# ANOVA results for lix between ptsd and schizophrenia: F-statistic = 2.9316892926283904, p-value = 0.08703681542652267
# ANOVA results for lix between ptsd and socialanxiety: F-statistic = 17.649259914956033, p-value = 2.721939828159254e-05
# ANOVA results for lix between schizophrenia and socialanxiety: F-statistic = 49.952759524305016, p-value = 1.8619567496530046e-12
# ANOVA results for smog_index between adhd and anxiety: F-statistic = 62.462983432418575, p-value = 2.921403552274783e-15
# ANOVA results for smog_index between adhd and autism: F-statistic = 1.329263371877457, p-value = 0.24898389356105632
# ANOVA results for smog_index between adhd and bpd: F-statistic = 82.66825366461644, p-value = 1.2258846780082242e-19
# ANOVA results for smog_index between adhd and depression: F-statistic = 1220.6332946846492, p-value = 4.186019862499563e-262
# ANOVA results for smog_index between adhd and ed: F-statistic = 1007.9248106824654, p-value = 5.631595473023218e-208
# ANOVA results for smog_index between adhd and healthanxiety: F-statistic = 90.12440851200347, p-value = 3.167563467798153e-21
# ANOVA results for smog_index between adhd and ptsd: F-statistic = 3.3757954173031726, p-value = 0.06621165909754317
# ANOVA results for smog_index between adhd and schizophrenia: F-statistic = 13.257714507892599, p-value = 0.00027370062307255073
# ANOVA results for smog_index between adhd and socialanxiety: F-statistic = 111.81817089810353, p-value = 5.826872836118901e-26
# ANOVA results for smog_index between anxiety and autism: F-statistic = 22.398692066951906, p-value = 2.2480531844992867e-06
# ANOVA results for smog_index between anxiety and bpd: F-statistic = 16.755049857824933, p-value = 4.283530648742866e-05
# ANOVA results for smog_index between anxiety and depression: F-statistic = 1069.6588070776945, p-value = 6.20033596036802e-231
# ANOVA results for smog_index between anxiety and ed: F-statistic = 847.5506849628806, p-value = 1.1399958038095015e-179
# ANOVA results for smog_index between anxiety and healthanxiety: F-statistic = 39.31998806337974, p-value = 3.7560824412726825e-10
# ANOVA results for smog_index between anxiety and ptsd: F-statistic = 2.669327593979222, p-value = 0.10233312793083352
# ANOVA results for smog_index between anxiety and schizophrenia: F-statistic = 0.05613831744531342, p-value = 0.8127120695792911
# ANOVA results for smog_index between anxiety and socialanxiety: F-statistic = 28.719159679930335, p-value = 8.530090618511169e-08
# ANOVA results for smog_index between autism and bpd: F-statistic = 35.6708360688414, p-value = 2.6100748538552235e-09
# ANOVA results for smog_index between autism and depression: F-statistic = 221.81341140208227, p-value = 5.934042386024249e-50
# ANOVA results for smog_index between autism and ed: F-statistic = 318.86793260148545, p-value = 3.98083424633847e-68
# ANOVA results for smog_index between autism and healthanxiety: F-statistic = 53.66616030045693, p-value = 3.894323773882052e-13
# ANOVA results for smog_index between autism and ptsd: F-statistic = 4.213789699554021, p-value = 0.040284202973713636
# ANOVA results for smog_index between autism and schizophrenia: F-statistic = 9.341407136326993, p-value = 0.0022752360384670537
# ANOVA results for smog_index between autism and socialanxiety: F-statistic = 43.84514460033546, p-value = 4.0968053307353745e-11
# ANOVA results for smog_index between bpd and depression: F-statistic = 207.186342830188, p-value = 8.434235448256851e-47
# ANOVA results for smog_index between bpd and ed: F-statistic = 337.0746790546613, p-value = 7.219021677524634e-73
# ANOVA results for smog_index between bpd and healthanxiety: F-statistic = 9.596202014152698, p-value = 0.001967154265451241
# ANOVA results for smog_index between bpd and ptsd: F-statistic = 12.088191647204695, p-value = 0.0005145631293237762
# ANOVA results for smog_index between bpd and schizophrenia: F-statistic = 6.243510677776078, p-value = 0.012512568291573585
# ANOVA results for smog_index between bpd and socialanxiety: F-statistic = 0.4820420047139012, p-value = 0.4875301489474313
# ANOVA results for smog_index between depression and ed: F-statistic = 108.66332254413965, p-value = 2.148116269638197e-25
# ANOVA results for smog_index between depression and healthanxiety: F-statistic = 26.977552745329145, p-value = 2.074236993831229e-07
# ANOVA results for smog_index between depression and ptsd: F-statistic = 146.15260994441897, p-value = 1.4885783054807804e-33
# ANOVA results for smog_index between depression and schizophrenia: F-statistic = 162.5486790159519, p-value = 4.0737412558133425e-37
# ANOVA results for smog_index between depression and socialanxiety: F-statistic = 217.94008023528679, p-value = 3.934950426978857e-49
# ANOVA results for smog_index between ed and healthanxiety: F-statistic = 99.37983919612725, p-value = 4.3281847939050975e-23
# ANOVA results for smog_index between ed and ptsd: F-statistic = 248.642497082269, p-value = 4.66777979533982e-54
# ANOVA results for smog_index between ed and schizophrenia: F-statistic = 261.8461520299495, p-value = 6.575721129311915e-57
# ANOVA results for smog_index between ed and socialanxiety: F-statistic = 349.53770189532224, p-value = 1.2364905373108e-75
# ANOVA results for smog_index between healthanxiety and ptsd: F-statistic = 29.849558349079693, p-value = 5.4604992765531e-08
# ANOVA results for smog_index between healthanxiety and schizophrenia: F-statistic = 20.21442292711154, p-value = 7.361611811734229e-06
# ANOVA results for smog_index between healthanxiety and socialanxiety: F-statistic = 7.298026641622667, p-value = 0.0069352267123533725
# ANOVA results for smog_index between ptsd and schizophrenia: F-statistic = 0.9771584689118686, p-value = 0.32304037821129317
# ANOVA results for smog_index between ptsd and socialanxiety: F-statistic = 16.37870832951266, p-value = 5.297720231059087e-05
# ANOVA results for smog_index between schizophrenia and socialanxiety: F-statistic = 9.716539942861946, p-value = 0.001839666511032967
# ANOVA results for wiener_sachtextformel between adhd and anxiety: F-statistic = 108.88961041386034, p-value = 2.136452123299742e-25
# ANOVA results for wiener_sachtextformel between adhd and autism: F-statistic = 13.73322951726827, p-value = 0.00021265934693181674
# ANOVA results for wiener_sachtextformel between adhd and bpd: F-statistic = 144.50622630224268, p-value = 5.5611805367466763e-33
# ANOVA results for wiener_sachtextformel between adhd and depression: F-statistic = 1669.3714208671845, p-value = 0.0
# ANOVA results for wiener_sachtextformel between adhd and ed: F-statistic = 1026.637058733879, p-value = 1.4394317978596775e-211
# ANOVA results for wiener_sachtextformel between adhd and healthanxiety: F-statistic = 87.12724040401879, p-value = 1.40930140340711e-20
# ANOVA results for wiener_sachtextformel between adhd and ptsd: F-statistic = 5.249129013369401, p-value = 0.021993378936703868
# ANOVA results for wiener_sachtextformel between adhd and schizophrenia: F-statistic = 0.32593938476091994, p-value = 0.5680809067071961
# ANOVA results for wiener_sachtextformel between adhd and socialanxiety: F-statistic = 171.0751637727181, p-value = 1.0810625595320825e-38
# ANOVA results for wiener_sachtextformel between anxiety and autism: F-statistic = 71.49134964724284, p-value = 3.206429865781928e-17
# ANOVA results for wiener_sachtextformel between anxiety and bpd: F-statistic = 27.495542384532538, p-value = 1.60402749505251e-07
# ANOVA results for wiener_sachtextformel between anxiety and depression: F-statistic = 1266.5134765880046, p-value = 2.9292663984714926e-272
# ANOVA results for wiener_sachtextformel between anxiety and ed: F-statistic = 699.7964624973819, p-value = 1.2662845015525504e-149
# ANOVA results for wiener_sachtextformel between anxiety and healthanxiety: F-statistic = 22.550164343549923, p-value = 2.077616293453737e-06
# ANOVA results for wiener_sachtextformel between anxiety and ptsd: F-statistic = 5.294481540764096, p-value = 0.021415138579542692
# ANOVA results for wiener_sachtextformel between anxiety and schizophrenia: F-statistic = 22.979981114048503, p-value = 1.6615507433308947e-06
# ANOVA results for wiener_sachtextformel between anxiety and socialanxiety: F-statistic = 33.84026852679898, p-value = 6.143466564028911e-09
# ANOVA results for wiener_sachtextformel between autism and bpd: F-statistic = 94.56514350769957, p-value = 4.988879449844269e-22
# ANOVA results for wiener_sachtextformel between autism and depression: F-statistic = 403.3633380408802, p-value = 5.074558383784777e-89
# ANOVA results for wiener_sachtextformel between autism and ed: F-statistic = 433.96582811330137, p-value = 1.3364356227925078e-90
# ANOVA results for wiener_sachtextformel between autism and healthanxiety: F-statistic = 77.6854368093015, p-value = 3.32804102942501e-18
# ANOVA results for wiener_sachtextformel between autism and ptsd: F-statistic = 16.25611038984196, p-value = 5.834514863707397e-05
# ANOVA results for wiener_sachtextformel between autism and schizophrenia: F-statistic = 8.117175106044122, p-value = 0.004437616574859345
# ANOVA results for wiener_sachtextformel between autism and socialanxiety: F-statistic = 106.08638743565011, p-value = 1.573385609872727e-24
# ANOVA results for wiener_sachtextformel between bpd and depression: F-statistic = 218.08806007364436, p-value = 3.684820781375141e-49
# ANOVA results for wiener_sachtextformel between bpd and ed: F-statistic = 253.77021430215123, p-value = 9.543409482572464e-56
# ANOVA results for wiener_sachtextformel between bpd and healthanxiety: F-statistic = 1.4448316175134848, p-value = 0.2294503294200858
# ANOVA results for wiener_sachtextformel between bpd and ptsd: F-statistic = 21.685210749791853, p-value = 3.3508855598430457e-06
# ANOVA results for wiener_sachtextformel between bpd and schizophrenia: F-statistic = 45.5113562721758, p-value = 1.7813238561394863e-11
# ANOVA results for wiener_sachtextformel between bpd and socialanxiety: F-statistic = 0.00886205775035966, p-value = 0.925002798054756
# ANOVA results for wiener_sachtextformel between depression and ed: F-statistic = 46.846134234426465, p-value = 7.841872493431264e-12
# ANOVA results for wiener_sachtextformel between depression and healthanxiety: F-statistic = 56.03437057310009, p-value = 7.353396036197559e-14
# ANOVA results for wiener_sachtextformel between depression and ptsd: F-statistic = 194.97658547761304, p-value = 3.8062875128615245e-44
# ANOVA results for wiener_sachtextformel between depression and schizophrenia: F-statistic = 352.38482090887226, p-value = 4.301701830177417e-78
# ANOVA results for wiener_sachtextformel between depression and socialanxiety: F-statistic = 257.15660122132795, p-value = 1.309664058291201e-57
# ANOVA results for wiener_sachtextformel between ed and healthanxiety: F-statistic = 103.87220625396724, p-value = 4.787694424985409e-24
# ANOVA results for wiener_sachtextformel between ed and ptsd: F-statistic = 249.99175539066673, p-value = 2.487013708531286e-54
# ANOVA results for wiener_sachtextformel between ed and schizophrenia: F-statistic = 355.7664116832424, p-value = 9.357835333647038e-76
# ANOVA results for wiener_sachtextformel between ed and socialanxiety: F-statistic = 285.3991833605219, p-value = 1.946663661513109e-62
# ANOVA results for wiener_sachtextformel between healthanxiety and ptsd: F-statistic = 23.22499829383614, p-value = 1.5874873240079039e-06
# ANOVA results for wiener_sachtextformel between healthanxiety and schizophrenia: F-statistic = 36.723032956023566, p-value = 1.652483673848322e-09
# ANOVA results for wiener_sachtextformel between healthanxiety and socialanxiety: F-statistic = 1.4328604134748695, p-value = 0.2313766096048465
# ANOVA results for wiener_sachtextformel between ptsd and schizophrenia: F-statistic = 1.5172496591590523, p-value = 0.2182045495577275
# ANOVA results for wiener_sachtextformel between ptsd and socialanxiety: F-statistic = 24.567554109928373, p-value = 7.512741177355232e-07
# ANOVA results for wiener_sachtextformel between schizophrenia and socialanxiety: F-statistic = 52.142481134640505, p-value = 6.192324576356802e-13
# adhd and anxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and autism: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, lix, wiener_sachtextformel : gunning_fog_index, smog_index
# adhd and bpd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and autism: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and bpd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, wiener_sachtextformel : gulpease_index, gunning_fog_index, lix, smog_index
# anxiety and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, lix, wiener_sachtextformel : gulpease_index, gunning_fog_index, smog_index
# autism and bpd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and socialanxiety: automated_readability_index, flesch_kincaid_grade_level, gulpease_index : coleman_liau_index, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel
# depression and ed: automated_readability_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : coleman_liau_index
# depression and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# depression and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# depression and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# depression and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# healthanxiety and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# healthanxiety and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# ptsd and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# schizophrenia and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# adhd and schizophrenia: coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, smog_index : automated_readability_index, gulpease_index, lix, wiener_sachtextformel
# anxiety and healthanxiety: coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : automated_readability_index, gulpease_index
# anxiety and socialanxiety: coleman_liau_index, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : automated_readability_index, flesch_kincaid_grade_level, gulpease_index
# bpd and healthanxiety: coleman_liau_index, gunning_fog_index, smog_index : automated_readability_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, lix, wiener_sachtextformel
# healthanxiety and socialanxiety: coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, smog_index : automated_readability_index, gulpease_index, lix, wiener_sachtextformel
# adhd and ptsd: flesch_kincaid_grade_level, flesch_reading_ease, lix, wiener_sachtextformel : automated_readability_index, coleman_liau_index, gulpease_index, gunning_fog_index, smog_index
# ptsd and schizophrenia: No significant parameters : automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel

# %%
def pretty_table(df):
    for pair in df.index:
        for parameter in df.columns:
            if pair in anova_significant_pairs and parameter in anova_significant_pairs[pair]:
                df.loc[pair, parameter] = 'Significant'
            else:
                df.loc[pair, parameter] = 'Insignificant'

    table = PrettyTable()

    table.field_names = ["Condition Pair"] + list(df.columns)
    for index, row in df.iterrows():
        table.add_row([index] + list(row))

    print(table)

def export_pdf_png(df, filename):
    fig, ax =plt.subplots(figsize=(12, 4))

    colormap = {"Significant": "red", "Insignificant": "white"}

    list1, list2 = zip(*df.index)

    new_row_labels = [f"{i} {j}" for i, j in zip(list1, list2)]

    table = ax.table(cellText=df.values, cellColours=[[colormap[i] for i in j] for j in df.values], cellLoc = 'center', loc='center', colLabels=df.columns, rowLabels=new_row_labels)

    ax.axis('off')

    pdf = matplotlib.backends.backend_pdf.PdfPages("results/" + filename + ".pdf")
    pdf.savefig(fig, bbox_inches='tight')
    pdf.close()

    plt.savefig("results/" + filename + ".png", bbox_inches='tight')

def export_ipywidgets(df):
    for pair in df.index:
        for parameter in df.columns:
            if pair in anova_significant_pairs and parameter in anova_significant_pairs[pair]:
                df.loc[pair, parameter] = 'Significant'
            else:
                df.loc[pair, parameter] = 'Insignificant'

    items = [widgets.Button(description='' if pair in df.index and parameter in readability_parameters else parameter if parameter in readability_parameters else pair[j], 
                            layout=widgets.Layout(width="100px"), 
                            style=widgets.ButtonStyle(button_color='red' if pair in df.index and parameter in readability_parameters and df.loc[pair, parameter] == 'Significant' else 'pink' if pair in df.index and parameter in readability_parameters and df.loc[pair, parameter] == 'Insignificant' else 'white')) 
            for i, pair in enumerate(itertools.chain([('', '')], df.index)) for j, parameter in enumerate(list(pair) + list(df.columns))]
    grid = widgets.GridBox(items, layout=widgets.Layout(grid_template_columns="repeat(11, 100px)"))
    return grid

# %%
anova_df = pd.DataFrame(index=pd.MultiIndex.from_tuples(itertools.combinations(datasets.keys(), 2)), columns=readability_parameters)

pretty_table(anova_df)
# Out:
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+
# |           Condition Pair           | automated_readability_index | coleman_liau_index | flesch_kincaid_grade_level | flesch_reading_ease | gulpease_index | gunning_fog_index |      lix      |   smog_index  | wiener_sachtextformel |
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+
# |        ('adhd', 'anxiety')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('adhd', 'autism')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |          ('adhd', 'bpd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('adhd', 'depression')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('adhd', 'ed')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('adhd', 'healthanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |          ('adhd', 'ptsd')          |        Insignificant        |   Insignificant    |        Significant         |     Significant     | Insignificant  |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |     ('adhd', 'schizophrenia')      |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |     ('adhd', 'socialanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('anxiety', 'autism')        |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('anxiety', 'bpd')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('anxiety', 'depression')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('anxiety', 'ed')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('anxiety', 'healthanxiety')    |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# |        ('anxiety', 'ptsd')         |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |   Insignificant   | Insignificant | Insignificant |      Significant      |
# |    ('anxiety', 'schizophrenia')    |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |    ('anxiety', 'socialanxiety')    |        Insignificant        |    Significant     |       Insignificant        |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('autism', 'bpd')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('autism', 'depression')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |          ('autism', 'ed')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'healthanxiety')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('autism', 'ptsd')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'schizophrenia')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'socialanxiety')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('bpd', 'depression')        |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('bpd', 'ed')            |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'healthanxiety')      |        Insignificant        |    Significant     |       Insignificant        |    Insignificant    | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |          ('bpd', 'ptsd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'schizophrenia')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'socialanxiety')      |         Significant         |   Insignificant    |        Significant         |    Insignificant    |  Significant   |   Insignificant   | Insignificant | Insignificant |     Insignificant     |
# |        ('depression', 'ed')        |         Significant         |   Insignificant    |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'healthanxiety')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('depression', 'ptsd')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'schizophrenia')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'socialanxiety')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'healthanxiety')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('ed', 'ptsd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'schizophrenia')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'socialanxiety')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('healthanxiety', 'ptsd')      |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('healthanxiety', 'schizophrenia') |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('healthanxiety', 'socialanxiety') |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |     ('ptsd', 'schizophrenia')      |        Insignificant        |   Insignificant    |       Insignificant        |    Insignificant    | Insignificant  |   Insignificant   | Insignificant | Insignificant |     Insignificant     |
# |     ('ptsd', 'socialanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('schizophrenia', 'socialanxiety') |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+

# %%
export_pdf_png(anova_df, "anova_results")

# %%
export_ipywidgets(anova_df)
# Out:
# GridBox(children=(Button(layout=Layout(width='100px'), style=ButtonStyle(button_color='white')), Button(layout…

# %% [markdown]
# ***T-Test***
#
# The t-test assesses if there's a significant difference between two group means. It measures the size of the difference relative to the variability in the data.
#
# * T-statistic: Shows the magnitude of the difference between group means. A higher value indicates a larger difference.
#
# * P-value: Indicates the probability of observing such a difference if there's no real distinction between groups. A smaller p-value suggests a significant difference between groups.
#
# * Interpretation: A small p-value (typically < 0.05) indicates a likely real difference between groups. A larger p-value suggests the observed difference might be due to chance.

# %%
t_test_significant_pairs = {} 
t_test_insignificant_pairs = {}

for parameter in readability_parameters:
    for pair in itertools.combinations(diseases, 2):
        disease_1 = pair[0]
        disease_2 = pair[1]

        group_1 = datasets[disease_1][parameter]
        group_2 = datasets[disease_2][parameter]

        t_stat, p_value = ttest_ind(group_1, group_2)
        if p_value < 0.05:
            if (disease_1, disease_2) not in t_test_significant_pairs:
                t_test_significant_pairs[(disease_1, disease_2)] = []
            t_test_significant_pairs[(disease_1, disease_2)].append(parameter)
        else:
            if (disease_1, disease_2) not in t_test_insignificant_pairs:
                t_test_insignificant_pairs[(disease_1, disease_2)] = []
            t_test_insignificant_pairs[(disease_1, disease_2)].append(parameter)
        print(f"T-test results for {parameter} between {disease_1} and {disease_2}: T-statistic = {t_stat}, p-value = {p_value}")

for pair, parameters in t_test_significant_pairs.items():
    if pair in t_test_insignificant_pairs:
        print(f"{pair[0]} and {pair[1]}: {', '.join(parameters)} : {', '.join(t_test_insignificant_pairs[pair])}")
    else:
        print(f"{pair[0]} and {pair[1]}: {', '.join(parameters)} : No insignificant parameters")
for pair, parameters in t_test_insignificant_pairs.items():
    if pair not in t_test_significant_pairs:
        print(f"{pair[0]} and {pair[1]}: No significant parameters : {', '.join(parameters)}")
# Out:
# T-test results for automated_readability_index between adhd and anxiety: T-statistic = 11.626088211929789, p-value = 4.2508434680488645e-31
# T-test results for automated_readability_index between adhd and autism: T-statistic = -6.948107420410898, p-value = 4.108654483850879e-12
# T-test results for automated_readability_index between adhd and bpd: T-statistic = 10.735357058673586, p-value = 1.0889349728203145e-26
# T-test results for automated_readability_index between adhd and depression: T-statistic = 29.19896262353126, p-value = 8.305541612711661e-185
# T-test results for automated_readability_index between adhd and ed: T-statistic = 21.693009600053553, p-value = 2.4739430633892194e-101
# T-test results for automated_readability_index between adhd and healthanxiety: T-statistic = 5.118798355898816, p-value = 3.1722471292037274e-07
# T-test results for automated_readability_index between adhd and ptsd: T-statistic = 0.47752517183160764, p-value = 0.6330061576483705
# T-test results for automated_readability_index between adhd and schizophrenia: T-statistic = -1.5770187168564118, p-value = 0.11484285261601562
# T-test results for automated_readability_index between adhd and socialanxiety: T-statistic = 8.548661424177903, p-value = 1.478701381939591e-17
# T-test results for automated_readability_index between anxiety and autism: T-statistic = -13.28453048722049, p-value = 6.587303060614176e-40
# T-test results for automated_readability_index between anxiety and bpd: T-statistic = 3.5474048178598356, p-value = 0.0003906792920759867
# T-test results for automated_readability_index between anxiety and depression: T-statistic = 21.45938669034364, p-value = 1.8355332593421507e-101
# T-test results for automated_readability_index between anxiety and ed: T-statistic = 16.89601402886187, p-value = 2.928980711427148e-63
# T-test results for automated_readability_index between anxiety and healthanxiety: T-statistic = 0.17442576448869795, p-value = 0.8615346323026114
# T-test results for automated_readability_index between anxiety and ptsd: T-statistic = -4.760676819612918, p-value = 1.9586122671919706e-06
# T-test results for automated_readability_index between anxiety and schizophrenia: T-statistic = -8.139665403786461, p-value = 4.456498274270049e-16
# T-test results for automated_readability_index between anxiety and socialanxiety: T-statistic = 0.27954749270628637, p-value = 0.779829763635816
# T-test results for automated_readability_index between autism and bpd: T-statistic = 12.418472122297038, p-value = 1.4397354788808215e-34
# T-test results for automated_readability_index between autism and depression: T-statistic = 18.81367409500128, p-value = 2.0114427963722714e-78
# T-test results for automated_readability_index between autism and ed: T-statistic = 16.75256541733138, p-value = 1.688191856393684e-60
# T-test results for automated_readability_index between autism and healthanxiety: T-statistic = 8.200226653445668, p-value = 5.158768868738593e-16
# T-test results for automated_readability_index between autism and ptsd: T-statistic = 4.665030866192743, p-value = 3.3839664365542364e-06
# T-test results for automated_readability_index between autism and schizophrenia: T-statistic = 4.071366252643113, p-value = 4.888581771150991e-05
# T-test results for automated_readability_index between autism and socialanxiety: T-statistic = 11.398976882019982, p-value = 1.3949402939404442e-29
# T-test results for automated_readability_index between bpd and depression: T-statistic = 8.659184425812139, p-value = 5.013241813567065e-18
# T-test results for automated_readability_index between bpd and ed: T-statistic = 9.396402370184115, p-value = 8.430768081849319e-21
# T-test results for automated_readability_index between bpd and healthanxiety: T-statistic = -1.7027613764618217, p-value = 0.08871236933229243
# T-test results for automated_readability_index between bpd and ptsd: T-statistic = -5.516998265305737, p-value = 3.739015300830184e-08
# T-test results for automated_readability_index between bpd and schizophrenia: T-statistic = -8.409486777859152, p-value = 6.017768602048488e-17
# T-test results for automated_readability_index between bpd and socialanxiety: T-statistic = -2.6057256275251293, p-value = 0.00919437970512752
# T-test results for automated_readability_index between depression and ed: T-statistic = 4.48533604699048, p-value = 7.309770404001496e-06
# T-test results for automated_readability_index between depression and healthanxiety: T-statistic = -7.058217454228748, p-value = 1.729974214327307e-12
# T-test results for automated_readability_index between depression and ptsd: T-statistic = -11.123943949494612, p-value = 1.1186561907037904e-28
# T-test results for automated_readability_index between depression and schizophrenia: T-statistic = -15.625603986698147, p-value = 8.740896566511093e-55
# T-test results for automated_readability_index between depression and socialanxiety: T-statistic = -12.933403610828996, p-value = 3.773339893102487e-38
# T-test results for automated_readability_index between ed and healthanxiety: T-statistic = -7.759760625916692, p-value = 1.118794747410119e-14
# T-test results for automated_readability_index between ed and ptsd: T-statistic = -10.667723199589497, p-value = 3.835616616153098e-26
# T-test results for automated_readability_index between ed and schizophrenia: T-statistic = -14.328204174616864, p-value = 2.5081606967416422e-45
# T-test results for automated_readability_index between ed and socialanxiety: T-statistic = -12.487590289740272, p-value = 2.6650567828410914e-35
# T-test results for automated_readability_index between healthanxiety and ptsd: T-statistic = -2.9783954948782307, p-value = 0.002944235193195223
# T-test results for automated_readability_index between healthanxiety and schizophrenia: T-statistic = -4.863828767500879, p-value = 1.2509772494922893e-06
# T-test results for automated_readability_index between healthanxiety and socialanxiety: T-statistic = -0.009544700348922148, p-value = 0.9923850728175063
# T-test results for automated_readability_index between ptsd and schizophrenia: T-statistic = -1.3015742099977092, p-value = 0.19323628147523522
# T-test results for automated_readability_index between ptsd and socialanxiety: T-statistic = 4.154800262818479, p-value = 3.332955614820273e-05
# T-test results for automated_readability_index between schizophrenia and socialanxiety: T-statistic = 6.935051547978818, p-value = 4.74380081171664e-12
# T-test results for coleman_liau_index between adhd and anxiety: T-statistic = 14.082742004004501, p-value = 9.945957210487382e-45
# T-test results for coleman_liau_index between adhd and autism: T-statistic = -9.266044401043073, p-value = 2.66683839443555e-20
# T-test results for coleman_liau_index between adhd and bpd: T-statistic = 11.376109274968353, p-value = 9.68051865582185e-30
# T-test results for coleman_liau_index between adhd and depression: T-statistic = 35.510918397498415, p-value = 1.5718244840384156e-270
# T-test results for coleman_liau_index between adhd and ed: T-statistic = 19.737102840769392, p-value = 1.2506135128416353e-84
# T-test results for coleman_liau_index between adhd and healthanxiety: T-statistic = 3.9173122594311933, p-value = 9.055261218377197e-05
# T-test results for coleman_liau_index between adhd and ptsd: T-statistic = -0.3896994536042243, p-value = 0.6967730796127796
# T-test results for coleman_liau_index between adhd and schizophrenia: T-statistic = -4.011186611138388, p-value = 6.113332349388087e-05
# T-test results for coleman_liau_index between adhd and socialanxiety: T-statistic = 12.109852244821653, p-value = 1.8462425582479162e-33
# T-test results for coleman_liau_index between anxiety and autism: T-statistic = -17.895399766582877, p-value = 1.9472376058893802e-70
# T-test results for coleman_liau_index between anxiety and bpd: T-statistic = 2.8509497733388947, p-value = 0.004367063721413571
# T-test results for coleman_liau_index between anxiety and depression: T-statistic = 26.62024076381642, p-value = 1.679690718415794e-154
# T-test results for coleman_liau_index between anxiety and ed: T-statistic = 14.341375094270825, p-value = 3.1015513438829037e-46
# T-test results for coleman_liau_index between anxiety and healthanxiety: T-statistic = -2.1728080727046764, p-value = 0.029819716949083568
# T-test results for coleman_liau_index between anxiety and ptsd: T-statistic = -6.861185744024448, p-value = 7.265607053849513e-12
# T-test results for coleman_liau_index between anxiety and schizophrenia: T-statistic = -12.707365654087678, p-value = 1.0619515461655342e-36
# T-test results for coleman_liau_index between anxiety and socialanxiety: T-statistic = 2.6710266267526612, p-value = 0.007572693799887052
# T-test results for coleman_liau_index between autism and bpd: T-statistic = 15.062142466069742, p-value = 1.7540404675180207e-49
# T-test results for coleman_liau_index between autism and depression: T-statistic = 24.324102075092714, p-value = 3.361713325460609e-129
# T-test results for coleman_liau_index between autism and ed: T-statistic = 16.52353827230541, p-value = 5.735797222029604e-59
# T-test results for coleman_liau_index between autism and healthanxiety: T-statistic = 8.450773382193804, p-value = 6.841470334700208e-17
# T-test results for coleman_liau_index between autism and ptsd: T-statistic = 4.986306803190525, p-value = 6.932366304023767e-07
# T-test results for coleman_liau_index between autism and schizophrenia: T-statistic = 4.10427207494403, p-value = 4.248160131827855e-05
# T-test results for coleman_liau_index between autism and socialanxiety: T-statistic = 16.225074587479476, p-value = 3.8508880661427253e-57
# T-test results for coleman_liau_index between bpd and depression: T-statistic = 12.19484289339213, p-value = 4.076441500566692e-34
# T-test results for coleman_liau_index between bpd and ed: T-statistic = 7.722746021042394, p-value = 1.3706505227908277e-14
# T-test results for coleman_liau_index between bpd and healthanxiety: T-statistic = -3.0791391750664574, p-value = 0.0020940661800568448
# T-test results for coleman_liau_index between bpd and ptsd: T-statistic = -6.358010649397909, p-value = 2.351651719196451e-10
# T-test results for coleman_liau_index between bpd and schizophrenia: T-statistic = -11.114461266899024, p-value = 3.310229358395132e-28
# T-test results for coleman_liau_index between bpd and socialanxiety: T-statistic = -0.33233639725716263, p-value = 0.7396487873306405
# T-test results for coleman_liau_index between depression and ed: T-statistic = -0.3514895359197344, p-value = 0.7252238519879143
# T-test results for coleman_liau_index between depression and healthanxiety: T-statistic = -10.793189202508682, p-value = 4.246272010321217e-27
# T-test results for coleman_liau_index between depression and ptsd: T-statistic = -14.542492449934006, p-value = 1.0168140098544753e-47
# T-test results for coleman_liau_index between depression and schizophrenia: T-statistic = -21.530654321218144, p-value = 6.47687406358392e-102
# T-test results for coleman_liau_index between depression and socialanxiety: T-statistic = -13.850413910054653, p-value = 1.7738081854480297e-43
# T-test results for coleman_liau_index between ed and healthanxiety: T-statistic = -7.316820426041476, p-value = 3.1560980335591495e-13
# T-test results for coleman_liau_index between ed and ptsd: T-statistic = -9.595242523822632, p-value = 1.5974187122862293e-21
# T-test results for coleman_liau_index between ed and schizophrenia: T-statistic = -14.367185595938132, p-value = 1.473929444532823e-45
# T-test results for coleman_liau_index between ed and socialanxiety: T-statistic = -8.743816839493475, p-value = 2.965572085855405e-18
# T-test results for coleman_liau_index between healthanxiety and ptsd: T-statistic = -2.4776840819002026, p-value = 0.0133334545422362
# T-test results for coleman_liau_index between healthanxiety and schizophrenia: T-statistic = -5.317397534065699, p-value = 1.18311000028241e-07
# T-test results for coleman_liau_index between healthanxiety and socialanxiety: T-statistic = 3.135917928357493, p-value = 0.0017269156663428315
# T-test results for coleman_liau_index between ptsd and schizophrenia: T-statistic = -1.9474368999269196, p-value = 0.05164490823968287
# T-test results for coleman_liau_index between ptsd and socialanxiety: T-statistic = 6.747622034200747, p-value = 1.7496605452151837e-11
# T-test results for coleman_liau_index between schizophrenia and socialanxiety: T-statistic = 11.891824938619363, p-value = 4.734807234341383e-32
# T-test results for flesch_kincaid_grade_level between adhd and anxiety: T-statistic = 11.33767539272501, p-value = 1.1576605499241855e-29
# T-test results for flesch_kincaid_grade_level between adhd and autism: T-statistic = -2.034446837226357, p-value = 0.041952033527396106
# T-test results for flesch_kincaid_grade_level between adhd and bpd: T-statistic = 11.82659994441487, p-value = 5.497908384397835e-32
# T-test results for flesch_kincaid_grade_level between adhd and depression: T-statistic = 32.655051203195484, p-value = 8.079916099485094e-230
# T-test results for flesch_kincaid_grade_level between adhd and ed: T-statistic = 28.86378574585345, p-value = 4.922999984465996e-174
# T-test results for flesch_kincaid_grade_level between adhd and healthanxiety: T-statistic = 9.002756088444889, p-value = 2.9196803406603306e-19
# T-test results for flesch_kincaid_grade_level between adhd and ptsd: T-statistic = 2.827042240254043, p-value = 0.004714068929040112
# T-test results for flesch_kincaid_grade_level between adhd and schizophrenia: T-statistic = 3.060372155513928, p-value = 0.0022201891646108107
# T-test results for flesch_kincaid_grade_level between adhd and socialanxiety: T-statistic = 8.433761986308852, p-value = 3.9395644926423305e-17
# T-test results for flesch_kincaid_grade_level between anxiety and autism: T-statistic = -7.349214821558045, p-value = 2.162556093402589e-13
# T-test results for flesch_kincaid_grade_level between anxiety and bpd: T-statistic = 4.763023171582714, p-value = 1.9317057470452674e-06
# T-test results for flesch_kincaid_grade_level between anxiety and depression: T-statistic = 25.48326132528413, p-value = 7.067185223111677e-142
# T-test results for flesch_kincaid_grade_level between anxiety and ed: T-statistic = 23.99696113702277, p-value = 4.007358860540791e-124
# T-test results for flesch_kincaid_grade_level between anxiety and healthanxiety: T-statistic = 4.41183048879992, p-value = 1.0364469189697546e-05
# T-test results for flesch_kincaid_grade_level between anxiety and ptsd: T-statistic = -2.097565049041367, p-value = 0.035970543031678744
# T-test results for flesch_kincaid_grade_level between anxiety and schizophrenia: T-statistic = -2.646929139229686, p-value = 0.008135894525031105
# T-test results for flesch_kincaid_grade_level between anxiety and socialanxiety: T-statistic = 0.29764321304940666, p-value = 0.7659809086756321
# T-test results for flesch_kincaid_grade_level between autism and bpd: T-statistic = 8.43602026875582, p-value = 5.0278983154958563e-17
# T-test results for flesch_kincaid_grade_level between autism and depression: T-statistic = 15.013456129327947, p-value = 9.933926837233005e-51
# T-test results for flesch_kincaid_grade_level between autism and ed: T-statistic = 17.47086990083503, p-value = 2.049778354448814e-65
# T-test results for flesch_kincaid_grade_level between autism and healthanxiety: T-statistic = 7.643526935436028, p-value = 3.784552542677751e-14
# T-test results for flesch_kincaid_grade_level between autism and ptsd: T-statistic = 3.3574766519501544, p-value = 0.0008079098071517218
# T-test results for flesch_kincaid_grade_level between autism and schizophrenia: T-statistic = 3.3789785314966316, p-value = 0.0007440088420476337
# T-test results for flesch_kincaid_grade_level between autism and socialanxiety: T-statistic = 6.445859092799997, p-value = 1.3063925932315136e-10
# T-test results for flesch_kincaid_grade_level between bpd and depression: T-statistic = 9.661446357673869, p-value = 4.77484947579232e-22
# T-test results for flesch_kincaid_grade_level between bpd and ed: T-statistic = 14.113763344020311, p-value = 2.2774686847258344e-44
# T-test results for flesch_kincaid_grade_level between bpd and healthanxiety: T-statistic = 1.1646273319346294, p-value = 0.2442589442573217
# T-test results for flesch_kincaid_grade_level between bpd and ptsd: T-statistic = -4.200881999017236, p-value = 2.7355338372407664e-05
# T-test results for flesch_kincaid_grade_level between bpd and schizophrenia: T-statistic = -4.8064280262509635, p-value = 1.6042255768339127e-06
# T-test results for flesch_kincaid_grade_level between bpd and socialanxiety: T-statistic = -3.5528454522730124, p-value = 0.0003845022644071307
# T-test results for flesch_kincaid_grade_level between depression and ed: T-statistic = 9.149401889089905, p-value = 6.11553296860186e-20
# T-test results for flesch_kincaid_grade_level between depression and healthanxiety: T-statistic = -4.513560875847398, p-value = 6.403496844928102e-06
# T-test results for flesch_kincaid_grade_level between depression and ptsd: T-statistic = -10.151618804177062, p-value = 3.627002102890021e-24
# T-test results for flesch_kincaid_grade_level between depression and schizophrenia: T-statistic = -12.277569764042735, p-value = 1.4960430378014227e-34
# T-test results for flesch_kincaid_grade_level between depression and socialanxiety: T-statistic = -15.467526621045556, p-value = 9.709397749478975e-54
# T-test results for flesch_kincaid_grade_level between ed and healthanxiety: T-statistic = -8.776823106791365, p-value = 2.61993785841849e-18
# T-test results for flesch_kincaid_grade_level between ed and ptsd: T-statistic = -13.582323251807866, p-value = 6.339640614867307e-41
# T-test results for flesch_kincaid_grade_level between ed and schizophrenia: T-statistic = -15.281335915879668, p-value = 3.950051657423164e-51
# T-test results for flesch_kincaid_grade_level between ed and socialanxiety: T-statistic = -18.50411592258608, p-value = 3.570196428043233e-74
# T-test results for flesch_kincaid_grade_level between healthanxiety and ptsd: T-statistic = -4.389658788808075, p-value = 1.2148770109137514e-05
# T-test results for flesch_kincaid_grade_level between healthanxiety and schizophrenia: T-statistic = -4.632911282672055, p-value = 3.862736316702464e-06
# T-test results for flesch_kincaid_grade_level between healthanxiety and socialanxiety: T-statistic = -3.6846030745383254, p-value = 0.00023241283149620366
# T-test results for flesch_kincaid_grade_level between ptsd and schizophrenia: T-statistic = -0.12194830285701072, p-value = 0.9029542064052194
# T-test results for flesch_kincaid_grade_level between ptsd and socialanxiety: T-statistic = 1.970394022034494, p-value = 0.04887133032097427
# T-test results for flesch_kincaid_grade_level between schizophrenia and socialanxiety: T-statistic = 2.372771215759311, p-value = 0.017704158035552642
# T-test results for flesch_reading_ease between adhd and anxiety: T-statistic = -15.20692915302134, p-value = 8.423635020730203e-52
# T-test results for flesch_reading_ease between adhd and autism: T-statistic = 2.8686014480743425, p-value = 0.004137818904617803
# T-test results for flesch_reading_ease between adhd and bpd: T-statistic = -13.8946483255619, p-value = 2.370438887624419e-43
# T-test results for flesch_reading_ease between adhd and depression: T-statistic = -42.69103924451026, p-value = 0.0
# T-test results for flesch_reading_ease between adhd and ed: T-statistic = -30.936540172483145, p-value = 3.576840155674037e-198
# T-test results for flesch_reading_ease between adhd and healthanxiety: T-statistic = -10.390086264477285, p-value = 4.520532771333388e-25
# T-test results for flesch_reading_ease between adhd and ptsd: T-statistic = -3.0449599034629573, p-value = 0.00233753571407264
# T-test results for flesch_reading_ease between adhd and schizophrenia: T-statistic = -2.0837869591689375, p-value = 0.03722089604936849
# T-test results for flesch_reading_ease between adhd and socialanxiety: T-statistic = -12.836521264141734, p-value = 2.4052845648182817e-37
# T-test results for flesch_reading_ease between anxiety and autism: T-statistic = 10.021730377707483, p-value = 1.6115419090515918e-23
# T-test results for flesch_reading_ease between anxiety and bpd: T-statistic = -4.210437333463923, p-value = 2.569214098024758e-05
# T-test results for flesch_reading_ease between anxiety and depression: T-statistic = -32.24648922459727, p-value = 1.1868770461773351e-224
# T-test results for flesch_reading_ease between anxiety and ed: T-statistic = -23.51195241539333, p-value = 2.3672038639083058e-119
# T-test results for flesch_reading_ease between anxiety and healthanxiety: T-statistic = -4.217279048717388, p-value = 2.4959071819041246e-05
# T-test results for flesch_reading_ease between anxiety and ptsd: T-statistic = 3.5655026575072277, p-value = 0.00036498488525131247
# T-test results for flesch_reading_ease between anxiety and schizophrenia: T-statistic = 5.752331423912026, p-value = 9.071445135002e-09
# T-test results for flesch_reading_ease between anxiety and socialanxiety: T-statistic = -2.1105969357910883, p-value = 0.03482867445517551
# T-test results for flesch_reading_ease between autism and bpd: T-statistic = -10.26150235323562, p-value = 2.630951850566637e-24
# T-test results for flesch_reading_ease between autism and depression: T-statistic = -20.028808831380427, p-value = 1.5099408095687358e-88
# T-test results for flesch_reading_ease between autism and ed: T-statistic = -19.110207381969236, p-value = 2.9202337762796873e-77
# T-test results for flesch_reading_ease between autism and healthanxiety: T-statistic = -8.750233693903594, p-value = 5.7015828168424526e-18
# T-test results for flesch_reading_ease between autism and ptsd: T-statistic = -3.891919772376952, p-value = 0.00010418132943698421
# T-test results for flesch_reading_ease between autism and schizophrenia: T-statistic = -3.270610806841179, p-value = 0.001094640231191809
# T-test results for flesch_reading_ease between autism and socialanxiety: T-statistic = -9.616380395830614, p-value = 1.2577502766353204e-21
# T-test results for flesch_reading_ease between bpd and depression: T-statistic = -13.997878554300696, p-value = 2.300108055125037e-44
# T-test results for flesch_reading_ease between bpd and ed: T-statistic = -14.10231486175935, p-value = 2.6619590502619807e-44
# T-test results for flesch_reading_ease between bpd and healthanxiety: T-statistic = -1.2932946328134585, p-value = 0.19600495262329248
# T-test results for flesch_reading_ease between bpd and ptsd: T-statistic = 5.056473724414075, p-value = 4.5249786917079547e-07
# T-test results for flesch_reading_ease between bpd and schizophrenia: T-statistic = 6.883763331927027, p-value = 6.932713247300961e-12
# T-test results for flesch_reading_ease between bpd and socialanxiety: T-statistic = 1.803119822968916, p-value = 0.07142783825185987
# T-test results for flesch_reading_ease between depression and ed: T-statistic = -5.287604803484228, p-value = 1.2488737640229087e-07
# T-test results for flesch_reading_ease between depression and healthanxiety: T-statistic = 6.889334229000374, p-value = 5.736605720218164e-12
# T-test results for flesch_reading_ease between depression and ptsd: T-statistic = 13.85217847870988, p-value = 1.7807374704501393e-43
# T-test results for flesch_reading_ease between depression and schizophrenia: T-statistic = 18.072326380204647, p-value = 1.4913565337931928e-72
# T-test results for flesch_reading_ease between depression and socialanxiety: T-statistic = 17.866402473879496, p-value = 5.459072884817678e-71
# T-test results for flesch_reading_ease between ed and healthanxiety: T-statistic = 8.410090167553845, p-value = 5.961736149325623e-17
# T-test results for flesch_reading_ease between ed and ptsd: T-statistic = 14.195482743043558, p-value = 1.9524212315423396e-44
# T-test results for flesch_reading_ease between ed and schizophrenia: T-statistic = 17.15625620078416, p-value = 1.756232458047817e-63
# T-test results for flesch_reading_ease between ed and socialanxiety: T-statistic = 16.848943182811418, p-value = 4.002751070135115e-62
# T-test results for flesch_reading_ease between healthanxiety and ptsd: T-statistic = 4.871781383377683, p-value = 1.2232978231216505e-06
# T-test results for flesch_reading_ease between healthanxiety and schizophrenia: T-statistic = 6.059373438242562, p-value = 1.6583315473209306e-09
# T-test results for flesch_reading_ease between healthanxiety and socialanxiety: T-statistic = 2.5942319804249205, p-value = 0.009518492953736026
# T-test results for flesch_reading_ease between ptsd and schizophrenia: T-statistic = 0.885403864224396, p-value = 0.37606261041081945
# T-test results for flesch_reading_ease between ptsd and socialanxiety: T-statistic = -4.115231259275468, p-value = 3.9563691748313545e-05
# T-test results for flesch_reading_ease between schizophrenia and socialanxiety: T-statistic = -5.941813042255905, p-value = 3.06942944370317e-09
# T-test results for gulpease_index between adhd and anxiety: T-statistic = -5.20901230072211, p-value = 1.9260192268992822e-07
# T-test results for gulpease_index between adhd and autism: T-statistic = 4.1815319421729855, p-value = 2.938247704000106e-05
# T-test results for gulpease_index between adhd and bpd: T-statistic = -7.756495718007981, p-value = 9.89404101258953e-15
# T-test results for gulpease_index between adhd and depression: T-statistic = -21.184060556215393, p-value = 7.253392623342953e-99
# T-test results for gulpease_index between adhd and ed: T-statistic = -21.259816272108008, p-value = 1.6351965860894865e-97
# T-test results for gulpease_index between adhd and healthanxiety: T-statistic = -3.1836527711174054, p-value = 0.0014618473298020033
# T-test results for gulpease_index between adhd and ptsd: T-statistic = -0.650698035593805, p-value = 0.5152671537129019
# T-test results for gulpease_index between adhd and schizophrenia: T-statistic = -1.3053266605240448, p-value = 0.19183066238308194
# T-test results for gulpease_index between adhd and socialanxiety: T-statistic = -4.159182431924264, p-value = 3.227550116874413e-05
# T-test results for gulpease_index between anxiety and autism: T-statistic = 7.223150579366677, p-value = 5.480473928180787e-13
# T-test results for gulpease_index between anxiety and bpd: T-statistic = -5.1113464763453065, p-value = 3.2528805188708135e-07
# T-test results for gulpease_index between anxiety and depression: T-statistic = -20.051858788847365, p-value = 6.563654778771351e-89
# T-test results for gulpease_index between anxiety and ed: T-statistic = -21.52156694892561, p-value = 1.0670404646737796e-100
# T-test results for gulpease_index between anxiety and healthanxiety: T-statistic = -1.0554273933103782, p-value = 0.29125708590284904
# T-test results for gulpease_index between anxiety and ptsd: T-statistic = 1.6745281920012847, p-value = 0.09406050537645663
# T-test results for gulpease_index between anxiety and schizophrenia: T-statistic = 1.3205203310850213, p-value = 0.18669282602687248
# T-test results for gulpease_index between anxiety and socialanxiety: T-statistic = -0.4787859461315646, p-value = 0.63210009109472
# T-test results for gulpease_index between autism and bpd: T-statistic = -8.372720711193384, p-value = 8.515983096762537e-17
# T-test results for gulpease_index between autism and depression: T-statistic = -12.554436537120486, p-value = 4.8181520240704375e-36
# T-test results for gulpease_index between autism and ed: T-statistic = -14.244169745627337, p-value = 1.0329051839818392e-44
# T-test results for gulpease_index between autism and healthanxiety: T-statistic = -5.787623961708143, p-value = 8.704669418372083e-09
# T-test results for gulpease_index between autism and ptsd: T-statistic = -3.4825026118785667, p-value = 0.0005122106493071826
# T-test results for gulpease_index between autism and schizophrenia: T-statistic = -4.071752883444469, p-value = 4.880551444110761e-05
# T-test results for gulpease_index between autism and socialanxiety: T-statistic = -6.653092834712415, p-value = 3.316990548051236e-11
# T-test results for gulpease_index between bpd and depression: T-statistic = -6.404963597367484, p-value = 1.5289284227891706e-10
# T-test results for gulpease_index between bpd and ed: T-statistic = -11.274113535901407, p-value = 4.0036453114639456e-29
# T-test results for gulpease_index between bpd and healthanxiety: T-statistic = 1.849971223003856, p-value = 0.06441222250319033
# T-test results for gulpease_index between bpd and ptsd: T-statistic = 3.8372220502825845, p-value = 0.00012697496045776667
# T-test results for gulpease_index between bpd and schizophrenia: T-statistic = 3.831556828031606, p-value = 0.0001296761837418387
# T-test results for gulpease_index between bpd and socialanxiety: T-statistic = 3.726206287511207, p-value = 0.0001964664630499805
# T-test results for gulpease_index between depression and ed: T-statistic = -9.781009987952592, p-value = 1.4803633256988366e-22
# T-test results for gulpease_index between depression and healthanxiety: T-statistic = 5.81635542817465, p-value = 6.086729842894767e-09
# T-test results for gulpease_index between depression and ptsd: T-statistic = 7.790805733088035, p-value = 6.913640179102215e-15
# T-test results for gulpease_index between depression and schizophrenia: T-statistic = 8.725215276319608, p-value = 2.8156014355077077e-18
# T-test results for gulpease_index between depression and socialanxiety: T-statistic = 11.872432158123026, p-value = 1.9776598631980257e-32
# T-test results for gulpease_index between ed and healthanxiety: T-statistic = 9.277911311061649, p-value = 2.9994461467864446e-20
# T-test results for gulpease_index between ed and ptsd: T-statistic = 10.413302114330588, p-value = 5.252967501777493e-25
# T-test results for gulpease_index between ed and schizophrenia: T-statistic = 11.553519848487877, p-value = 2.4106853927766792e-30
# T-test results for gulpease_index between ed and socialanxiety: T-statistic = 15.761280490377517, p-value = 9.347437440621937e-55
# T-test results for gulpease_index between healthanxiety and ptsd: T-statistic = 1.826289881767177, p-value = 0.0680056896523588
# T-test results for gulpease_index between healthanxiety and schizophrenia: T-statistic = 1.537099015477352, p-value = 0.12444374981770871
# T-test results for gulpease_index between healthanxiety and socialanxiety: T-statistic = 0.6929802336770396, p-value = 0.4883664354224573
# T-test results for gulpease_index between ptsd and schizophrenia: T-statistic = -0.3579562310587476, p-value = 0.7204199907557787
# T-test results for gulpease_index between ptsd and socialanxiety: T-statistic = -1.7071321302315479, p-value = 0.08788551198535349
# T-test results for gulpease_index between schizophrenia and socialanxiety: T-statistic = -1.3848584856291746, p-value = 0.16617617391891581
# T-test results for gunning_fog_index between adhd and anxiety: T-statistic = 6.947341074046593, p-value = 3.890462370101441e-12
# T-test results for gunning_fog_index between adhd and autism: T-statistic = -1.4092174617670974, p-value = 0.15882457043955048
# T-test results for gunning_fog_index between adhd and bpd: T-statistic = 8.540112564625705, p-value = 1.6094998286452904e-17
# T-test results for gunning_fog_index between adhd and depression: T-statistic = 29.499407432405793, p-value = 1.5619652524638325e-188
# T-test results for gunning_fog_index between adhd and ed: T-statistic = 29.00783198463396, p-value = 1.1421404611706311e-175
# T-test results for gunning_fog_index between adhd and healthanxiety: T-statistic = 8.595896466275533, p-value = 1.0455488577835258e-17
# T-test results for gunning_fog_index between adhd and ptsd: T-statistic = 1.8855124448668839, p-value = 0.05941051829964315
# T-test results for gunning_fog_index between adhd and schizophrenia: T-statistic = 2.861890767456869, p-value = 0.0042254936247928185
# T-test results for gunning_fog_index between adhd and socialanxiety: T-statistic = 7.64985323030476, p-value = 2.2483929450779915e-14
# T-test results for gunning_fog_index between anxiety and autism: T-statistic = -4.6242033232812565, p-value = 3.811324878164312e-06
# T-test results for gunning_fog_index between anxiety and bpd: T-statistic = 4.253152706484897, p-value = 2.1253904225259248e-05
# T-test results for gunning_fog_index between anxiety and depression: T-statistic = 27.058530555846392, p-value = 1.6530094640416974e-159
# T-test results for gunning_fog_index between anxiety and ed: T-statistic = 26.858324472352727, p-value = 4.9197323279632385e-154
# T-test results for gunning_fog_index between anxiety and healthanxiety: T-statistic = 5.886928680201573, p-value = 4.0694671075116965e-09
# T-test results for gunning_fog_index between anxiety and ptsd: T-statistic = -1.140173125286495, p-value = 0.25424358191824475
# T-test results for gunning_fog_index between anxiety and schizophrenia: T-statistic = -0.5623765343122625, p-value = 0.573872631591746
# T-test results for gunning_fog_index between anxiety and socialanxiety: T-statistic = 2.898294466796335, p-value = 0.0037591272571471136
# T-test results for gunning_fog_index between autism and bpd: T-statistic = 6.005094890448953, p-value = 2.1412837991024406e-09
# T-test results for gunning_fog_index between autism and depression: T-statistic = 13.142856753025946, p-value = 2.519287414321814e-39
# T-test results for gunning_fog_index between autism and ed: T-statistic = 17.289332868373005, p-value = 3.7168682499178e-64
# T-test results for gunning_fog_index between autism and healthanxiety: T-statistic = 7.021570331249163, p-value = 3.335827775229026e-12
# T-test results for gunning_fog_index between autism and ptsd: T-statistic = 2.302616741933444, p-value = 0.021448077397508414
# T-test results for gunning_fog_index between autism and schizophrenia: T-statistic = 2.8149405754305272, p-value = 0.004934893567500992
# T-test results for gunning_fog_index between autism and socialanxiety: T-statistic = 5.423063402368026, p-value = 6.254910203353112e-08
# T-test results for gunning_fog_index between bpd and depression: T-statistic = 11.007516144851584, p-value = 4.0377966791780373e-28
# T-test results for gunning_fog_index between bpd and ed: T-statistic = 16.873048484406233, p-value = 3.8808254472197783e-62
# T-test results for gunning_fog_index between bpd and healthanxiety: T-statistic = 2.7084354426418016, p-value = 0.00679703631900536
# T-test results for gunning_fog_index between bpd and ptsd: T-statistic = -3.1561678686345584, p-value = 0.001614267159875041
# T-test results for gunning_fog_index between bpd and schizophrenia: T-statistic = -2.868045065853161, p-value = 0.004156046090951114
# T-test results for gunning_fog_index between bpd and socialanxiety: T-statistic = -1.2536943556726012, p-value = 0.2100100388443161
# T-test results for gunning_fog_index between depression and ed: T-statistic = 11.63459036898932, p-value = 3.261169476451482e-31
# T-test results for gunning_fog_index between depression and healthanxiety: T-statistic = -3.543970818502262, p-value = 0.00039485838287763
# T-test results for gunning_fog_index between depression and ptsd: T-statistic = -9.865221319042467, p-value = 6.480728359594354e-23
# T-test results for gunning_fog_index between depression and schizophrenia: T-statistic = -10.965474187037618, p-value = 6.463919396317989e-28
# T-test results for gunning_fog_index between depression and socialanxiety: T-statistic = -13.813913072597584, p-value = 2.93615680452816e-43
# T-test results for gunning_fog_index between ed and healthanxiety: T-statistic = -9.317877839359992, p-value = 2.079215816623673e-20
# T-test results for gunning_fog_index between ed and ptsd: T-statistic = -14.70498779875531, p-value = 1.8608620734561677e-47
# T-test results for gunning_fog_index between ed and schizophrenia: T-statistic = -15.626856625349548, p-value = 2.5864789838364116e-53
# T-test results for gunning_fog_index between ed and socialanxiety: T-statistic = -19.14987861513906, p-value = 3.8320887624238153e-79
# T-test results for gunning_fog_index between healthanxiety and ptsd: T-statistic = -4.833770765900554, p-value = 1.4774334825277756e-06
# T-test results for gunning_fog_index between healthanxiety and schizophrenia: T-statistic = -4.4490686923990115, p-value = 9.148804789915268e-06
# T-test results for gunning_fog_index between healthanxiety and socialanxiety: T-statistic = -3.6891353462667817, p-value = 0.0002283271561003304
# T-test results for gunning_fog_index between ptsd and schizophrenia: T-statistic = 0.4555296765876201, p-value = 0.6487857215871031
# T-test results for gunning_fog_index between ptsd and socialanxiety: T-statistic = 2.4329814608804243, p-value = 0.015024448145083321
# T-test results for gunning_fog_index between schizophrenia and socialanxiety: T-statistic = 2.066376357728802, p-value = 0.0388598404778745
# T-test results for lix between adhd and anxiety: T-statistic = 9.257781630480734, p-value = 2.3928588883804436e-20
# T-test results for lix between adhd and autism: T-statistic = -4.676140261729948, p-value = 2.989593509121263e-06
# T-test results for lix between adhd and bpd: T-statistic = 11.494757846269273, p-value = 2.526233114084459e-30
# T-test results for lix between adhd and depression: T-statistic = 34.5135612444078, p-value = 5.906684617128646e-256
# T-test results for lix between adhd and ed: T-statistic = 27.992611856556913, p-value = 2.7391726922867847e-164
# T-test results for lix between adhd and healthanxiety: T-statistic = 7.2338901735820675, p-value = 5.290164262790829e-13
# T-test results for lix between adhd and ptsd: T-statistic = 2.1159719002389594, p-value = 0.03438960585812681
# T-test results for lix between adhd and schizophrenia: T-statistic = -0.32890792092188165, p-value = 0.7422365302206122
# T-test results for lix between adhd and socialanxiety: T-statistic = 11.266912311365902, p-value = 3.18454856259721e-29
# T-test results for lix between anxiety and autism: T-statistic = -9.10303316879055, p-value = 1.060734595748437e-19
# T-test results for lix between anxiety and bpd: T-statistic = 5.706702169787216, p-value = 1.181878500357226e-08
# T-test results for lix between anxiety and depression: T-statistic = 30.128230839173323, p-value = 9.42576395131168e-197
# T-test results for lix between anxiety and ed: T-statistic = 23.778394166171946, p-value = 5.806489064674753e-122
# T-test results for lix between anxiety and healthanxiety: T-statistic = 3.2430755045407236, p-value = 0.0011866051855868116
# T-test results for lix between anxiety and ptsd: T-statistic = -1.9542462176870559, p-value = 0.050702071025717374
# T-test results for lix between anxiety and schizophrenia: T-statistic = -5.203107927832704, p-value = 2.000289186713084e-07
# T-test results for lix between anxiety and socialanxiety: T-statistic = 4.971105948767076, p-value = 6.753948869487993e-07
# T-test results for lix between autism and bpd: T-statistic = 10.461007888136798, p-value = 3.5107041615909098e-25
# T-test results for lix between autism and depression: T-statistic = 18.48017552143769, p-value = 9.443761416968183e-76
# T-test results for lix between autism and ed: T-statistic = 19.2364439791159, p-value = 3.2958430450274407e-78
# T-test results for lix between autism and healthanxiety: T-statistic = 8.27511653766055, p-value = 2.8361701105912426e-16
# T-test results for lix between autism and ptsd: T-statistic = 4.6743131100518065, p-value = 3.2367469657026e-06
# T-test results for lix between autism and schizophrenia: T-statistic = 3.047667373587966, p-value = 0.002341803964869109
# T-test results for lix between autism and socialanxiety: T-statistic = 10.337753581064826, p-value = 1.0723831813037392e-24
# T-test results for lix between bpd and depression: T-statistic = 11.272641001365413, p-value = 2.0855580286209038e-29
# T-test results for lix between bpd and ed: T-statistic = 13.352267138932765, p-value = 5.676062973199663e-40
# T-test results for lix between bpd and healthanxiety: T-statistic = -0.33869050229130815, p-value = 0.7348656945765304
# T-test results for lix between bpd and ptsd: T-statistic = -4.614406698240827, p-value = 4.105963057208618e-06
# T-test results for lix between bpd and schizophrenia: T-statistic = -7.343194189536045, p-value = 2.606918452046615e-13
# T-test results for lix between bpd and socialanxiety: T-statistic = -0.8919076004136516, p-value = 0.3724841380771643
# T-test results for lix between depression and ed: T-statistic = 6.667604988038495, p-value = 2.650014988482654e-11
# T-test results for lix between depression and healthanxiety: T-statistic = -7.180694677267898, p-value = 7.127160761580012e-13
# T-test results for lix between depression and ptsd: T-statistic = -11.636924390486977, p-value = 3.214215140558419e-31
# T-test results for lix between depression and schizophrenia: T-statistic = -16.74545319150838, p-value = 1.3190725912097327e-62
# T-test results for lix between depression and socialanxiety: T-statistic = -13.586707621727962, p-value = 6.56917708721349e-42
# T-test results for lix between ed and healthanxiety: T-statistic = -9.830376094397801, p-value = 1.663663910201394e-22
# T-test results for lix between ed and ptsd: T-statistic = -13.651414048153416, p-value = 2.5895013019040825e-41
# T-test results for lix between ed and schizophrenia: T-statistic = -17.245504075569258, p-value = 4.230500493474947e-64
# T-test results for lix between ed and socialanxiety: T-statistic = -15.092671316828671, p-value = 1.902597405363293e-50
# T-test results for lix between healthanxiety and ptsd: T-statistic = -3.609401396088514, p-value = 0.00031701456408441845
# T-test results for lix between healthanxiety and schizophrenia: T-statistic = -5.348340537978996, p-value = 1.0003204969765601e-07
# T-test results for lix between healthanxiety and socialanxiety: T-statistic = -0.27705535877160514, p-value = 0.781753426541702
# T-test results for lix between ptsd and schizophrenia: T-statistic = -1.7122176534040237, p-value = 0.08703681542653777
# T-test results for lix between ptsd and socialanxiety: T-statistic = 4.201102226196832, p-value = 2.7219398281639668e-05
# T-test results for lix between schizophrenia and socialanxiety: T-statistic = 7.067726616409612, p-value = 1.8619567496515344e-12
# T-test results for smog_index between adhd and anxiety: T-statistic = 7.9033526703809045, p-value = 2.9214035522796205e-15
# T-test results for smog_index between adhd and autism: T-statistic = -1.1529368464393535, p-value = 0.24898389356114808
# T-test results for smog_index between adhd and bpd: T-statistic = 9.092208404156564, p-value = 1.2258846780054352e-19
# T-test results for smog_index between adhd and depression: T-statistic = 34.93756280401718, p-value = 4.1860198625754e-262
# T-test results for smog_index between adhd and ed: T-statistic = 31.747831590243468, p-value = 5.631595473051775e-208
# T-test results for smog_index between adhd and healthanxiety: T-statistic = 9.493387620444175, p-value = 3.1675634677813107e-21
# T-test results for smog_index between adhd and ptsd: T-statistic = 1.8373337795030962, p-value = 0.06621165909736475
# T-test results for smog_index between adhd and schizophrenia: T-statistic = 3.6411144595978318, p-value = 0.00027370062307201286
# T-test results for smog_index between adhd and socialanxiety: T-statistic = 10.574411137179359, p-value = 5.826872836099198e-26
# T-test results for smog_index between anxiety and autism: T-statistic = -4.732725648815043, p-value = 2.2480531845161685e-06
# T-test results for smog_index between anxiety and bpd: T-statistic = 4.0932932777685185, p-value = 4.283530648774027e-05
# T-test results for smog_index between anxiety and depression: T-statistic = 32.7056387657801, p-value = 6.200335960618825e-231
# T-test results for smog_index between anxiety and ed: T-statistic = 29.112723764067148, p-value = 1.1399958038101034e-179
# T-test results for smog_index between anxiety and healthanxiety: T-statistic = 6.270565210838637, p-value = 3.756082441305843e-10
# T-test results for smog_index between anxiety and ptsd: T-statistic = -1.6338076979801244, p-value = 0.10233312793047307
# T-test results for smog_index between anxiety and schizophrenia: T-statistic = -0.2369352600296166, p-value = 0.8127120695778731
# T-test results for smog_index between anxiety and socialanxiety: T-statistic = 5.359026001050079, p-value = 8.530090618574556e-08
# T-test results for smog_index between autism and bpd: T-statistic = 5.972506682193104, p-value = 2.610074853848536e-09
# T-test results for smog_index between autism and depression: T-statistic = 14.893401606150373, p-value = 5.934042386075642e-50
# T-test results for smog_index between autism and ed: T-statistic = 17.856873539382114, p-value = 3.980834246342644e-68
# T-test results for smog_index between autism and healthanxiety: T-statistic = 7.325719097839941, p-value = 3.894323773885017e-13
# T-test results for smog_index between autism and ptsd: T-statistic = 2.0527517384121423, p-value = 0.04028420297372239
# T-test results for smog_index between autism and schizophrenia: T-statistic = 3.0563715638526388, p-value = 0.002275236038468029
# T-test results for smog_index between autism and socialanxiety: T-statistic = 6.6215666273424745, p-value = 4.0968053307404384e-11
# T-test results for smog_index between bpd and depression: T-statistic = 14.393968974198495, p-value = 8.434235448363113e-47
# T-test results for smog_index between bpd and ed: T-statistic = 18.35959365167599, p-value = 7.219021677520575e-73
# T-test results for smog_index between bpd and healthanxiety: T-statistic = 3.0977737190041363, p-value = 0.0019671542654551314
# T-test results for smog_index between bpd and ptsd: T-statistic = -3.4768076805029784, p-value = 0.0005145631293244365
# T-test results for smog_index between bpd and schizophrenia: T-statistic = -2.4987017984897646, p-value = 0.01251256829156584
# T-test results for smog_index between bpd and socialanxiety: T-statistic = 0.6942924489823765, p-value = 0.48753014894779756
# T-test results for smog_index between depression and ed: T-statistic = 10.424170112970096, p-value = 2.1481162696763587e-25
# T-test results for smog_index between depression and healthanxiety: T-statistic = -5.193991985489514, p-value = 2.0742369938509303e-07
# T-test results for smog_index between depression and ptsd: T-statistic = -12.089359368652195, p-value = 1.4885783054779641e-33
# T-test results for smog_index between depression and schizophrenia: T-statistic = -12.749457989104945, p-value = 4.073741255766326e-37
# T-test results for smog_index between depression and socialanxiety: T-statistic = -14.762793781506483, p-value = 3.934950427050134e-49
# T-test results for smog_index between ed and healthanxiety: T-statistic = -9.968943735227278, p-value = 4.328184793909408e-23
# T-test results for smog_index between ed and ptsd: T-statistic = -15.768401855681768, p-value = 4.6677797953447324e-54
# T-test results for smog_index between ed and schizophrenia: T-statistic = -16.18166097871133, p-value = 6.575721129321794e-57
# T-test results for smog_index between ed and socialanxiety: T-statistic = -18.695927414689038, p-value = 1.2364905373077734e-75
# T-test results for smog_index between healthanxiety and ptsd: T-statistic = -5.463474933508845, p-value = 5.4604992765578106e-08
# T-test results for smog_index between healthanxiety and schizophrenia: T-statistic = -4.49604525412183, p-value = 7.361611811731257e-06
# T-test results for smog_index between healthanxiety and socialanxiety: T-statistic = -2.7014860061866988, p-value = 0.006935226712363256
# T-test results for smog_index between ptsd and schizophrenia: T-statistic = 0.9885132618796024, p-value = 0.32304037821111053
# T-test results for smog_index between ptsd and socialanxiety: T-statistic = 4.047061690845916, p-value = 5.2977202310687366e-05
# T-test results for smog_index between schizophrenia and socialanxiety: T-statistic = 3.1171364973099873, p-value = 0.0018396665110317198
# T-test results for wiener_sachtextformel between adhd and anxiety: T-statistic = 10.435018467346406, p-value = 2.1364521233016515e-25
# T-test results for wiener_sachtextformel between adhd and autism: T-statistic = -3.705837222176424, p-value = 0.00021265934693188735
# T-test results for wiener_sachtextformel between adhd and bpd: T-statistic = 12.02107425741322, p-value = 5.561180536729969e-33
# T-test results for wiener_sachtextformel between adhd and depression: T-statistic = 40.857941955844815, p-value = 0.0
# T-test results for wiener_sachtextformel between adhd and ed: T-statistic = 32.04117754911451, p-value = 1.4394317978637183e-211
# T-test results for wiener_sachtextformel between adhd and healthanxiety: T-statistic = 9.334197362602685, p-value = 1.4093014033993136e-20
# T-test results for wiener_sachtextformel between adhd and ptsd: T-statistic = 2.291097774729272, p-value = 0.021993378936654918
# T-test results for wiener_sachtextformel between adhd and schizophrenia: T-statistic = 0.5709110129967041, p-value = 0.5680809067080215
# T-test results for wiener_sachtextformel between adhd and socialanxiety: T-statistic = 13.079570473556002, p-value = 1.0810625595278736e-38
# T-test results for wiener_sachtextformel between anxiety and autism: T-statistic = -8.455255741090443, p-value = 3.206429865806256e-17
# T-test results for wiener_sachtextformel between anxiety and bpd: T-statistic = 5.2436192066675185, p-value = 1.6040274950646048e-07
# T-test results for wiener_sachtextformel between anxiety and depression: T-statistic = 35.588108640218614, p-value = 2.9292663986050552e-272
# T-test results for wiener_sachtextformel between anxiety and ed: T-statistic = 26.453666333750068, p-value = 1.2662845015525198e-149
# T-test results for wiener_sachtextformel between anxiety and healthanxiety: T-statistic = 4.748701332317072, p-value = 2.0776162934711565e-06
# T-test results for wiener_sachtextformel between anxiety and ptsd: T-statistic = -2.3009740417406044, p-value = 0.02141513857948137
# T-test results for wiener_sachtextformel between anxiety and schizophrenia: T-statistic = -4.793743955829151, p-value = 1.6615507433293519e-06
# T-test results for wiener_sachtextformel between anxiety and socialanxiety: T-statistic = 5.8172389092076005, p-value = 6.143466564074207e-09
# T-test results for wiener_sachtextformel between autism and bpd: T-statistic = 9.724461090862548, p-value = 4.988879449831967e-22
# T-test results for wiener_sachtextformel between autism and depression: T-statistic = 20.083907439561656, p-value = 5.074558383820312e-89
# T-test results for wiener_sachtextformel between autism and ed: T-statistic = 20.83184648832891, p-value = 1.3364356227938017e-90
# T-test results for wiener_sachtextformel between autism and healthanxiety: T-statistic = 8.813934241262613, p-value = 3.3280410294274823e-18
# T-test results for wiener_sachtextformel between autism and ptsd: T-statistic = 4.031886703497755, p-value = 5.834514863708353e-05
# T-test results for wiener_sachtextformel between autism and schizophrenia: T-statistic = 2.849065654919895, p-value = 0.004437616574861423
# T-test results for wiener_sachtextformel between autism and socialanxiety: T-statistic = 10.299824631305626, p-value = 1.5733856098747927e-24
# T-test results for wiener_sachtextformel between bpd and depression: T-statistic = 14.767804849524657, p-value = 3.684820781428407e-49
# T-test results for wiener_sachtextformel between bpd and ed: T-statistic = 15.930166800826386, p-value = 9.543409482571712e-56
# T-test results for wiener_sachtextformel between bpd and healthanxiety: T-statistic = 1.202011488095472, p-value = 0.2294503294205394
# T-test results for wiener_sachtextformel between bpd and ptsd: T-statistic = -4.656738209282527, p-value = 3.350885559846838e-06
# T-test results for wiener_sachtextformel between bpd and schizophrenia: T-statistic = -6.746210511996776, p-value = 1.781323856138224e-11
# T-test results for wiener_sachtextformel between bpd and socialanxiety: T-statistic = 0.0941385030174056, p-value = 0.9250027980564856
# T-test results for wiener_sachtextformel between depression and ed: T-statistic = 6.844423586718364, p-value = 7.841872493566471e-12
# T-test results for wiener_sachtextformel between depression and healthanxiety: T-statistic = -7.485610901796856, p-value = 7.353396036267867e-14
# T-test results for wiener_sachtextformel between depression and ptsd: T-statistic = -13.963401644213087, p-value = 3.80628751285122e-44
# T-test results for wiener_sachtextformel between depression and schizophrenia: T-statistic = -18.77191574956781, p-value = 4.3017018301288134e-78
# T-test results for wiener_sachtextformel between depression and socialanxiety: T-statistic = -16.036103055958698, p-value = 1.3096640583147068e-57
# T-test results for wiener_sachtextformel between ed and healthanxiety: T-statistic = -10.19177149733878, p-value = 4.7876944249910795e-24
# T-test results for wiener_sachtextformel between ed and ptsd: T-statistic = -15.811127581253233, p-value = 2.4870137085329454e-54
# T-test results for wiener_sachtextformel between ed and schizophrenia: T-statistic = -18.8617711703658, p-value = 9.357835333657143e-76
# T-test results for wiener_sachtextformel between ed and socialanxiety: T-statistic = -16.89376166993373, p-value = 1.9466636615064785e-62
# T-test results for wiener_sachtextformel between healthanxiety and ptsd: T-statistic = -4.819232126992447, p-value = 1.5874873240091056e-06
# T-test results for wiener_sachtextformel between healthanxiety and schizophrenia: T-statistic = -6.059953214012762, p-value = 1.6524836738474469e-09
# T-test results for wiener_sachtextformel between healthanxiety and socialanxiety: T-statistic = -1.1970214757784803, p-value = 0.23137660960519493
# T-test results for wiener_sachtextformel between ptsd and schizophrenia: T-statistic = -1.2317668850716263, p-value = 0.21820454955777271
# T-test results for wiener_sachtextformel between ptsd and socialanxiety: T-statistic = 4.9565667664148645, p-value = 7.512741177369e-07
# T-test results for wiener_sachtextformel between schizophrenia and socialanxiety: T-statistic = 7.2209750819844585, p-value = 6.192324576352707e-13
# adhd and anxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and autism: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, lix, wiener_sachtextformel : gunning_fog_index, smog_index
# adhd and bpd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# adhd and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and autism: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and bpd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# anxiety and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, wiener_sachtextformel : gulpease_index, gunning_fog_index, lix, smog_index
# anxiety and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, lix, wiener_sachtextformel : gulpease_index, gunning_fog_index, smog_index
# autism and bpd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# autism and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and depression: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and ed: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# bpd and socialanxiety: automated_readability_index, flesch_kincaid_grade_level, gulpease_index : coleman_liau_index, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel
# depression and ed: automated_readability_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : coleman_liau_index
# depression and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# depression and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# depression and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# depression and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and healthanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# ed and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel : No insignificant parameters
# healthanxiety and ptsd: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# healthanxiety and schizophrenia: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# ptsd and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# schizophrenia and socialanxiety: automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : gulpease_index
# adhd and schizophrenia: coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, smog_index : automated_readability_index, gulpease_index, lix, wiener_sachtextformel
# anxiety and healthanxiety: coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : automated_readability_index, gulpease_index
# anxiety and socialanxiety: coleman_liau_index, flesch_reading_ease, gunning_fog_index, lix, smog_index, wiener_sachtextformel : automated_readability_index, flesch_kincaid_grade_level, gulpease_index
# bpd and healthanxiety: coleman_liau_index, gunning_fog_index, smog_index : automated_readability_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, lix, wiener_sachtextformel
# healthanxiety and socialanxiety: coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gunning_fog_index, smog_index : automated_readability_index, gulpease_index, lix, wiener_sachtextformel
# adhd and ptsd: flesch_kincaid_grade_level, flesch_reading_ease, lix, wiener_sachtextformel : automated_readability_index, coleman_liau_index, gulpease_index, gunning_fog_index, smog_index
# ptsd and schizophrenia: No significant parameters : automated_readability_index, coleman_liau_index, flesch_kincaid_grade_level, flesch_reading_ease, gulpease_index, gunning_fog_index, lix, smog_index, wiener_sachtextformel

# %%
t_test_df = pd.DataFrame(index=pd.MultiIndex.from_tuples(itertools.combinations(datasets.keys(), 2)), columns=readability_parameters)

pretty_table(t_test_df)
# Out:
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+
# |           Condition Pair           | automated_readability_index | coleman_liau_index | flesch_kincaid_grade_level | flesch_reading_ease | gulpease_index | gunning_fog_index |      lix      |   smog_index  | wiener_sachtextformel |
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+
# |        ('adhd', 'anxiety')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('adhd', 'autism')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |          ('adhd', 'bpd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('adhd', 'depression')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('adhd', 'ed')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('adhd', 'healthanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |          ('adhd', 'ptsd')          |        Insignificant        |   Insignificant    |        Significant         |     Significant     | Insignificant  |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |     ('adhd', 'schizophrenia')      |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |     ('adhd', 'socialanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('anxiety', 'autism')        |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('anxiety', 'bpd')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('anxiety', 'depression')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('anxiety', 'ed')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('anxiety', 'healthanxiety')    |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# |        ('anxiety', 'ptsd')         |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |   Insignificant   | Insignificant | Insignificant |      Significant      |
# |    ('anxiety', 'schizophrenia')    |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |    ('anxiety', 'socialanxiety')    |        Insignificant        |    Significant     |       Insignificant        |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('autism', 'bpd')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('autism', 'depression')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |          ('autism', 'ed')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'healthanxiety')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('autism', 'ptsd')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'schizophrenia')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'socialanxiety')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('bpd', 'depression')        |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('bpd', 'ed')            |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'healthanxiety')      |        Insignificant        |    Significant     |       Insignificant        |    Insignificant    | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |          ('bpd', 'ptsd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'schizophrenia')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'socialanxiety')      |         Significant         |   Insignificant    |        Significant         |    Insignificant    |  Significant   |   Insignificant   | Insignificant | Insignificant |     Insignificant     |
# |        ('depression', 'ed')        |         Significant         |   Insignificant    |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'healthanxiety')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('depression', 'ptsd')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'schizophrenia')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'socialanxiety')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'healthanxiety')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('ed', 'ptsd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'schizophrenia')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'socialanxiety')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('healthanxiety', 'ptsd')      |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('healthanxiety', 'schizophrenia') |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('healthanxiety', 'socialanxiety') |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |     ('ptsd', 'schizophrenia')      |        Insignificant        |   Insignificant    |       Insignificant        |    Insignificant    | Insignificant  |   Insignificant   | Insignificant | Insignificant |     Insignificant     |
# |     ('ptsd', 'socialanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('schizophrenia', 'socialanxiety') |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+

# %%
export_pdf_png(t_test_df, "t_test_results")

# %%
export_ipywidgets(t_test_df)
# Out:
# GridBox(children=(Button(layout=Layout(width='100px'), style=ButtonStyle(button_color='white')), Button(layout…

# %% [markdown]
# ***Tukey's HSD Test***
#
# Tukey's HSD test is employed after an ANOVA to pinpoint specific group differences among three or more groups:
#
# * Test Statistic: The test statistic quantifies the difference between group means in relation to within-group variability. Larger values denote more substantial differences.
#
# * P-value: This value signifies the likelihood of observing extreme differences in sample means (or larger) if there were no actual differences between the population means. A smaller p-value (often < 0.05) suggests strong evidence against the null hypothesis.
#
# Null hypotesis: There is no difference between the means of the groups.

# %%
tukeys_rejected_parameters = {pair: [] for pair in itertools.combinations(diseases, 2)}
tukeys_not_rejected_parameters = {pair: [] for pair in itertools.combinations(diseases, 2)}

for parameter in readability_parameters:
    data = []
    labels = []
    for disease in diseases:
        data.append(datasets[disease][parameter])
        labels.extend([disease] * len(datasets[disease][parameter]))

    tukey_results = pairwise_tukeyhsd(np.concatenate(data), labels)
    print(f"Tukey HSD test for {parameter}:")
    print(tukey_results)

    reject_mask = tukey_results.reject
    pairs = tukey_results._results_table.data[1:]

    for i, pair in enumerate(pairs):
        group_1, group_2 = pair[0], pair[1]
        if reject_mask[i]:
            tukeys_rejected_parameters[(group_1, group_2)].append(parameter)
        else:
            tukeys_not_rejected_parameters[(group_1, group_2)].append(parameter)

print("Summary of rejected and not rejected parameters:")
for pair in itertools.combinations(diseases, 2):
    rejected = tukeys_rejected_parameters[pair]
    not_rejected = tukeys_not_rejected_parameters[pair]
    print(f"{pair[0]} and {pair[1]}: Significant parameters - {rejected if rejected else 'None'}, Insignificant parameters - {not_rejected if not_rejected else 'None'}")
# Out:
# Tukey HSD test for automated_readability_index:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety  -0.5517    0.0 -0.7142 -0.3893   True
#          adhd        autism    0.845    0.0  0.4705  1.2195   True
#          adhd           bpd  -0.7676    0.0 -0.9976 -0.5377   True
#          adhd    depression  -1.3182    0.0 -1.4596 -1.1768   True
#          adhd            ed  -1.5948    0.0 -1.8165  -1.373   True
#          adhd healthanxiety  -0.5685    0.0  -0.919 -0.2181   True
#          adhd          ptsd  -0.0574    1.0  -0.427  0.3122  False
#          adhd schizophrenia   0.1602 0.8457 -0.1554  0.4757  False
#          adhd socialanxiety  -0.5675    0.0  -0.783 -0.3519   True
#       anxiety        autism   1.3967    0.0  1.0313  1.7622   True
#       anxiety           bpd  -0.2159 0.0478 -0.4308  -0.001   True
#       anxiety    depression  -0.7665    0.0 -0.8817 -0.6512   True
#       anxiety            ed   -1.043    0.0 -1.2492 -0.8369   True
#       anxiety healthanxiety  -0.0168    1.0 -0.3576   0.324  False
#       anxiety          ptsd   0.4943 0.0006  0.1339  0.8547   True
#       anxiety schizophrenia   0.7119    0.0  0.4072  1.0166   True
#       anxiety socialanxiety  -0.0157    1.0 -0.2151  0.1837  False
#        autism           bpd  -1.6126    0.0 -2.0127 -1.2126   True
#        autism    depression  -2.1632    0.0 -2.5198 -1.8066   True
#        autism            ed  -2.4398    0.0 -2.8352 -2.0443   True
#        autism healthanxiety  -1.4135    0.0 -1.8932 -0.9339   True
#        autism          ptsd  -0.9024    0.0 -1.3961 -0.4087   True
#        autism schizophrenia  -0.6848 0.0001 -1.1395 -0.2301   True
#        autism socialanxiety  -1.4125    0.0 -1.8045 -1.0205   True
#           bpd    depression  -0.5506    0.0   -0.75 -0.3511   True
#           bpd            ed  -0.8271    0.0 -1.0898 -0.5645   True
#           bpd healthanxiety   0.1991 0.8137 -0.1786  0.5768  False
#           bpd          ptsd   0.7103    0.0  0.3148  1.1057   True
#           bpd schizophrenia   0.9278    0.0  0.5823  1.2733   True
#           bpd socialanxiety   0.2002 0.2901 -0.0572  0.4576  False
#    depression            ed  -0.2766 0.0002 -0.4666 -0.0866   True
#    depression healthanxiety   0.7497    0.0  0.4184  1.0809   True
#    depression          ptsd   1.2608    0.0  0.9094  1.6122   True
#    depression schizophrenia   1.4784    0.0  1.1843  1.7724   True
#    depression socialanxiety   0.7507    0.0  0.5681  0.9334   True
#            ed healthanxiety   1.0262    0.0  0.6534   1.399   True
#            ed          ptsd   1.5374    0.0  1.1466  1.9281   True
#            ed schizophrenia   1.7549    0.0  1.4148   2.095   True
#            ed socialanxiety   1.0273    0.0  0.7771  1.2774   True
# healthanxiety          ptsd   0.5111 0.0237  0.0354  0.9869   True
# healthanxiety schizophrenia   0.7287    0.0  0.2936  1.1638   True
# healthanxiety socialanxiety   0.0011    1.0  -0.368  0.3701  False
#          ptsd schizophrenia   0.2176 0.8815 -0.2331  0.6682  False
#          ptsd socialanxiety  -0.5101 0.0013 -0.8973 -0.1228   True
# schizophrenia socialanxiety  -0.7276    0.0 -1.0637 -0.3916   True
# ------------------------------------------------------------------
# Tukey HSD test for coleman_liau_index:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety  -0.5803    0.0 -0.7242 -0.4363   True
#          adhd        autism   1.0327    0.0  0.7008  1.3647   True
#          adhd           bpd  -0.7269    0.0 -0.9307 -0.5231   True
#          adhd    depression  -1.3971    0.0 -1.5224 -1.2718   True
#          adhd            ed   -1.378    0.0 -1.5745 -1.1814   True
#          adhd healthanxiety  -0.4005 0.0019 -0.7111 -0.0898   True
#          adhd          ptsd   0.0439    1.0 -0.2836  0.3715  False
#          adhd schizophrenia   0.3724  0.001  0.0927   0.652   True
#          adhd socialanxiety  -0.7054    0.0 -0.8965 -0.5144   True
#       anxiety        autism    1.613    0.0  1.2891  1.9369   True
#       anxiety           bpd  -0.1466 0.3046 -0.3371  0.0439  False
#       anxiety    depression  -0.8169    0.0  -0.919 -0.7147   True
#       anxiety            ed  -0.7977    0.0 -0.9804  -0.615   True
#       anxiety healthanxiety   0.1798 0.6806 -0.1223  0.4819  False
#       anxiety          ptsd   0.6242    0.0  0.3048  0.9436   True
#       anxiety schizophrenia   0.9526    0.0  0.6826  1.2227   True
#       anxiety socialanxiety  -0.1252 0.4284 -0.3019  0.0515  False
#        autism           bpd  -1.7596    0.0 -2.1142  -1.405   True
#        autism    depression  -2.4298    0.0 -2.7459 -2.1138   True
#        autism            ed  -2.4107    0.0 -2.7612 -2.0602   True
#        autism healthanxiety  -1.4332    0.0 -1.8583 -1.0081   True
#        autism          ptsd  -0.9888    0.0 -1.4264 -0.5512   True
#        autism schizophrenia  -0.6603    0.0 -1.0634 -0.2573   True
#        autism socialanxiety  -1.7382    0.0 -2.0856 -1.3907   True
#           bpd    depression  -0.6702    0.0  -0.847 -0.4935   True
#           bpd            ed  -0.6511    0.0 -0.8839 -0.4183   True
#           bpd healthanxiety   0.3264 0.0631 -0.0083  0.6611  False
#           bpd          ptsd   0.7708    0.0  0.4203  1.1213   True
#           bpd schizophrenia   1.0993    0.0  0.7931  1.4054   True
#           bpd socialanxiety   0.0214    1.0 -0.2067  0.2496  False
#    depression            ed   0.0191    1.0 -0.1493  0.1875  False
#    depression healthanxiety   0.9967    0.0   0.703  1.2903   True
#    depression          ptsd   1.4411    0.0  1.1296  1.7525   True
#    depression schizophrenia   1.7695    0.0  1.5089  2.0301   True
#    depression socialanxiety   0.6917    0.0  0.5298  0.8536   True
#            ed healthanxiety   0.9775    0.0  0.6471  1.3079   True
#            ed          ptsd   1.4219    0.0  1.0756  1.7683   True
#            ed schizophrenia   1.7504    0.0  1.4489  2.0518   True
#            ed socialanxiety   0.6725    0.0  0.4508  0.8942   True
# healthanxiety          ptsd   0.4444 0.0293  0.0227  0.8661   True
# healthanxiety schizophrenia   0.7728    0.0  0.3872  1.1585   True
# healthanxiety socialanxiety   -0.305 0.0923 -0.6321  0.0221  False
#          ptsd schizophrenia   0.3284 0.2166 -0.0709  0.7278  False
#          ptsd socialanxiety  -0.7494    0.0 -1.0926 -0.4062   True
# schizophrenia socialanxiety  -1.0778    0.0 -1.3757   -0.78   True
# ------------------------------------------------------------------
# Tukey HSD test for flesch_kincaid_grade_level:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety   -0.399    0.0 -0.5155 -0.2824   True
#          adhd        autism   0.1772 0.5381 -0.0916   0.446  False
#          adhd           bpd  -0.6172    0.0 -0.7823 -0.4522   True
#          adhd    depression  -1.0596    0.0  -1.161 -0.9581   True
#          adhd            ed   -1.459    0.0 -1.6182 -1.2998   True
#          adhd healthanxiety  -0.7161    0.0 -0.9677 -0.4646   True
#          adhd          ptsd  -0.2388 0.1206  -0.504  0.0265  False
#          adhd schizophrenia  -0.2251  0.053 -0.4515  0.0014  False
#          adhd socialanxiety  -0.4116    0.0 -0.5663 -0.2569   True
#       anxiety        autism   0.5761    0.0  0.3138  0.8384   True
#       anxiety           bpd  -0.2183 0.0003 -0.3725 -0.0641   True
#       anxiety    depression  -0.6606    0.0 -0.7434 -0.5779   True
#       anxiety            ed  -1.0601    0.0  -1.208 -0.9121   True
#       anxiety healthanxiety  -0.3172 0.0017 -0.5618 -0.0726   True
#       anxiety          ptsd   0.1602 0.6281 -0.0985  0.4188  False
#       anxiety schizophrenia   0.1739 0.2601 -0.0448  0.3926  False
#       anxiety socialanxiety  -0.0127    1.0 -0.1558  0.1304  False
#        autism           bpd  -0.7944    0.0 -1.0815 -0.5073   True
#        autism    depression  -1.2367    0.0 -1.4927 -0.9808   True
#        autism            ed  -1.6362    0.0   -1.92 -1.3524   True
#        autism healthanxiety  -0.8933    0.0 -1.2375  -0.549   True
#        autism          ptsd   -0.416 0.0078 -0.7703 -0.0616   True
#        autism schizophrenia  -0.4022 0.0038 -0.7286 -0.0759   True
#        autism socialanxiety  -0.5888    0.0 -0.8701 -0.3074   True
#           bpd    depression  -0.4423    0.0 -0.5855 -0.2992   True
#           bpd            ed  -0.8418    0.0 -1.0303 -0.6533   True
#           bpd healthanxiety  -0.0989 0.9789 -0.3699  0.1722  False
#           bpd          ptsd   0.3784  0.001  0.0946  0.6623   True
#           bpd schizophrenia   0.3922    0.0  0.1442  0.6401   True
#           bpd socialanxiety   0.2056 0.0156  0.0209  0.3903   True
#    depression            ed  -0.3995    0.0 -0.5358 -0.2631   True
#    depression healthanxiety   0.3435 0.0002  0.1057  0.5812   True
#    depression          ptsd   0.8208    0.0  0.5686   1.073   True
#    depression schizophrenia   0.8345    0.0  0.6234  1.0455   True
#    depression socialanxiety   0.6479    0.0  0.5169   0.779   True
#            ed healthanxiety   0.7429    0.0  0.4754  1.0105   True
#            ed          ptsd   1.2202    0.0  0.9398  1.5007   True
#            ed schizophrenia   1.2339    0.0  0.9898   1.478   True
#            ed socialanxiety   1.0474    0.0  0.8679  1.2269   True
# healthanxiety          ptsd   0.4773 0.0004  0.1359  0.8188   True
# healthanxiety schizophrenia    0.491    0.0  0.1787  0.8033   True
# healthanxiety socialanxiety   0.3045 0.0104  0.0396  0.5694   True
#          ptsd schizophrenia   0.0137    1.0 -0.3097  0.3371  False
#          ptsd socialanxiety  -0.1728 0.6222 -0.4508  0.1051  False
# schizophrenia socialanxiety  -0.1865 0.2979 -0.4277  0.0547  False
# ------------------------------------------------------------------
# Tukey HSD test for flesch_reading_ease:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety   2.5973    0.0  2.0377  3.1569   True
#          adhd        autism  -1.2256 0.0793  -2.516  0.0647  False
#          adhd           bpd    3.532    0.0  2.7398  4.3242   True
#          adhd    depression   6.5534    0.0  6.0664  7.0404   True
#          adhd            ed   7.6433    0.0  6.8792  8.4075   True
#          adhd healthanxiety   4.0787    0.0  2.8712  5.2862   True
#          adhd          ptsd   1.2681  0.052 -0.0052  2.5413  False
#          adhd schizophrenia   0.7541 0.4604  -0.333  1.8411  False
#          adhd socialanxiety   3.0303    0.0  2.2877  3.7728   True
#       anxiety        autism  -3.8229    0.0 -5.0821 -2.5637   True
#       anxiety           bpd   0.9347 0.0026  0.1944  1.6751   True
#       anxiety    depression   3.9561    0.0   3.559  4.3532   True
#       anxiety            ed    5.046    0.0  4.3358  5.7563   True
#       anxiety healthanxiety   1.4814 0.0026  0.3072  2.6556   True
#       anxiety          ptsd  -1.3293 0.0247 -2.5709 -0.0876   True
#       anxiety schizophrenia  -1.8432    0.0 -2.8931 -0.7934   True
#       anxiety socialanxiety    0.433 0.6033  -0.254  1.1199  False
#        autism           bpd   4.7577    0.0  3.3793  6.1361   True
#        autism    depression    7.779    0.0  6.5504  9.0077   True
#        autism            ed    8.869    0.0  7.5065 10.2315   True
#        autism healthanxiety   5.3043    0.0  3.6519  6.9568   True
#        autism          ptsd   2.4937 0.0002  0.7926  4.1948   True
#        autism schizophrenia   1.9797 0.0026  0.4131  3.5463   True
#        autism socialanxiety   4.2559    0.0  2.9054  5.6064   True
#           bpd    depression   3.0214    0.0  2.3342  3.7085   True
#           bpd            ed   4.1113    0.0  3.2064  5.0162   True
#           bpd healthanxiety   0.5467 0.9471 -0.7545  1.8479  False
#           bpd          ptsd   -2.264    0.0 -3.6264 -0.9016   True
#           bpd schizophrenia   -2.778    0.0 -3.9682 -1.5877   True
#           bpd socialanxiety  -0.5018 0.7417 -1.3885   0.385  False
#    depression            ed   1.0899    0.0  0.4353  1.7445   True
#    depression healthanxiety  -2.4747    0.0 -3.6161 -1.3333   True
#    depression          ptsd  -5.2854    0.0 -6.4961 -4.0746   True
#    depression schizophrenia  -5.7993    0.0 -6.8124 -4.7863   True
#    depression socialanxiety  -3.5231    0.0 -4.1524 -2.8939   True
#            ed healthanxiety  -3.5646    0.0 -4.8489 -2.2803   True
#            ed          ptsd  -6.3753    0.0 -7.7216  -5.029   True
#            ed schizophrenia  -6.8893    0.0  -8.061 -5.7175   True
#            ed socialanxiety  -4.6131    0.0 -5.4749 -3.7513   True
# healthanxiety          ptsd  -2.8107    0.0 -4.4498 -1.1715   True
# healthanxiety schizophrenia  -3.3246    0.0 -4.8237 -1.8256   True
# healthanxiety socialanxiety  -1.0484 0.2133   -2.32  0.2231  False
#          ptsd schizophrenia   -0.514 0.9893 -2.0665  1.0385  False
#          ptsd socialanxiety   1.7622 0.0012   0.428  3.0964   True
# schizophrenia socialanxiety   2.2762    0.0  1.1184   3.434   True
# ------------------------------------------------------------------
# Tukey HSD test for gulpease_index:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety   0.8487 0.0001  0.2851  1.4124   True
#          adhd        autism  -1.7012 0.0014 -3.0009 -0.4015   True
#          adhd           bpd   1.9248    0.0  1.1268  2.7227   True
#          adhd    depression   3.3641    0.0  2.8736  3.8547   True
#          adhd            ed    5.503    0.0  4.7333  6.2727   True
#          adhd healthanxiety   1.1922 0.0602 -0.0241  2.4085  False
#          adhd          ptsd   0.2628 0.9997 -1.0197  1.5453  False
#          adhd schizophrenia   0.4538 0.9514 -0.6411  1.5487  False
#          adhd socialanxiety   0.9405 0.0028  0.1926  1.6885   True
#       anxiety        autism  -2.5499    0.0 -3.8182 -1.2816   True
#       anxiety           bpd    1.076 0.0002  0.3303  1.8217   True
#       anxiety    depression   2.5154    0.0  2.1154  2.9154   True
#       anxiety            ed   4.6542    0.0  3.9389  5.3696   True
#       anxiety healthanxiety   0.3435 0.9959 -0.8392  1.5261  False
#       anxiety          ptsd  -0.5859 0.8995 -1.8366  0.6647  False
#       anxiety schizophrenia  -0.3949 0.9752 -1.4524  0.6625  False
#       anxiety socialanxiety   0.0918    1.0 -0.6002  0.7837  False
#        autism           bpd   3.6259    0.0  2.2375  5.0143   True
#        autism    depression   5.0653    0.0  3.8277  6.3029   True
#        autism            ed   7.2041    0.0  5.8318  8.5765   True
#        autism healthanxiety   2.8933    0.0  1.2289  4.5577   True
#        autism          ptsd    1.964 0.0108  0.2506  3.6774   True
#        autism schizophrenia   2.1549 0.0007   0.577  3.7328   True
#        autism socialanxiety   2.6417    0.0  1.2814  4.0019   True
#           bpd    depression   1.4394    0.0  0.7473  2.1315   True
#           bpd            ed   3.5782    0.0  2.6667  4.4897   True
#           bpd healthanxiety  -0.7326 0.7553 -2.0432   0.578  False
#           bpd          ptsd  -1.6619  0.005 -3.0342 -0.2897   True
#           bpd schizophrenia   -1.471 0.0041 -2.6698 -0.2721   True
#           bpd socialanxiety  -0.9842 0.0176 -1.8774 -0.0911   True
#    depression            ed   2.1388    0.0  1.4795  2.7982   True
#    depression healthanxiety   -2.172    0.0 -3.3216 -1.0223   True
#    depression          ptsd  -3.1013    0.0 -4.3208 -1.8819   True
#    depression schizophrenia  -2.9104    0.0 -3.9307   -1.89   True
#    depression socialanxiety  -2.4236    0.0 -3.0575 -1.7898   True
#            ed healthanxiety  -4.3108    0.0 -5.6044 -3.0172   True
#            ed          ptsd  -5.2402    0.0 -6.5962 -3.8841   True
#            ed schizophrenia  -5.0492    0.0 -6.2294  -3.869   True
#            ed socialanxiety  -4.5625    0.0 -5.4305 -3.6944   True
# healthanxiety          ptsd  -0.9294 0.7475 -2.5804  0.7216  False
# healthanxiety schizophrenia  -0.7384  0.873 -2.2483  0.7715  False
# healthanxiety socialanxiety  -0.2517 0.9998 -1.5325  1.0291  False
#          ptsd schizophrenia    0.191    1.0 -1.3728  1.7547  False
#          ptsd socialanxiety   0.6777 0.8508 -0.6661  2.0215  False
# schizophrenia socialanxiety   0.4867 0.9492 -0.6795  1.6529  False
# ------------------------------------------------------------------
# Tukey HSD test for gunning_fog_index:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety  -0.2657    0.0 -0.3903 -0.1412   True
#          adhd        autism   0.1306 0.9152 -0.1566  0.4178  False
#          adhd           bpd  -0.4799    0.0 -0.6562 -0.3036   True
#          adhd    depression  -1.0151    0.0 -1.1235 -0.9067   True
#          adhd            ed   -1.552    0.0  -1.722 -1.3819   True
#          adhd healthanxiety  -0.7295    0.0 -0.9983 -0.4608   True
#          adhd          ptsd  -0.1702 0.6689 -0.4536  0.1132  False
#          adhd schizophrenia  -0.2252 0.0934 -0.4672  0.0167  False
#          adhd socialanxiety  -0.4009    0.0 -0.5662 -0.2356   True
#       anxiety        autism   0.3963 0.0003  0.1161  0.6766   True
#       anxiety           bpd  -0.2142 0.0016 -0.3789 -0.0494   True
#       anxiety    depression  -0.7493    0.0 -0.8377 -0.6609   True
#       anxiety            ed  -1.2862    0.0 -1.4443 -1.1281   True
#       anxiety healthanxiety  -0.4638    0.0 -0.7251 -0.2025   True
#       anxiety          ptsd   0.0955 0.9855 -0.1808  0.3719  False
#       anxiety schizophrenia   0.0405 0.9999 -0.1932  0.2742  False
#       anxiety socialanxiety  -0.1352 0.1373 -0.2881  0.0177  False
#        autism           bpd  -0.6105    0.0 -0.9173 -0.3037   True
#        autism    depression  -1.1457    0.0 -1.4191 -0.8722   True
#        autism            ed  -1.6826    0.0 -1.9858 -1.3793   True
#        autism healthanxiety  -0.8601    0.0 -1.2279 -0.4923   True
#        autism          ptsd  -0.3008 0.2609 -0.6794  0.0778  False
#        autism schizophrenia  -0.3558  0.041 -0.7045 -0.0072   True
#        autism socialanxiety  -0.5315    0.0 -0.8321 -0.2309   True
#           bpd    depression  -0.5352    0.0 -0.6881 -0.3822   True
#           bpd            ed  -1.0721    0.0 -1.2735 -0.8707   True
#           bpd healthanxiety  -0.2496 0.1627 -0.5392    0.04  False
#           bpd          ptsd   0.3097 0.0407  0.0065  0.6129   True
#           bpd schizophrenia   0.2547 0.0716 -0.0102  0.5196  False
#           bpd socialanxiety    0.079  0.961 -0.1184  0.2764  False
#    depression            ed  -0.5369    0.0 -0.6826 -0.3912   True
#    depression healthanxiety   0.2855 0.0138  0.0315  0.5396   True
#    depression          ptsd   0.8449    0.0  0.5754  1.1143   True
#    depression schizophrenia   0.7898    0.0  0.5644  1.0153   True
#    depression socialanxiety   0.6142    0.0  0.4741  0.7542   True
#            ed healthanxiety   0.8224    0.0  0.5366  1.1083   True
#            ed          ptsd   1.3817    0.0  1.0821  1.6814   True
#            ed schizophrenia   1.3267    0.0  1.0659  1.5875   True
#            ed socialanxiety   1.1511    0.0  0.9593  1.3429   True
# healthanxiety          ptsd   0.5593 0.0001  0.1945  0.9241   True
# healthanxiety schizophrenia   0.5043 0.0001  0.1706  0.8379   True
# healthanxiety socialanxiety   0.3286 0.0091  0.0456  0.6116   True
#          ptsd schizophrenia   -0.055    1.0 -0.4006  0.2905  False
#          ptsd socialanxiety  -0.2307 0.2917 -0.5276  0.0663  False
# schizophrenia socialanxiety  -0.1757 0.4871 -0.4334   0.082  False
# ------------------------------------------------------------------
# Tukey HSD test for lix:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety  -1.0339    0.0 -1.4011 -0.6668   True
#          adhd        autism   1.2637 0.0001   0.417  2.1104   True
#          adhd           bpd  -1.8767    0.0 -2.3965 -1.3569   True
#          adhd    depression  -3.4919    0.0 -3.8114 -3.1723   True
#          adhd            ed  -4.4015    0.0 -4.9029 -3.9001   True
#          adhd healthanxiety   -1.785    0.0 -2.5773 -0.9926   True
#          adhd          ptsd  -0.5537 0.5297 -1.3892  0.2818  False
#          adhd schizophrenia   0.0762    1.0 -0.6371  0.7895  False
#          adhd socialanxiety  -1.7128    0.0    -2.2 -1.2255   True
#       anxiety        autism   2.2976    0.0  1.4714  3.1239   True
#       anxiety           bpd  -0.8427    0.0 -1.3285  -0.357   True
#       anxiety    depression  -2.4579    0.0 -2.7185 -2.1973   True
#       anxiety            ed  -3.3675    0.0 -3.8336 -2.9015   True
#       anxiety healthanxiety   -0.751 0.0633 -1.5214  0.0194  False
#       anxiety          ptsd   0.4802  0.693 -0.3345   1.295  False
#       anxiety schizophrenia   1.1101    0.0  0.4213   1.799   True
#       anxiety socialanxiety  -0.6788 0.0001 -1.1296 -0.2281   True
#        autism           bpd  -3.1404    0.0 -4.0448 -2.2359   True
#        autism    depression  -4.7555    0.0 -5.5617 -3.9494   True
#        autism            ed  -5.6652    0.0 -6.5592 -4.7712   True
#        autism healthanxiety  -3.0487    0.0 -4.1329 -1.9644   True
#        autism          ptsd  -1.8174    0.0 -2.9336 -0.7012   True
#        autism schizophrenia  -1.1875 0.0097 -2.2154 -0.1596   True
#        autism socialanxiety  -2.9765    0.0 -3.8626 -2.0903   True
#           bpd    depression  -1.6152    0.0  -2.066 -1.1643   True
#           bpd            ed  -2.5248    0.0 -3.1186  -1.931   True
#           bpd healthanxiety   0.0917    1.0 -0.7621  0.9455  False
#           bpd          ptsd    1.323 0.0001   0.429   2.217   True
#           bpd schizophrenia   1.9529    0.0  1.1719  2.7339   True
#           bpd socialanxiety   0.1639 0.9968  -0.418  0.7458  False
#    depression            ed  -0.9096    0.0 -1.3391 -0.4801   True
#    depression healthanxiety   1.7069    0.0   0.958  2.4558   True
#    depression          ptsd   2.9382    0.0  2.1437  3.7326   True
#    depression schizophrenia   3.5681    0.0  2.9033  4.2328   True
#    depression socialanxiety   1.7791    0.0  1.3662   2.192   True
#            ed healthanxiety   2.6165    0.0  1.7738  3.4592   True
#            ed          ptsd   3.8478    0.0  2.9644  4.7312   True
#            ed schizophrenia   4.4777    0.0  3.7088  5.2465   True
#            ed socialanxiety   2.6887    0.0  2.1232  3.2542   True
# healthanxiety          ptsd   1.2313 0.0109  0.1557  2.3068   True
# healthanxiety schizophrenia   1.8612    0.0  0.8775  2.8448   True
# healthanxiety socialanxiety   0.0722    1.0 -0.7622  0.9065  False
#          ptsd schizophrenia   0.6299   0.63 -0.3888  1.6486  False
#          ptsd socialanxiety  -1.1591 0.0012 -2.0345 -0.2837   True
# schizophrenia socialanxiety   -1.789    0.0 -2.5487 -1.0293   True
# ------------------------------------------------------------------
# Tukey HSD test for smog_index:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety  -0.2245    0.0 -0.3189   -0.13   True
#          adhd        autism   0.0789 0.9799 -0.1389  0.2966  False
#          adhd           bpd  -0.3788    0.0 -0.5125 -0.2451   True
#          adhd    depression  -0.9132    0.0 -0.9954  -0.831   True
#          adhd            ed  -1.2823    0.0 -1.4112 -1.1533   True
#          adhd healthanxiety  -0.5935    0.0 -0.7973 -0.3897   True
#          adhd          ptsd  -0.1222 0.7359 -0.3371  0.0927  False
#          adhd schizophrenia  -0.2117 0.0098 -0.3952 -0.0283   True
#          adhd socialanxiety  -0.4119    0.0 -0.5372 -0.2866   True
#       anxiety        autism   0.3033 0.0003  0.0908  0.5158   True
#       anxiety           bpd  -0.1543 0.0037 -0.2793 -0.0294   True
#       anxiety    depression  -0.6887    0.0 -0.7558 -0.6217   True
#       anxiety            ed  -1.0578    0.0 -1.1777 -0.9379   True
#       anxiety healthanxiety   -0.369    0.0 -0.5672 -0.1709   True
#       anxiety          ptsd   0.1023 0.8744 -0.1073  0.3118  False
#       anxiety schizophrenia   0.0128    1.0 -0.1644  0.1899  False
#       anxiety socialanxiety  -0.1874    0.0 -0.3033 -0.0715   True
#        autism           bpd  -0.4577    0.0 -0.6903  -0.225   True
#        autism    depression  -0.9921    0.0 -1.1994 -0.7847   True
#        autism            ed  -1.3611    0.0 -1.5911 -1.1312   True
#        autism healthanxiety  -0.6723    0.0 -0.9512 -0.3935   True
#        autism          ptsd  -0.2011 0.4457 -0.4881   0.086  False
#        autism schizophrenia  -0.2906 0.0182 -0.5549 -0.0262   True
#        autism socialanxiety  -0.4907    0.0 -0.7186 -0.2628   True
#           bpd    depression  -0.5344    0.0 -0.6503 -0.4184   True
#           bpd            ed  -0.9035    0.0 -1.0562 -0.7507   True
#           bpd healthanxiety  -0.2147 0.0617 -0.4343  0.0049  False
#           bpd          ptsd   0.2566 0.0151  0.0267  0.4865   True
#           bpd schizophrenia   0.1671 0.2026 -0.0338   0.368  False
#           bpd socialanxiety  -0.0331 0.9995 -0.1827  0.1166  False
#    depression            ed  -0.3691    0.0 -0.4796 -0.2586   True
#    depression healthanxiety   0.3197    0.0  0.1271  0.5123   True
#    depression          ptsd    0.791    0.0  0.5867  0.9953   True
#    depression schizophrenia   0.7015    0.0  0.5305  0.8725   True
#    depression socialanxiety   0.5013    0.0  0.3951  0.6075   True
#            ed healthanxiety   0.6888    0.0   0.472  0.9055   True
#            ed          ptsd   1.1601    0.0  0.9329  1.3873   True
#            ed schizophrenia   1.0706    0.0  0.8728  1.2683   True
#            ed socialanxiety   0.8704    0.0   0.725  1.0158   True
# healthanxiety          ptsd   0.4713    0.0  0.1947  0.7479   True
# healthanxiety schizophrenia   0.3818 0.0001  0.1288  0.6348   True
# healthanxiety socialanxiety   0.1816 0.1828  -0.033  0.3962  False
#          ptsd schizophrenia  -0.0895 0.9866 -0.3515  0.1725  False
#          ptsd socialanxiety  -0.2897 0.0019 -0.5148 -0.0645   True
# schizophrenia socialanxiety  -0.2002 0.0394 -0.3956 -0.0048   True
# ------------------------------------------------------------------
# Tukey HSD test for wiener_sachtextformel:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#          adhd       anxiety  -0.2838    0.0 -0.3714 -0.1962   True
#          adhd        autism   0.2402 0.0065  0.0382  0.4423   True
#          adhd           bpd  -0.4744    0.0 -0.5984 -0.3503   True
#          adhd    depression  -0.9726    0.0 -1.0488 -0.8963   True
#          adhd            ed  -1.1911    0.0 -1.3107 -1.0714   True
#          adhd healthanxiety  -0.5547    0.0 -0.7437 -0.3656   True
#          adhd          ptsd  -0.1445 0.3935 -0.3438  0.0549  False
#          adhd schizophrenia  -0.0319 0.9999 -0.2021  0.1383  False
#          adhd socialanxiety  -0.4786    0.0 -0.5949 -0.3623   True
#       anxiety        autism   0.5241    0.0  0.3269  0.7212   True
#       anxiety           bpd  -0.1905    0.0 -0.3065 -0.0746   True
#       anxiety    depression  -0.6887    0.0 -0.7509 -0.6265   True
#       anxiety            ed  -0.9072    0.0 -1.0184  -0.796   True
#       anxiety healthanxiety  -0.2709 0.0001 -0.4547  -0.087   True
#       anxiety          ptsd   0.1393 0.4104 -0.0551  0.3338  False
#       anxiety schizophrenia   0.2519 0.0001  0.0875  0.4163   True
#       anxiety socialanxiety  -0.1948    0.0 -0.3023 -0.0872   True
#        autism           bpd  -0.7146    0.0 -0.9304 -0.4988   True
#        autism    depression  -1.2128    0.0 -1.4052 -1.0204   True
#        autism            ed  -1.4313    0.0 -1.6446  -1.218   True
#        autism healthanxiety  -0.7949    0.0 -1.0537 -0.5362   True
#        autism          ptsd  -0.3847 0.0002 -0.6511 -0.1184   True
#        autism schizophrenia  -0.2722 0.0162 -0.5175 -0.0269   True
#        autism socialanxiety  -0.7188    0.0 -0.9303 -0.5074   True
#           bpd    depression  -0.4982    0.0 -0.6058 -0.3906   True
#           bpd            ed  -0.7167    0.0 -0.8584  -0.575   True
#           bpd healthanxiety  -0.0803 0.9646 -0.2841  0.1234  False
#           bpd          ptsd   0.3299    0.0  0.1166  0.5432   True
#           bpd schizophrenia   0.4424    0.0  0.2561  0.6288   True
#           bpd socialanxiety  -0.0042    1.0 -0.1431  0.1346  False
#    depression            ed  -0.2185    0.0  -0.321  -0.116   True
#    depression healthanxiety   0.4179    0.0  0.2392  0.5966   True
#    depression          ptsd   0.8281    0.0  0.6385  1.0176   True
#    depression schizophrenia   0.9406    0.0   0.782  1.0992   True
#    depression socialanxiety    0.494    0.0  0.3954  0.5925   True
#            ed healthanxiety   0.6364    0.0  0.4353  0.8375   True
#            ed          ptsd   1.0466    0.0  0.8358  1.2574   True
#            ed schizophrenia   1.1591    0.0  0.9757  1.3426   True
#            ed socialanxiety   0.7125    0.0  0.5775  0.8474   True
# healthanxiety          ptsd   0.4102    0.0  0.1535  0.6668   True
# healthanxiety schizophrenia   0.5227    0.0   0.288  0.7575   True
# healthanxiety socialanxiety   0.0761 0.9711  -0.123  0.2752  False
#          ptsd schizophrenia   0.1126  0.906 -0.1305  0.3556  False
#          ptsd socialanxiety  -0.3341    0.0  -0.543 -0.1252   True
# schizophrenia socialanxiety  -0.4467    0.0 -0.6279 -0.2654   True
# ------------------------------------------------------------------
# Summary of rejected and not rejected parameters:
# adhd and anxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# adhd and autism: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'gulpease_index', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'smog_index']
# adhd and bpd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# adhd and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# adhd and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# adhd and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['gulpease_index']
# adhd and ptsd: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# adhd and schizophrenia: Significant parameters - ['coleman_liau_index', 'smog_index'], Insignificant parameters - ['automated_readability_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'wiener_sachtextformel']
# adhd and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# anxiety and autism: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# anxiety and bpd: Significant parameters - ['automated_readability_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['coleman_liau_index']
# anxiety and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# anxiety and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# anxiety and healthanxiety: Significant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'gulpease_index', 'lix']
# anxiety and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# anxiety and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index', 'smog_index']
# anxiety and socialanxiety: Significant parameters - ['lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index']
# autism and bpd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['gunning_fog_index', 'smog_index']
# autism and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# bpd and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# bpd and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# bpd and healthanxiety: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# bpd and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# bpd and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['gunning_fog_index', 'smog_index']
# bpd and socialanxiety: Significant parameters - ['flesch_kincaid_grade_level', 'gulpease_index'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# depression and ed: Significant parameters - ['automated_readability_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['coleman_liau_index']
# depression and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# depression and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# depression and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# depression and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# healthanxiety and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['gulpease_index']
# healthanxiety and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['gulpease_index']
# healthanxiety and socialanxiety: Significant parameters - ['flesch_kincaid_grade_level', 'gunning_fog_index'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'gulpease_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# ptsd and schizophrenia: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# ptsd and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index']
# schizophrenia and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index']

# %%
tukeys_df = pd.DataFrame(index=pd.MultiIndex.from_tuples(itertools.combinations(datasets.keys(), 2)), columns=readability_parameters)

pretty_table(tukeys_df)
# Out:
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+
# |           Condition Pair           | automated_readability_index | coleman_liau_index | flesch_kincaid_grade_level | flesch_reading_ease | gulpease_index | gunning_fog_index |      lix      |   smog_index  | wiener_sachtextformel |
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+
# |        ('adhd', 'anxiety')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('adhd', 'autism')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |          ('adhd', 'bpd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('adhd', 'depression')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('adhd', 'ed')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('adhd', 'healthanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |          ('adhd', 'ptsd')          |        Insignificant        |   Insignificant    |        Significant         |     Significant     | Insignificant  |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |     ('adhd', 'schizophrenia')      |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |     ('adhd', 'socialanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('anxiety', 'autism')        |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('anxiety', 'bpd')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('anxiety', 'depression')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('anxiety', 'ed')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('anxiety', 'healthanxiety')    |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# |        ('anxiety', 'ptsd')         |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |   Insignificant   | Insignificant | Insignificant |      Significant      |
# |    ('anxiety', 'schizophrenia')    |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |   Insignificant   |  Significant  | Insignificant |      Significant      |
# |    ('anxiety', 'socialanxiety')    |        Insignificant        |    Significant     |       Insignificant        |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('autism', 'bpd')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('autism', 'depression')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |          ('autism', 'ed')          |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'healthanxiety')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |         ('autism', 'ptsd')         |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'schizophrenia')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |    ('autism', 'socialanxiety')     |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('bpd', 'depression')        |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('bpd', 'ed')            |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'healthanxiety')      |        Insignificant        |    Significant     |       Insignificant        |    Insignificant    | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |          ('bpd', 'ptsd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'schizophrenia')      |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('bpd', 'socialanxiety')      |         Significant         |   Insignificant    |        Significant         |    Insignificant    |  Significant   |   Insignificant   | Insignificant | Insignificant |     Insignificant     |
# |        ('depression', 'ed')        |         Significant         |   Insignificant    |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'healthanxiety')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |       ('depression', 'ptsd')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'schizophrenia')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |  ('depression', 'socialanxiety')   |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'healthanxiety')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |           ('ed', 'ptsd')           |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'schizophrenia')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |      ('ed', 'socialanxiety')       |         Significant         |    Significant     |        Significant         |     Significant     |  Significant   |    Significant    |  Significant  |  Significant  |      Significant      |
# |     ('healthanxiety', 'ptsd')      |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('healthanxiety', 'schizophrenia') |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('healthanxiety', 'socialanxiety') |        Insignificant        |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    | Insignificant |  Significant  |     Insignificant     |
# |     ('ptsd', 'schizophrenia')      |        Insignificant        |   Insignificant    |       Insignificant        |    Insignificant    | Insignificant  |   Insignificant   | Insignificant | Insignificant |     Insignificant     |
# |     ('ptsd', 'socialanxiety')      |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# | ('schizophrenia', 'socialanxiety') |         Significant         |    Significant     |        Significant         |     Significant     | Insignificant  |    Significant    |  Significant  |  Significant  |      Significant      |
# +------------------------------------+-----------------------------+--------------------+----------------------------+---------------------+----------------+-------------------+---------------+---------------+-----------------------+

# %%
export_pdf_png(tukeys_df, "tukeys_results")

# %%
export_ipywidgets(tukeys_df)
# Out:
# GridBox(children=(Button(layout=Layout(width='100px'), style=ButtonStyle(button_color='white')), Button(layout…

# %% [markdown]
# ***Effect Size Calculation***
#
# Effect size measures quantify the strength of relationships, differences between means, or explained variance, aiding in the interpretation of study findings.
#
# * Cohen's d: For comparing means between two groups, Cohen's d quantifies the difference in standard deviation units. Larger values indicate more substantial differences. A common benchmark is: small (around 0.2), medium (around 0.5), large (around 0.8).
#
# * Interpretation Nuances: The significance of effect sizes varies across fields and contexts. Consider practical implications, previous research benchmarks, and the specific context of the study for accurate interpretation.
#
# Null Hypothesis: There is no practical or significant difference or relationship between the compared groups or variables.

# %%
def cohen_d(group1, group2):
    diff = mean(group1) - mean(group2)
    pooled_std = ((len(group1) - 1) * std(group1) ** 2 + (len(group2) - 1) * std(group2) ** 2) / (len(group1) + len(group2) - 2)
    pooled_std = pooled_std ** 0.5
    return diff / pooled_std

effect_sizes = {}
cohens_d_significant_parameters = {pair: [] for pair in itertools.combinations(diseases, 2)}
cohens_d_insignificant_parameters = {pair: [] for pair in itertools.combinations(diseases, 2)}

# Threshold for Cohen's d
cohens_d_threshold = 0.2 

for parameter in readability_parameters:
    for pair in itertools.combinations(diseases, 2):
        dataset_1 = datasets[pair[0]][parameter]
        dataset_2 = datasets[pair[1]][parameter]

        effect_size = cohen_d(dataset_1, dataset_2)
        if parameter not in effect_sizes:
            effect_sizes[parameter] = {}
        effect_sizes[parameter][pair] = effect_size

        if abs(effect_size) >= cohens_d_threshold:
            cohens_d_significant_parameters[pair].append(parameter)
        else:
            cohens_d_insignificant_parameters[pair].append(parameter)

print("\nEffect sizes for all combinations of datasets and parameters:")
for parameter, pairs in effect_sizes.items():
    print(f"Effect sizes for {parameter}:")
    for pair, effect_size in pairs.items():
        print(f"{pair}: Cohen's d = {effect_size}")
    print()

print("Summary of significant and insignificant parameters for Cohen's d test:")
for pair in itertools.combinations(diseases, 2):
    significant = cohens_d_significant_parameters[pair]
    insignificant = cohens_d_insignificant_parameters[pair]
    print(f"{pair[0]} and {pair[1]}: Significant parameters - {significant if significant else 'None'}, Insignificant parameters - {insignificant if insignificant else 'None'}")
# Out:
# Effect sizes for all combinations of datasets and parameters:
# Effect sizes for automated_readability_index:
# ('adhd', 'anxiety'): Cohen's d = 0.20542691322575413
# ('adhd', 'autism'): Cohen's d = -0.28313073414414625
# ('adhd', 'bpd'): Cohen's d = 0.2685520173547663
# ('adhd', 'depression'): Cohen's d = 0.44900807783643026
# ('adhd', 'ed'): Cohen's d = 0.5234501006471771
# ('adhd', 'healthanxiety'): Cohen's d = 0.19519113705540642
# ('adhd', 'ptsd'): Cohen's d = 0.019201112703271073
# ('adhd', 'schizophrenia'): Cohen's d = -0.05413634384586858
# ('adhd', 'socialanxiety'): Cohen's d = 0.20044981035470866
# ('anxiety', 'autism'): Cohen's d = -0.5282286209734334
# ('anxiety', 'bpd'): Cohen's d = 0.08292862380496019
# ('anxiety', 'depression'): Cohen's d = 0.2690870700880647
# ('anxiety', 'ed'): Cohen's d = 0.3789275255000619
# ('anxiety', 'healthanxiety'): Cohen's d = 0.006467107651982365
# ('anxiety', 'ptsd'): Cohen's d = -0.18666370456672848
# ('anxiety', 'schizophrenia'): Cohen's d = -0.2698479290220461
# ('anxiety', 'socialanxiety'): Cohen's d = 0.006063900243459502
# ('autism', 'bpd'): Cohen's d = 0.540668865516492
# ('autism', 'depression'): Cohen's d = 0.7298719863911746
# ('autism', 'ed'): Cohen's d = 0.7208884621766593
# ('autism', 'healthanxiety'): Cohen's d = 0.4281214505763159
# ('autism', 'ptsd'): Cohen's d = 0.25073178592635204
# ('autism', 'schizophrenia'): Cohen's d = 0.2014969381878915
# ('autism', 'socialanxiety'): Cohen's d = 0.4862109314859134
# ('bpd', 'depression'): Cohen's d = 0.18786921618986277
# ('bpd', 'ed'): Cohen's d = 0.2685219270535851
# ('bpd', 'healthanxiety'): Cohen's d = -0.06997737234536607
# ('bpd', 'ptsd'): Cohen's d = -0.23741000821096933
# ('bpd', 'schizophrenia'): Cohen's d = -0.31612761062441297
# ('bpd', 'socialanxiety'): Cohen's d = -0.07297009346413372
# ('depression', 'ed'): Cohen's d = 0.09270570137740207
# ('depression', 'healthanxiety'): Cohen's d = -0.25436283624381184
# ('depression', 'ptsd'): Cohen's d = -0.4252425564114024
# ('depression', 'schizophrenia'): Cohen's d = -0.4998153701775543
# ('depression', 'socialanxiety'): Cohen's d = -0.25697065385459583
# ('ed', 'healthanxiety'): Cohen's d = -0.3147429401261782
# ('ed', 'ptsd'): Cohen's d = -0.45359839699081794
# ('ed', 'schizophrenia'): Cohen's d = -0.5302345861362009
# ('ed', 'socialanxiety'): Cohen's d = -0.3398499833445576
# ('healthanxiety', 'ptsd'): Cohen's d = -0.15424328585267247
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.23033357499826887
# ('healthanxiety', 'socialanxiety'): Cohen's d = -0.00038331137565552573
# ('ptsd', 'schizophrenia'): Cohen's d = -0.0638384471672808
# ('ptsd', 'socialanxiety'): Cohen's d = 0.1750766109726916
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.25358608632156576
#
# Effect sizes for coleman_liau_index:
# ('adhd', 'anxiety'): Cohen's d = 0.24883507899530014
# ('adhd', 'autism'): Cohen's d = -0.37758981756952487
# ('adhd', 'bpd'): Cohen's d = 0.2845802205801535
# ('adhd', 'depression'): Cohen's d = 0.546070965142594
# ('adhd', 'ed'): Cohen's d = 0.47625674167231663
# ('adhd', 'healthanxiety'): Cohen's d = 0.1493779767113589
# ('adhd', 'ptsd'): Cohen's d = -0.015670212858932085
# ('adhd', 'schizophrenia'): Cohen's d = -0.1376979562772572
# ('adhd', 'socialanxiety'): Cohen's d = 0.28395196476875
# ('anxiety', 'autism'): Cohen's d = -0.7115870409547107
# ('anxiety', 'bpd'): Cohen's d = 0.0666475271320608
# ('anxiety', 'depression'): Cohen's d = 0.33380077563941746
# ('anxiety', 'ed'): Cohen's d = 0.32163838840029685
# ('anxiety', 'healthanxiety'): Cohen's d = -0.08056217803674619
# ('anxiety', 'ptsd'): Cohen's d = -0.2690362272481465
# ('anxiety', 'schizophrenia'): Cohen's d = -0.42128385677619645
# ('anxiety', 'socialanxiety'): Cohen's d = 0.05793941933689499
# ('autism', 'bpd'): Cohen's d = 0.6557851211768707
# ('autism', 'depression'): Cohen's d = 0.9436541468708545
# ('autism', 'ed'): Cohen's d = 0.711027041240366
# ('autism', 'healthanxiety'): Cohen's d = 0.4412013052691529
# ('autism', 'ptsd'): Cohen's d = 0.26799911621945244
# ('autism', 'schizophrenia'): Cohen's d = 0.203126004179924
# ('autism', 'socialanxiety'): Cohen's d = 0.692091777650723
# ('bpd', 'depression'): Cohen's d = 0.2645786773914516
# ('bpd', 'ed'): Cohen's d = 0.22069333885504272
# ('bpd', 'healthanxiety'): Cohen's d = -0.12654494777923406
# ('bpd', 'ptsd'): Cohen's d = -0.2736150027742223
# ('bpd', 'schizophrenia'): Cohen's d = -0.41781750145356206
# ('bpd', 'socialanxiety'): Cohen's d = -0.00930667587612672
# ('depression', 'ed'): Cohen's d = -0.007264849900277878
# ('depression', 'healthanxiety'): Cohen's d = -0.3889657110899342
# ('depression', 'ptsd'): Cohen's d = -0.5559339465305777
# ('depression', 'schizophrenia'): Cohen's d = -0.6887028805989173
# ('depression', 'socialanxiety'): Cohen's d = -0.27519013140469417
# ('ed', 'healthanxiety'): Cohen's d = -0.29677650877094186
# ('ed', 'ptsd'): Cohen's d = -0.4080008476818232
# ('ed', 'schizophrenia'): Cohen's d = -0.5316731012279268
# ('ed', 'socialanxiety'): Cohen's d = -0.23796350860779414
# ('healthanxiety', 'ptsd'): Cohen's d = -0.1283131219842046
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.25181393679647635
# ('healthanxiety', 'socialanxiety'): Cohen's d = 0.12594212799060583
# ('ptsd', 'schizophrenia'): Cohen's d = -0.09551748904305894
# ('ptsd', 'socialanxiety'): Cohen's d = 0.28435338269710314
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.4348442297316031
#
# Effect sizes for flesch_kincaid_grade_level:
# ('adhd', 'anxiety'): Cohen's d = 0.2003306403824775
# ('adhd', 'autism'): Cohen's d = -0.08290148911881132
# ('adhd', 'bpd'): Cohen's d = 0.29585063094922814
# ('adhd', 'depression'): Cohen's d = 0.5021542802857077
# ('adhd', 'ed'): Cohen's d = 0.696475988329943
# ('adhd', 'healthanxiety'): Cohen's d = 0.3432920540216888
# ('adhd', 'ptsd'): Cohen's d = 0.1136709788422052
# ('adhd', 'schizophrenia'): Cohen's d = 0.10505742573778522
# ('adhd', 'socialanxiety'): Cohen's d = 0.19775598441967343
# ('anxiety', 'autism'): Cohen's d = -0.29222007969061786
# ('anxiety', 'bpd'): Cohen's d = 0.1113463772414843
# ('anxiety', 'depression'): Cohen's d = 0.3195441092298783
# ('anxiety', 'ed'): Cohen's d = 0.5381752543347301
# ('anxiety', 'healthanxiety'): Cohen's d = 0.16357352964365582
# ('anxiety', 'ptsd'): Cohen's d = -0.08224191805965685
# ('anxiety', 'schizophrenia'): Cohen's d = -0.08775120168212583
# ('anxiety', 'socialanxiety'): Cohen's d = 0.006456431559490717
# ('autism', 'bpd'): Cohen's d = 0.36727557982996567
# ('autism', 'depression'): Cohen's d = 0.5824418436543823
# ('autism', 'ed'): Cohen's d = 0.7518097340745111
# ('autism', 'healthanxiety'): Cohen's d = 0.39905719238435033
# ('autism', 'ptsd'): Cohen's d = 0.1804548171724719
# ('autism', 'schizophrenia'): Cohen's d = 0.16722847007721622
# ('autism', 'socialanxiety'): Cohen's d = 0.27493441899230076
# ('bpd', 'depression'): Cohen's d = 0.2096144710155203
# ('bpd', 'ed'): Cohen's d = 0.40333113851330415
# ('bpd', 'healthanxiety'): Cohen's d = 0.04786121258908743
# ('bpd', 'ptsd'): Cohen's d = -0.1807662036152373
# ('bpd', 'schizophrenia'): Cohen's d = -0.18068166331227145
# ('bpd', 'socialanxiety'): Cohen's d = -0.09949296739524076
# ('depression', 'ed'): Cohen's d = 0.18910470160856702
# ('depression', 'healthanxiety'): Cohen's d = -0.1626585625012752
# ('depression', 'ptsd'): Cohen's d = -0.38806956478429966
# ('depression', 'schizophrenia'): Cohen's d = -0.39272223767037
# ('depression', 'socialanxiety'): Cohen's d = -0.3073209921944937
# ('ed', 'healthanxiety'): Cohen's d = -0.3559993964291633
# ('ed', 'ptsd'): Cohen's d = -0.5775235023001583
# ('ed', 'schizophrenia'): Cohen's d = -0.5655167884277431
# ('ed', 'socialanxiety'): Cohen's d = -0.5035890788709416
# ('healthanxiety', 'ptsd'): Cohen's d = -0.22732781509686925
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.21939703779187222
# ('healthanxiety', 'socialanxiety'): Cohen's d = -0.14796930964269478
# ('ptsd', 'schizophrenia'): Cohen's d = -0.005981087162767065
# ('ptsd', 'socialanxiety'): Cohen's d = 0.08302521741132836
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.0867619032586325
#
# Effect sizes for flesch_reading_ease:
# ('adhd', 'anxiety'): Cohen's d = -0.26869831666880445
# ('adhd', 'autism'): Cohen's d = 0.11689317922894835
# ('adhd', 'bpd'): Cohen's d = -0.34758424808117855
# ('adhd', 'depression'): Cohen's d = -0.6564835980493078
# ('adhd', 'ed'): Cohen's d = -0.7464912788723738
# ('adhd', 'healthanxiety'): Cohen's d = -0.3961979971135264
# ('adhd', 'ptsd'): Cohen's d = -0.12243456165240517
# ('adhd', 'schizophrenia'): Cohen's d = -0.07153330768469297
# ('adhd', 'socialanxiety'): Cohen's d = -0.30099222856723207
# ('anxiety', 'autism'): Cohen's d = 0.3984875302068142
# ('anxiety', 'bpd'): Cohen's d = -0.09842846554055674
# ('anxiety', 'depression'): Cohen's d = -0.40435090103723104
# ('anxiety', 'ed'): Cohen's d = -0.5272984737407577
# ('anxiety', 'healthanxiety'): Cohen's d = -0.15636188288517833
# ('anxiety', 'ptsd'): Cohen's d = 0.13979870385504467
# ('anxiety', 'schizophrenia'): Cohen's d = 0.19070286771499018
# ('anxiety', 'socialanxiety'): Cohen's d = -0.04578271627014338
# ('autism', 'bpd'): Cohen's d = -0.446755039245154
# ('autism', 'depression'): Cohen's d = -0.7770138687226671
# ('autism', 'ed'): Cohen's d = -0.8223597167046646
# ('autism', 'healthanxiety'): Cohen's d = -0.456835597192812
# ('autism', 'ptsd'): Cohen's d = -0.20917952025850017
# ('autism', 'schizophrenia'): Cohen's d = -0.16186519930689872
# ('autism', 'socialanxiety'): Cohen's d = -0.41017188328469817
# ('bpd', 'depression'): Cohen's d = -0.3036978933725729
# ('bpd', 'ed'): Cohen's d = -0.4030039273521294
# ('bpd', 'healthanxiety'): Cohen's d = -0.053149670345088856
# ('bpd', 'ptsd'): Cohen's d = 0.21758631673933243
# ('bpd', 'schizophrenia'): Cohen's d = 0.25877372976858687
# ('bpd', 'socialanxiety'): Cohen's d = 0.05049412129480317
# ('depression', 'ed'): Cohen's d = -0.10928717349425776
# ('depression', 'healthanxiety'): Cohen's d = 0.2482772846276418
# ('depression', 'ptsd'): Cohen's d = 0.5295349101080534
# ('depression', 'schizophrenia'): Cohen's d = 0.5780811496997709
# ('depression', 'socialanxiety'): Cohen's d = 0.3549838796648599
# ('ed', 'healthanxiety'): Cohen's d = 0.3411285723950523
# ('ed', 'ptsd'): Cohen's d = 0.6036035430234296
# ('ed', 'schizophrenia'): Cohen's d = 0.6349050755740464
# ('ed', 'socialanxiety'): Cohen's d = 0.4585437051414378
# ('healthanxiety', 'ptsd'): Cohen's d = 0.25229549717006516
# ('healthanxiety', 'schizophrenia'): Cohen's d = 0.2869496746980064
# ('healthanxiety', 'socialanxiety'): Cohen's d = 0.10418317290831253
# ('ptsd', 'schizophrenia'): Cohen's d = 0.04342576552576326
# ('ptsd', 'socialanxiety'): Cohen's d = -0.17340429420508605
# ('schizophrenia', 'socialanxiety'): Cohen's d = -0.2172682412649145
#
# Effect sizes for gulpease_index:
# ('adhd', 'anxiety'): Cohen's d = -0.0920405336696395
# ('adhd', 'autism'): Cohen's d = 0.17038961000410158
# ('adhd', 'bpd'): Cohen's d = -0.19403414202827943
# ('adhd', 'depression'): Cohen's d = -0.32575844836521817
# ('adhd', 'ed'): Cohen's d = -0.5129985616324166
# ('adhd', 'healthanxiety'): Cohen's d = -0.12139756275447865
# ('adhd', 'ptsd'): Cohen's d = -0.026163716975677653
# ('adhd', 'schizophrenia'): Cohen's d = -0.04480950284097891
# ('adhd', 'socialanxiety'): Cohen's d = -0.09752480238973932
# ('anxiety', 'autism'): Cohen's d = 0.28720457060093585
# ('anxiety', 'bpd'): Cohen's d = -0.11948953779654094
# ('anxiety', 'depression'): Cohen's d = -0.25143747308312236
# ('anxiety', 'ed'): Cohen's d = -0.48266675163532424
# ('anxiety', 'healthanxiety'): Cohen's d = -0.03913101318159583
# ('anxiety', 'ptsd'): Cohen's d = 0.06565606243325571
# ('anxiety', 'schizophrenia'): Cohen's d = 0.04377807556713898
# ('anxiety', 'socialanxiety'): Cohen's d = -0.010385736876916801
# ('autism', 'bpd'): Cohen's d = -0.36451047104665224
# ('autism', 'depression'): Cohen's d = -0.48704169618656934
# ('autism', 'ed'): Cohen's d = -0.6129231417686467
# ('autism', 'healthanxiety'): Cohen's d = -0.302162567532293
# ('autism', 'ptsd'): Cohen's d = -0.18717426172784363
# ('autism', 'schizophrenia'): Cohen's d = -0.20151221108593614
# ('autism', 'socialanxiety'): Cohen's d = -0.2837707253149153
# ('bpd', 'depression'): Cohen's d = -0.13896177281673197
# ('bpd', 'ed'): Cohen's d = -0.3221813789334096
# ('bpd', 'healthanxiety'): Cohen's d = 0.07602499559308579
# ('bpd', 'ptsd'): Cohen's d = 0.16511905747211006
# ('bpd', 'schizophrenia'): Cohen's d = 0.14403408759908887
# ('bpd', 'socialanxiety'): Cohen's d = 0.10434787352534503
# ('depression', 'ed'): Cohen's d = -0.20216019401280627
# ('depression', 'healthanxiety'): Cohen's d = 0.20960758097509435
# ('depression', 'ptsd'): Cohen's d = 0.2978220169655505
# ('depression', 'schizophrenia'): Cohen's d = 0.2790924344264794
# ('depression', 'socialanxiety'): Cohen's d = 0.23589015022890666
# ('ed', 'healthanxiety'): Cohen's d = 0.3763107611916369
# ('ed', 'ptsd'): Cohen's d = 0.44276500208552905
# ('ed', 'schizophrenia'): Cohen's d = 0.4275497725564263
# ('ed', 'socialanxiety'): Cohen's d = 0.42894380515752495
# ('healthanxiety', 'ptsd'): Cohen's d = 0.09457878353533115
# ('healthanxiety', 'schizophrenia'): Cohen's d = 0.07279091553886224
# ('healthanxiety', 'socialanxiety'): Cohen's d = 0.027829251365656494
# ('ptsd', 'schizophrenia'): Cohen's d = -0.01755648386883408
# ('ptsd', 'socialanxiety'): Cohen's d = -0.07193399438775228
# ('schizophrenia', 'socialanxiety'): Cohen's d = -0.05063858447297407
#
# Effect sizes for gunning_fog_index:
# ('adhd', 'anxiety'): Cohen's d = 0.12275572081893017
# ('adhd', 'autism'): Cohen's d = -0.05742383015351856
# ('adhd', 'bpd'): Cohen's d = 0.21363712651404804
# ('adhd', 'depression'): Cohen's d = 0.45362833878678865
# ('adhd', 'ed'): Cohen's d = 0.6999509485816436
# ('adhd', 'healthanxiety'): Cohen's d = 0.32777731648763986
# ('adhd', 'ptsd'): Cohen's d = 0.07581355450595767
# ('adhd', 'schizophrenia'): Cohen's d = 0.09824398922529923
# ('adhd', 'socialanxiety'): Cohen's d = 0.17937487837079652
# ('anxiety', 'autism'): Cohen's d = -0.18386663396501748
# ('anxiety', 'bpd'): Cohen's d = 0.09942698366200686
# ('anxiety', 'depression'): Cohen's d = 0.3392971712612632
# ('anxiety', 'ed'): Cohen's d = 0.6023447417130262
# ('anxiety', 'healthanxiety'): Cohen's d = 0.21826362181688996
# ('anxiety', 'ptsd'): Cohen's d = -0.044704099694104354
# ('anxiety', 'schizophrenia'): Cohen's d = -0.0186439066317795
# ('anxiety', 'socialanxiety'): Cohen's d = 0.06286932145814372
# ('autism', 'bpd'): Cohen's d = 0.26143860594184865
# ('autism', 'depression'): Cohen's d = 0.509872163288128
# ('autism', 'ed'): Cohen's d = 0.7439981507363688
# ('autism', 'healthanxiety'): Cohen's d = 0.36658547084201454
# ('autism', 'ptsd'): Cohen's d = 0.12375905985471179
# ('autism', 'schizophrenia'): Cohen's d = 0.13931321434551144
# ('autism', 'socialanxiety'): Cohen's d = 0.23130732136431215
# ('bpd', 'depression'): Cohen's d = 0.2388190095438556
# ('bpd', 'ed'): Cohen's d = 0.48218392274410943
# ('bpd', 'healthanxiety'): Cohen's d = 0.11130453922069046
# ('bpd', 'ptsd'): Cohen's d = -0.13581104872070754
# ('bpd', 'schizophrenia'): Cohen's d = -0.10781437330646426
# ('bpd', 'socialanxiety'): Cohen's d = -0.03510814018877886
# ('depression', 'ed'): Cohen's d = 0.24046976260543257
# ('depression', 'healthanxiety'): Cohen's d = -0.12771671458017578
# ('depression', 'ptsd'): Cohen's d = -0.37712151760784807
# ('depression', 'schizophrenia'): Cohen's d = -0.3507525407683599
# ('depression', 'socialanxiety'): Cohen's d = -0.27446587722037297
# ('ed', 'healthanxiety'): Cohen's d = -0.37794631429218184
# ('ed', 'ptsd'): Cohen's d = -0.6252629933939492
# ('ed', 'schizophrenia'): Cohen's d = -0.5783062764669691
# ('ed', 'socialanxiety'): Cohen's d = -0.521163315979158
# ('healthanxiety', 'ptsd'): Cohen's d = -0.25032723280662345
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.21069070875641469
# ('healthanxiety', 'socialanxiety'): Cohen's d = -0.148150764298099
# ('ptsd', 'schizophrenia'): Cohen's d = 0.022341937223138347
# ('ptsd', 'socialanxiety'): Cohen's d = 0.1025167524584534
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.0755583098961531
#
# Effect sizes for lix:
# ('adhd', 'anxiety'): Cohen's d = 0.16357990171714265
# ('adhd', 'autism'): Cohen's d = -0.1905482033447701
# ('adhd', 'bpd'): Cohen's d = 0.2875498694985882
# ('adhd', 'depression'): Cohen's d = 0.530733483314424
# ('adhd', 'ed'): Cohen's d = 0.675455219717064
# ('adhd', 'healthanxiety'): Cohen's d = 0.27584249002368255
# ('adhd', 'ptsd'): Cohen's d = 0.08508004545981585
# ('adhd', 'schizophrenia'): Cohen's d = -0.011290978525214658
# ('adhd', 'socialanxiety'): Cohen's d = 0.26418825058551215
# ('anxiety', 'autism'): Cohen's d = -0.3619543959662819
# ('anxiety', 'bpd'): Cohen's d = 0.133406934927323
# ('anxiety', 'depression'): Cohen's d = 0.37778928185926686
# ('anxiety', 'ed'): Cohen's d = 0.5332727469648929
# ('anxiety', 'healthanxiety'): Cohen's d = 0.12024036506528794
# ('anxiety', 'ptsd'): Cohen's d = -0.07662235560324401
# ('anxiety', 'schizophrenia'): Cohen's d = -0.17249461229187027
# ('anxiety', 'socialanxiety'): Cohen's d = 0.10783235819126434
# ('autism', 'bpd'): Cohen's d = 0.45543511104246914
# ('autism', 'depression'): Cohen's d = 0.7169323560134596
# ('autism', 'ed'): Cohen's d = 0.8277868023896355
# ('autism', 'healthanxiety'): Cohen's d = 0.4320315412903275
# ('autism', 'ptsd'): Cohen's d = 0.25123105669493173
# ('autism', 'schizophrenia'): Cohen's d = 0.15083050817797464
# ('autism', 'socialanxiety'): Cohen's d = 0.44093490203929464
# ('bpd', 'depression'): Cohen's d = 0.2445710924463124
# ('bpd', 'ed'): Cohen's d = 0.38156982585096894
# ('bpd', 'healthanxiety'): Cohen's d = -0.013918700700124947
# ('bpd', 'ptsd'): Cohen's d = -0.1985594636932477
# ('bpd', 'schizophrenia'): Cohen's d = -0.2760446238757073
# ('bpd', 'socialanxiety'): Cohen's d = -0.024976757781551173
# ('depression', 'ed'): Cohen's d = 0.1378096289731173
# ('depression', 'healthanxiety'): Cohen's d = -0.2587761412229705
# ('depression', 'ptsd'): Cohen's d = -0.4448488638148687
# ('depression', 'schizophrenia'): Cohen's d = -0.5356381246167111
# ('depression', 'socialanxiety'): Cohen's d = -0.2699514708548004
# ('ed', 'healthanxiety'): Cohen's d = -0.3987330926054282
# ('ed', 'ptsd'): Cohen's d = -0.5804605709574001
# ('ed', 'schizophrenia'): Cohen's d = -0.6382105233773191
# ('ed', 'socialanxiety'): Cohen's d = -0.41074668350653837
# ('healthanxiety', 'ptsd'): Cohen's d = -0.18692044984669917
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.25327604808869303
# ('healthanxiety', 'socialanxiety'): Cohen's d = -0.011126216555733258
# ('ptsd', 'schizophrenia'): Cohen's d = -0.08397697163596
# ('ptsd', 'socialanxiety'): Cohen's d = 0.17701881238289988
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.25843824340779853
#
# Effect sizes for smog_index:
# ('adhd', 'anxiety'): Cohen's d = 0.1396478813855441
# ('adhd', 'autism'): Cohen's d = -0.04698089798279095
# ('adhd', 'bpd'): Cohen's d = 0.22744849844845366
# ('adhd', 'depression'): Cohen's d = 0.5372533453247051
# ('adhd', 'ed'): Cohen's d = 0.7660688964152413
# ('adhd', 'healthanxiety'): Cohen's d = 0.36200085252053166
# ('adhd', 'ptsd'): Cohen's d = 0.07387651252526563
# ('adhd', 'schizophrenia'): Cohen's d = 0.124993808035832
# ('adhd', 'socialanxiety'): Cohen's d = 0.24795060550618603
# ('anxiety', 'autism'): Cohen's d = -0.18818185470060184
# ('anxiety', 'bpd'): Cohen's d = 0.09568996097314329
# ('anxiety', 'depression'): Cohen's d = 0.4101082734341251
# ('anxiety', 'ed'): Cohen's d = 0.6529055943950695
# ('anxiety', 'healthanxiety'): Cohen's d = 0.232487254634047
# ('anxiety', 'ptsd'): Cohen's d = -0.06405859721878955
# ('anxiety', 'schizophrenia'): Cohen's d = -0.007854882614613212
# ('anxiety', 'socialanxiety'): Cohen's d = 0.11624717321463568
# ('autism', 'bpd'): Cohen's d = 0.2600197561776275
# ('autism', 'depression'): Cohen's d = 0.5777834709863376
# ('autism', 'ed'): Cohen's d = 0.7684123405493365
# ('autism', 'healthanxiety'): Cohen's d = 0.38246482272614707
# ('autism', 'ptsd'): Cohen's d = 0.11032954183350681
# ('autism', 'schizophrenia'): Cohen's d = 0.15126181981585712
# ('autism', 'socialanxiety'): Cohen's d = 0.2824261758027906
# ('bpd', 'depression'): Cohen's d = 0.31229133731875836
# ('bpd', 'ed'): Cohen's d = 0.5246648787060385
# ('bpd', 'healthanxiety'): Cohen's d = 0.12730436234512837
# ('bpd', 'ptsd'): Cohen's d = -0.14960801067446522
# ('bpd', 'schizophrenia'): Cohen's d = -0.09393013244582464
# ('bpd', 'socialanxiety'): Cohen's d = 0.019442788909211216
# ('depression', 'ed'): Cohen's d = 0.21545240685905134
# ('depression', 'healthanxiety'): Cohen's d = -0.18717959070406676
# ('depression', 'ptsd'): Cohen's d = -0.4621440379480089
# ('depression', 'schizophrenia'): Cohen's d = -0.40781650014328785
# ('depression', 'socialanxiety'): Cohen's d = -0.29331891737307936
# ('ed', 'healthanxiety'): Cohen's d = -0.40435060418990915
# ('ed', 'ptsd'): Cohen's d = -0.6704723814435827
# ('ed', 'schizophrenia'): Cohen's d = -0.5988336459152933
# ('ed', 'socialanxiety'): Cohen's d = -0.5088092436653758
# ('healthanxiety', 'ptsd'): Cohen's d = -0.282937838697786
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.21291521752351544
# ('healthanxiety', 'socialanxiety'): Cohen's d = -0.10848781785075426
# ('ptsd', 'schizophrenia'): Cohen's d = 0.04848264822260852
# ('ptsd', 'socialanxiety'): Cohen's d = 0.17052762068855112
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.11397987661612619
#
# Effect sizes for wiener_sachtextformel:
# ('adhd', 'anxiety'): Cohen's d = 0.18438093588980883
# ('adhd', 'autism'): Cohen's d = -0.15100949934950156
# ('adhd', 'bpd'): Cohen's d = 0.3007164798570273
# ('adhd', 'depression'): Cohen's d = 0.6282947177328589
# ('adhd', 'ed'): Cohen's d = 0.7731448651763416
# ('adhd', 'healthanxiety'): Cohen's d = 0.355933037514926
# ('adhd', 'ptsd'): Cohen's d = 0.09212216908840484
# ('adhd', 'schizophrenia'): Cohen's d = 0.019598718310692785
# ('adhd', 'socialanxiety'): Cohen's d = 0.3066918754984177
# ('anxiety', 'autism'): Cohen's d = -0.33619669561177695
# ('anxiety', 'bpd'): Cohen's d = 0.12258133473206635
# ('anxiety', 'depression'): Cohen's d = 0.4462530591078043
# ('anxiety', 'ed'): Cohen's d = 0.5932685398088068
# ('anxiety', 'healthanxiety'): Cohen's d = 0.17606317685877113
# ('anxiety', 'ptsd'): Cohen's d = -0.0902170704635537
# ('anxiety', 'schizophrenia'): Cohen's d = -0.15892339088423738
# ('anxiety', 'socialanxiety'): Cohen's d = 0.12618644627849393
# ('autism', 'bpd'): Cohen's d = 0.423366834671687
# ('autism', 'depression'): Cohen's d = 0.7791498134946728
# ('autism', 'ed'): Cohen's d = 0.8964496906299912
# ('autism', 'healthanxiety'): Cohen's d = 0.4601617156799094
# ('autism', 'ptsd'): Cohen's d = 0.21670237807467008
# ('autism', 'schizophrenia'): Cohen's d = 0.14100122749781685
# ('autism', 'socialanxiety'): Cohen's d = 0.43931668036931354
# ('bpd', 'depression'): Cohen's d = 0.3204026315681113
# ('bpd', 'ed'): Cohen's d = 0.4552391963409336
# ('bpd', 'healthanxiety'): Cohen's d = 0.049397506365008594
# ('bpd', 'ptsd'): Cohen's d = -0.20038161855015402
# ('bpd', 'schizophrenia'): Cohen's d = -0.25360305753969475
# ('bpd', 'socialanxiety'): Cohen's d = 0.00263623182690947
# ('depression', 'ed'): Cohen's d = 0.14146413647240713
# ('depression', 'healthanxiety'): Cohen's d = -0.26976523973007105
# ('depression', 'ptsd'): Cohen's d = -0.5337853905544729
# ('depression', 'schizophrenia'): Cohen's d = -0.6004604734999237
# ('depression', 'socialanxiety'): Cohen's d = -0.3186183218793129
# ('ed', 'healthanxiety'): Cohen's d = -0.41339686111179463
# ('ed', 'ptsd'): Cohen's d = -0.6723024272867242
# ('ed', 'schizophrenia'): Cohen's d = -0.6980313626929999
# ('ed', 'socialanxiety'): Cohen's d = -0.4597631185409294
# ('healthanxiety', 'ptsd'): Cohen's d = -0.24957414220527369
# ('healthanxiety', 'schizophrenia'): Cohen's d = -0.2869752781582024
# ('healthanxiety', 'socialanxiety'): Cohen's d = -0.04807115666158866
# ('ptsd', 'schizophrenia'): Cohen's d = -0.060412978165823784
# ('ptsd', 'socialanxiety'): Cohen's d = 0.20885244127400726
# ('schizophrenia', 'socialanxiety'): Cohen's d = 0.2640426595677243
#
# Summary of significant and insignificant parameters for Cohen's d test:
# adhd and anxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease'], Insignificant parameters - ['gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# adhd and autism: Significant parameters - ['automated_readability_index', 'coleman_liau_index'], Insignificant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# adhd and bpd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['gulpease_index']
# adhd and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# adhd and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# adhd and healthanxiety: Significant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'gulpease_index']
# adhd and ptsd: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# adhd and schizophrenia: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# adhd and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index']
# anxiety and autism: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['gunning_fog_index', 'smog_index']
# anxiety and bpd: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# anxiety and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# anxiety and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# anxiety and healthanxiety: Significant parameters - ['gunning_fog_index', 'smog_index'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'lix', 'wiener_sachtextformel']
# anxiety and ptsd: Significant parameters - ['coleman_liau_index'], Insignificant parameters - ['automated_readability_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# anxiety and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index'], Insignificant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# anxiety and socialanxiety: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# autism and bpd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and depression: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# autism and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index', 'smog_index']
# autism and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'gulpease_index'], Insignificant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# autism and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# bpd and depression: Significant parameters - ['coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['automated_readability_index', 'gulpease_index']
# bpd and ed: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# bpd and healthanxiety: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# bpd and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index']
# bpd and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index', 'smog_index']
# bpd and socialanxiety: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# depression and ed: Significant parameters - ['gulpease_index', 'gunning_fog_index', 'smog_index'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'lix', 'wiener_sachtextformel']
# depression and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'gulpease_index', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gunning_fog_index', 'smog_index']
# depression and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# depression and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# depression and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and healthanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and ptsd: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# ed and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - None
# healthanxiety and ptsd: Significant parameters - ['flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'gulpease_index', 'lix']
# healthanxiety and schizophrenia: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel'], Insignificant parameters - ['gulpease_index']
# healthanxiety and socialanxiety: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# ptsd and schizophrenia: Significant parameters - None, Insignificant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index', 'wiener_sachtextformel']
# ptsd and socialanxiety: Significant parameters - ['coleman_liau_index', 'wiener_sachtextformel'], Insignificant parameters - ['automated_readability_index', 'flesch_kincaid_grade_level', 'flesch_reading_ease', 'gulpease_index', 'gunning_fog_index', 'lix', 'smog_index']
# schizophrenia and socialanxiety: Significant parameters - ['automated_readability_index', 'coleman_liau_index', 'flesch_reading_ease', 'lix', 'wiener_sachtextformel'], Insignificant parameters - ['flesch_kincaid_grade_level', 'gulpease_index', 'gunning_fog_index', 'smog_index']
